# %%
#!/usr/bin/python
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import os
import glob
# from model import *
from functions import *
import pdb
import scipy.stats as stats
from scipy.signal import spectrogram

# %% [markdown]
# # Go to the directory and print the *.csv files

# %%
directory = '/raid/togzhan_syrymova/lump_project/data/'
os.chdir(directory)
# glob.glob('*.csv')

# %% [markdown]
# # Load the datasets

# %%
directory = '/raid/togzhan_syrymova/lump_project/data/'
os.chdir(directory)
csv_files_train = glob.glob('df_train*raw*8.csv')
csv_files_test = glob.glob('test*raw*.csv')
csv_files_dev = glob.glob('df_dev*raw*8.csv')

index = 0

df_train_ = pd.read_csv(csv_files_train[index], sep = ',', header = None)
df_train_ = pd.DataFrame(df_train_.values[1:,:])

df_test1 = pd.read_csv(csv_files_test[index], sep = ',', header = None)
df_test2 = pd.read_csv(csv_files_test[index+1], sep = ',', header = None)
df_test_ = pd.concat([df_test1, df_test2], axis = 1)
df_test_ = df_test_.transpose()

df_dev_ = pd.read_csv(csv_files_dev[index], sep = ',', header = None)
df_dev_ = pd.DataFrame(df_dev_.values[1:,:])


print(csv_files_train, '\n')
print(csv_files_test, '\n')
print(csv_files_dev, '\n')

print(csv_files_train[index], '\n')
print(csv_files_test[index], '\n')
print(csv_files_dev[index], '\n')
# Out:
# ['df_train_raw_8.csv']
#
# ['test_pressure_data_without_raw.csv', 'test_pressure_data_with_raw.csv']
#
# ['df_dev_raw_8.csv']
#
# df_train_raw_8.csv
#
# test_pressure_data_without_raw.csv
#
# df_dev_raw_8.csv

# %% [markdown]
# # Get labels and data separately

# %%
# Train and dev labels
train_y11 = pd.DataFrame((df_train_.values[:,-1].astype('float64')))
dev_y11 = pd.DataFrame((df_dev_.values[:,-1].astype('float64')))

# Create test labels
test_y11 = pd.concat([ pd.DataFrame([0 for i in range(2*32*9)]), pd.DataFrame([1 for i in range(2*32*9)])], axis=0)
test_y11 = test_y11.reset_index(drop=True)


df_train1 = pd.DataFrame(df_train_.values[:,:-1].astype('float64'))
df_dev1 = pd.DataFrame(df_dev_.values[:,:-1].astype('float64'))
df_test1 = df_test_.astype('float64')

## SHUFFLE the TEST labels and data
test_y1, df_test1 = shuffle(test_y11.astype('float64'), df_test1)

# %%
def get_data(idx, df_train1, df_dev1, df_test1):
    df_train_mean = pd.DataFrame()
    df_train_stdev = pd.DataFrame()

    df_test_mean = pd.DataFrame()
    df_test_stdev = pd.DataFrame()

    df_dev_mean = pd.DataFrame()
    df_dev_stdev = pd.DataFrame()
    if (idx == 0):
        for i in range(15):
            df_train_mean = pd.concat([df_train_mean, pd.DataFrame(np.mean(df_train1.values[:, i*1120:(i+1)*1120], axis = 1))], axis = 1)
            df_train_stdev = pd.concat([df_train_stdev, pd.DataFrame(np.std(df_train1.values[:, i*1120:(i+1)*1120], axis = 1))], axis = 1)

            df_dev_mean = pd.concat([df_dev_mean, pd.DataFrame(np.mean(df_dev1.values[:, i*1120:(i+1)*1120], axis = 1))], axis = 1)
            df_dev_stdev = pd.concat([df_dev_stdev, pd.DataFrame(np.std(df_dev1.values[:, i*1120:(i+1)*1120], axis = 1))], axis = 1)

            df_test_mean = pd.concat([df_test_mean, pd.DataFrame(np.mean(df_test1.values[:, i*1120:(i+1)*1120], axis = 1))], axis = 1)
            df_test_stdev = pd.concat([df_test_stdev, pd.DataFrame(np.std(df_test1.values[:, i*1120:(i+1)*1120], axis = 1))], axis = 1)

        df_train = pd.concat([df_train_mean, df_train_stdev], axis = 1)
        df_dev = pd.concat([df_dev_mean, df_dev_stdev], axis = 1)
        df_test = pd.concat([df_test_mean, df_test_stdev], axis = 1)
        return df_train, df_dev, df_test
    
    elif (idx == 1):
        train_y2 = pd.DataFrame()
        dev_y2 = pd.DataFrame()
        test_y2 = pd.DataFrame()

        for j in range(7):
            df_train_mean_s = pd.DataFrame()
            df_train_stdev_s = pd.DataFrame()

            df_test_mean_s = pd.DataFrame()
            df_test_stdev_s = pd.DataFrame()

            df_dev_mean_s = pd.DataFrame()
            df_dev_stdev_s = pd.DataFrame()

            for i in range(15):
                index1 = i*1120+j*160
                index2 = i*1120+(j+1)*160
                df_train_mean_s = pd.concat([df_train_mean_s, pd.DataFrame(np.mean(df_train1.values[:, index1:index2], axis = 1))], axis = 1)
                df_train_stdev_s = pd.concat([df_train_stdev_s, pd.DataFrame(np.std(df_train1.values[:, index1:index2], axis = 1))], axis = 1)

                df_dev_mean_s = pd.concat([df_dev_mean_s, pd.DataFrame(np.mean(df_dev1.values[:, index1:index2], axis = 1))], axis = 1)
                df_dev_stdev_s = pd.concat([df_dev_stdev_s, pd.DataFrame(np.std(df_dev1.values[:, index1:index2], axis = 1))], axis = 1)

                df_test_mean_s = pd.concat([df_test_mean_s, pd.DataFrame(np.mean(df_test1.values[:, index1:index2], axis = 1))], axis = 1)
                df_test_stdev_s = pd.concat([df_test_stdev_s, pd.DataFrame(np.std(df_test1.values[:, index1:index2], axis = 1))], axis = 1)

            df_train_mean = pd.concat([df_train_mean, df_train_mean_s], axis = 0)
            df_train_stdev = pd.concat([df_train_stdev, df_train_stdev_s], axis = 0)

            df_test_mean = pd.concat([df_test_mean, df_test_mean_s], axis = 0)
            df_test_stdev = pd.concat([df_test_stdev, df_test_stdev_s], axis = 0)

            df_dev_mean = pd.concat([df_dev_mean, df_dev_mean_s], axis = 0)
            df_dev_stdev = pd.concat([df_dev_stdev, df_dev_stdev_s], axis = 0)

            # concat labels 7 times corresponding to 7 second
            train_y2 = pd.concat([train_y2, train_y11], axis = 0)
            dev_y2 = pd.concat([dev_y2, dev_y11], axis = 0)
            test_y2 = pd.concat([test_y2, test_y11], axis = 0)


        df_train = pd.concat([df_train_mean, df_train_stdev], axis = 1)
        df_dev = pd.concat([df_dev_mean, df_dev_stdev], axis = 1)
        df_test = pd.concat([df_test_mean, df_test_stdev], axis = 1)
        
    elif(idx == 2):
        df_train = df_train1
        df_dev = df_dev1
        df_test = df_test1
        return df_train, df_dev, df_test
    
    elif(idx == 3): #COMPUTE z-score
        df_train_z = pd.DataFrame()
        df_test_z = pd.DataFrame()
        df_dev_z = pd.DataFrame()
        for i in range(15):
            df_train_z1 = pd.DataFrame()
            df_dev_z1 = pd.DataFrame()
            df_test_z1 = pd.DataFrame()

            index1 = i*1120
            index2 = (i+1)*1120

            d_train = df_train1.values[:, i*1120:(i+1)*1120]
            d_dev = df_dev1.values[:, i*1120:(i+1)*1120]
            d_test = df_test1.values[:, i*1120:(i+1)*1120] 

            df_train_z1 = pd.DataFrame(stats.zscore(d_train, axis = 1))
            df_dev_z1 = pd.DataFrame(stats.zscore(d_dev, axis = 1))
            df_test_z1 = pd.DataFrame(stats.zscore(d_test, axis = 1))

            df_train_z1.columns = [''] * len(df_train_z1.columns)
            df_dev_z1.columns = [''] * len(df_dev_z1.columns)
            df_test_z1.columns = [''] * len(df_test_z1.columns)

        #     df_train_z1 = df_train_z1.reset_indext_index()
            df_train_z = pd.concat([df_train_z, df_train_z1], axis = 1)
            df_dev_z = pd.concat([df_dev_z, df_dev_z1], axis = 1)
            df_test_z = pd.concat([df_test_z, df_test_z1], axis = 1)
            
        return df_train_z, df_dev_z, df_test_z
    
    elif(idx == 4): #COMPUTE z-score
        df_train_z = pd.DataFrame()
        df_test_z = pd.DataFrame()
        df_dev_z = pd.DataFrame()
        df_train_z = pd.DataFrame(stats.zscore(df_train1, axis = 1))
        df_dev_z = pd.DataFrame(stats.zscore(df_dev1, axis = 1))
        df_test_z = pd.DataFrame(stats.zscore(df_test1, axis = 1))
            
        return df_train_z, df_dev_z, df_test_z
    
def compute_spectogram(df):
    df_1 = np.zeros([np.shape(df)[0], 129, 4])
    for i in range(15):
        fs = 160
        f, t, data = spectrogram(df.values[:, 1120*i:(i+1)*1120], fs, axis = 1)
        df_1 = np.concatenate([df_1, 10*np.log10(data)], axis = 1)
        data = []
    return df_1[:, 129:, :],t, f

# %% [markdown]
# # Compute z-score

# %%
# # run FUNCTIONS at the end of the notebook
# idx = 3
# df_train11, df_dev11, df_test11 = get_data(idx, df_train1, df_dev1, df_test1)
# train_y1 = train_y11
# dev_y1 = dev_y11
# test_y1 = test_y1

# %% [markdown]
# # Compute z-score per trial

# %%
# # run FUNCTIONS at the end of the notebook
# idx = 4
# df_train11, df_dev11, df_test11 = get_data(idx, df_train1, df_dev1, df_test1)
# train_y1 = train_y11
# dev_y1 = dev_y11
# test_y1 = test_y11

# %% [markdown]
# # Compute spectogram

# %%
from numpy import newaxis

def compute_spectogram(df):
    df_1 = np.zeros([np.shape(df)[0], 1, 129, 4])
    for i in range(15):
        fs = 160
        f, t, data = spectrogram(df.values[:, 1120*i:(i+1)*1120], fs, axis = 1)
        data1 = data[:, newaxis, ...]
#         d = 10*np.log10(data1)
        df_1 = np.concatenate([df_1, data1], axis = 1)
        data = []
#         print(np.shape(df_1))
    return df_1[:, 1:, :, :],t, f

df_train3, t, f = compute_spectogram(df_train1)
train_y1 = train_y11
print(np.shape(df_train3))

df_dev3, t, f = compute_spectogram(df_dev1)
dev_y1 = dev_y11
print(np.shape(df_dev3))
df_test3, t, f = compute_spectogram(df_test1)
test_y1 = test_y1
print(np.shape(df_test3))
# Out:
# (4032, 15, 129, 4)
# (576, 15, 129, 4)
# (1152, 15, 129, 4)

# %%
shape = np.shape(df_train3)
df_train = np.reshape(df_train3, (shape[0], shape[1], shape[2]*shape[3]))

shape = np.shape(df_dev3)
df_dev = np.reshape(df_dev3, (shape[0], shape[1], shape[2]*shape[3]))


shape = np.shape(df_test3)
df_test = np.reshape(df_test3, (shape[0], shape[1], shape[2]*shape[3]))

# %% [markdown]
# # Create Tensor from labels and data

# %%
# from numpy import newaxis
# sh = np.shape(df_train11)
# a = df_train11.values[:]
# df_train = df_train11.values[:, newaxis, :]
# df_dev = df_dev11.values[:,newaxis, :]
# df_test = df_test11.values[:,newaxis, :]
# print(np.shape(df_train))

# channels_in = 15

# df_train = df_train.reshape(np.shape(df_train)[0], channels_in, np.int64(np.shape(df_train)[2]//channels_in))
# df_dev = df_dev.reshape(np.shape(df_dev)[0], channels_in, np.int64(np.shape(df_dev)[2]//channels_in))
# df_test = df_test.reshape(np.shape(df_test)[0], channels_in, np.int64(np.shape(df_test)[2]//channels_in))
# print(np.shape(df_train))
####


# df_train = df_train11.values[:, :, newaxis]
# df_dev = df_dev11.values[:, :,newaxis]
# df_test = df_test11.values[:, :,newaxis]

# df_train = df_train.reshape(np.shape(df_train)[0], np.int64(np.shape(df_train)[1]//channels_in), channels_in)
# df_dev = df_dev.reshape(np.shape(df_dev)[0], np.int64(np.shape(df_dev)[1]//channels_in), channels_in)
# df_test = df_test.reshape(np.shape(df_test)[0], np.int64(np.shape(df_test)[1]//channels_in), channels_in)
# print(np.shape(df_train))

# %%
# Create tensor from labels
# Transform labels in the format 1_9 to binary
train_y3 = pd.DataFrame(np.floor(train_y1.values[:].astype('float64')/10))
dev_y3 = pd.DataFrame(np.floor(dev_y1.values[:].astype('float64')/10))

train_y = torch.FloatTensor(train_y3.values[:])
dev_y = torch.FloatTensor(dev_y3.values[:])
test_y = torch.FloatTensor(test_y1.values[:])

train_x	= torch.FloatTensor(df_train.astype('float64'))
dev_x = torch.FloatTensor(df_dev.astype('float64'))
test_x = torch.FloatTensor(df_test.astype('float64'))

# %%
print(np.shape(train_x))
print(np.shape(train_y))

print(np.shape(dev_x))
print(np.shape(dev_y))

print(np.shape(test_x))
print(np.shape(test_y))
# Out:
# torch.Size([4032, 15, 516])
# torch.Size([4032, 1])
# torch.Size([576, 15, 516])
# torch.Size([576, 1])
# torch.Size([1152, 15, 516])
# torch.Size([1152, 1])

# %%
# from torch.nn import Conv2d, functional as F, Linear, MaxPool2d, Module

# class ConvLayerNet4(torch.nn.Module):

#     def __init__(self,  channels_in, channels_out, D_in, H, D_out, device, drop=0.0, kernel_size=1, stride=1):
#         super(ConvLayerNet4, self).__init__()
        
#         self.device = device
        
#         self.convs = nn.ModuleList([
#             nn.Conv2d(1, channels_out, kernel_size=kernel_size, stride=stride)
#         for i in range(15)])
        
#         W_out = ((D_in - kernel_size)//stride + 1)*channels_out
        
#         self.pool = MaxPool2d(kernel_size=2, stride=2, padding=0)
        
#         self.linear1_1 = torch.nn.Linear(H3, 64)
#         self.linear2 = torch.nn.Linear(64, D_out)
        
#         self.fc1 = Linear(18 * 16 * 16, 64)
#         self.fc2 = Linear(64, 1)

#     def forward(self, x):
#         ii = 0
#         h_relu = torch.FloatTensor([]).to(self.device)
#         for layers in self.convs:
#             print(np.shape(torch.unsqueeze(x[:, ii, :, :], 1)))
#             x_data = layers(torch.unsqueeze(x[:, ii, :, :], 1)) # torch.unsqueeze(x[:, ii, :, :], 1
#             print(np.shape(x_data))
#             x_data = self.relu(x_data)
#             b, h, w = x_data.size()
#             x_data = x_data.view(b,-1)
#             h_relu = torch.cat([h_relu, x_data], axis = 1)
#             ii = ii+1
            
#         x = F.relu(self.conv(x))
#         x = self.pool(x)
#         x = x.view(-1, 18 * 16 * 16)
#         x = F.relu(self.fc1(x))
#         x = self.fc2(x)
#         return x

# %%
# print(np.shape(train_x))
# print(D_in)
# W_out = ((D_in - kernel_size)//stride + 1)*channels_out
# print(W_out)
# #         W_out = ((W_out - kernel_size)//stride + 1)*channels_out
# W_out = ((W_out - kernel_size)//stride + 1)*15*channels_out
# W_out = np.int64(W_out) 

# print(W_out)

# %% [markdown]
# # Define the hyperparameters of the model

# %%
print('Started training')
seed = 777
torch.manual_seed(seed)

#################
# choose the gpu
gpu_id = 5
device = torch.device("cuda:" + str(gpu_id))
# device = torch.device("cpu")
print(device)

#################
# Input and output sizes
D_in = np.shape(train_x)[2]
channels_in = 1
channels_out = 1

D_out = 1

#################
# Choose the hidden layer, drop, batch_size, num_epochs, learning_rate
# H = 512  #hidden layer size

drop = 0.5
H1 = [ 512, 256, 128]#, 2048,1024, 512
N1 = [8, 16, 32, 64]
epochs = 100
learning_rate = 1e-4
kernel_size = 10
stride  = 3

# loss_fn = torch.nn.BCELoss()BCEWithLogitsLoss
# N = batch_size

best_epoch = 0
dev_acc_max=0
epoch_max=0
loss_list     = np.zeros((epochs,))
accuracy_list = np.zeros((epochs,))
# Out:
# Started training
# cuda:5

# %%
D_in
# Out:
# 516

# %%
# class ConvLayerNet3(torch.nn.Module):
#     def __init__(self,  channels_in, channels_out, D_in, H, D_out, device, drop=0.0, kernel_size=1, stride=1):
#         super(ConvLayerNet3, self).__init__()
#         self.device = device
# #         self.convs = nn.ModuleList([nn.Conv1d(1, channels_out, kernel_size=kernel_size, stride=stride) for i in range(15)])
#         self.convs = nn.ModuleList([nn.Sequential(
#             nn.Conv1d(1, channels_out, kernel_size=kernel_size, stride=stride),
#             nn.Conv1d(1, channels_out, kernel_size=kernel_size, stride=stride),
# #             nn.Conv1d(1, channels_out, kernel_size=kernel_size, stride=stride),
#         ) for i in range(15)])
                                    
#         W_out = ((D_in - kernel_size)//stride + 1)*channels_out
# #         W_out = ((W_out - kernel_size)//stride + 1)*channels_out
#         W_out = ((W_out - kernel_size)//stride + 1)*15*channels_out
#         W_out = np.int64(W_out) 
#         print(W_out)
        
#         self.linear1_1 = torch.nn.Linear(W_out, H)
#         self.linear1_2 = torch.nn.Linear(H, 32)
# #         self.linear1_3 = torch.nn.Linear(H3, 64)
#         self.linear2 = torch.nn.Linear(32, D_out)
        
#         self.relu = torch.nn.ReLU()
#         self.drop1   = torch.nn.Dropout(p=drop)
#         self.sigmoid = torch.nn.Sigmoid()
# #         self.softmax = torch.nn.Softmax(dim=1)

#     def forward(self, x):
#         ii = 0
#         h_relu = torch.FloatTensor([]).to(self.device)
#         for layers in self.convs:
#             x_data = layers(torch.unsqueeze(x[:, ii, :],1))
# #             print(np.shape(x_data))
#             x_data = self.relu(x_data)
#             b, h, w = x_data.size()
#             x_data = x_data.view(b,-1)
#             print(np.shape(x_data))
#             h_relu = torch.cat([h_relu, x_data], axis = 1)
#             ii = ii+1
        
#         h_relu = self.drop1(self.linear1_1(h_relu))#.clamp(min=0)#.clamp(min=0)
#         h_relu = self.relu(h_relu)
        
#         h_relu = self.drop1(self.linear1_2(h_relu))#.clamp(min=0)#.clamp(min=0)
#         h_relu = self.relu(h_relu)
        
# #         h_relu = self.drop1(self.linear1_3(h_relu))#.clamp(min=0)#.clamp(min=0)
# #         h_relu = self.relu(h_relu)
        
#         y_pred = self.sigmoid(self.linear2(h_relu))
        
#         return y_pred
class ConvLayerNet3(torch.nn.Module):
    def __init__(self,  channels_in, channels_out, D_in, H, D_out, device, drop=0.0, kernel_size=1, stride=1):
        super(ConvLayerNet3, self).__init__()
        self.device = device
#         self.convs = nn.ModuleList([nn.Conv1d(1, channels_out, kernel_size=kernel_size, stride=stride) for i in range(15)])
        self.convs = nn.ModuleList([nn.Sequential(
            nn.Conv1d(1, channels_out, kernel_size=kernel_size, stride=stride),
            nn.Conv1d(1, channels_out, kernel_size=kernel_size, stride=stride),
#             nn.Conv1d(1, channels_out, kernel_size=kernel_size, stride=stride),
        ) for i in range(15)])
                                    
        W_out = ((D_in - kernel_size)//stride + 1)*channels_out
#         W_out = ((W_out - kernel_size)//stride + 1)*channels_out
        W_out = ((W_out - kernel_size)//stride + 1)*15*channels_out
        W_out = np.int64(W_out) 
        H3 = H//2
        print(W_out)
        self.linear1_1 = torch.nn.Linear(W_out, H)
        self.linear1_2 = torch.nn.Linear(H, H3)
        self.linear1_3 = torch.nn.Linear(H3, 32)
#         self.linear1_4 = torch.nn.Linear(64, 16)
        self.linear2 = torch.nn.Linear(32, D_out)
        
        self.relu = torch.nn.ReLU()
        self.drop1   = torch.nn.Dropout(p=drop)
        self.sigmoid = torch.nn.Sigmoid()
#         self.softmax = torch.nn.Softmax(dim=1)

    def forward(self, x):
        ii = 0
        h_relu = torch.FloatTensor([]).to(self.device)
        for layers in self.convs:
            x_data = layers(torch.unsqueeze(x[:, ii, :],1))
            x_data = self.relu(x_data)
            b, h, w = x_data.size()
            x_data = x_data.view(b,-1)
            h_relu = torch.cat([h_relu, x_data], axis = 1)
            ii = ii+1
        
        h_relu = self.drop1(self.linear1_1(h_relu))#.clamp(min=0)#.clamp(min=0)
        h_relu = self.relu(h_relu)
        
        h_relu = self.drop1(self.linear1_2(h_relu))#.clamp(min=0)#.clamp(min=0)
        h_relu = self.relu(h_relu)
        
        h_relu = self.drop1(self.linear1_3(h_relu))#.clamp(min=0)#.clamp(min=0)
        h_relu = self.relu(h_relu)
        
#         h_relu = self.drop1(self.linear1_4(h_relu))#.clamp(min=0)#.clamp(min=0)
#         h_relu = self.relu(h_relu)
        
        y_pred = (self.linear2(h_relu))#
        
        return y_pred

# %%
for N in N1:
    for H in H1:
    #         H = 512
    #         H2 = 256
#         epochs  =1
        directory = '/raid/togzhan_syrymova/lump_project/models/'

        model = ConvLayerNet3(channels_in, channels_out, D_in, H, D_out, device, drop, kernel_size, stride).to(device)
        model_name = type(model).__name__

        model_name += '_pressure_' + 'conv2_' + 'epochs_' \
        + str(epochs) + '_bs_' + str(N)+ '_H_' + str(H) \
        + '_drop_' + str(drop) \
        + '_ks_' + str(kernel_size) + '_stride_' + str(stride) + '_spect_1d_bce_loss_lr_3'
        model_path = directory + model_name

        optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
        loss_fn = torch.nn.BCEWithLogitsLoss()#BCELoss()
        print(model_name)
        print(model_path)
        print(model)

        # for H in H1:
        #     for N in N1:
        print(H)
        print(N)
        for e in range(epochs):
            total_loss = 0
            for i in range(0, train_x.shape[0], N):
                if i+N >= train_x.shape[0]:
                    x = train_x[i:]
                    y = train_y[i:]
                else:
                    x = train_x[i:i+N]
                    y = train_y[i:i+N]
                y_pred = model(x.to(device))
                loss = loss_fn(y_pred, y.to(device))
        #         loss_list[e] = loss.item()
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                total_loss += loss.item()
            print("Epoch {}/{}, Train Loss: {:.3f}".format(e+1, epochs, total_loss))
            #pdb.set_trace()
            #Loss and accuracy on dev data
            with torch.no_grad():
                model.eval()
                output = model(dev_x.to(device))
                output = (output>0.5).float()
                acc    = accuracy_score(dev_y, output.cpu())
        #         accuracy_list[e] = acc
                if acc > dev_acc_max:
                    dev_acc_max=acc
                    epoch_max=e+1
                    torch.save(model, model_path)
              #correct = (output == dev_y.to(device)).float().sum()
    #             model.train()
                torch.save(model, model_path+'_last')
            print("Dev Accuracy: {:.3f}".format(acc))

        print("##############################################")
        print("Best dev accuracy is {:.3f} at epoch {}".format(dev_acc_max, epoch_max))
        print("Number of class 1 samples: ", (dev_y>0.5).float().sum().item())
        print("##############################################")

        ####################################################################################################
        #Evaluation
        ####################################################################################################
        with torch.no_grad():
        #             pdb.set_trace()
            model = torch.load(model_path)
            model.eval().to(device)
            output = model(test_x.to(device))
            output = (output>0.5).float()
            acc    = accuracy_score(test_y, output.cpu())
            print("Test Accuracy: {:.3f}".format(acc))
            print(model)

        with torch.no_grad():
        #             pdb.set_trace()
            model = torch.load(model_path+'_last')
            model.eval().to(device)
            output = model(test_x.to(device))
            output = (output>0.5).float()
            acc    = accuracy_score(test_y, output.cpu())
            print("Test Accuracy Last: {:.3f}".format(acc))
            print(model)
exit()
# Out:
# 810
# ConvLayerNet3_pressure_conv2_epochs_100_bs_8_H_512_drop_0.5_ks_10_stride_3_spect_1d_bce_loss_lr_3
# /raid/togzhan_syrymova/lump_project/models/ConvLayerNet3_pressure_conv2_epochs_100_bs_8_H_512_drop_0.5_ks_10_stride_3_spect_1d_bce_loss_lr_3
# ConvLayerNet3(
#   (convs): ModuleList(
#     (0): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (1): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (2): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (3): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (4): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (5): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (6): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (7): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (8): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (9): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (10): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (11): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (12): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (13): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (14): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#   )
#   (linear1_1): Linear(in_features=810, out_features=512, bias=True)
#   (linear1_2): Linear(in_features=512, out_features=256, bias=True)
#   (linear1_3): Linear(in_features=256, out_features=32, bias=True)
#   (linear2): Linear(in_features=32, out_features=1, bias=True)
#   (relu): ReLU()
#   (drop1): Dropout(p=0.5, inplace=False)
#   (sigmoid): Sigmoid()
# )
# 512
# 8
# Epoch 1/100, Train Loss: 339.284
# Dev Accuracy: 0.571
# Epoch 2/100, Train Loss: 292.135
# Dev Accuracy: 0.628
# Epoch 3/100, Train Loss: 276.733
# Dev Accuracy: 0.670
# Epoch 4/100, Train Loss: 259.540
# Dev Accuracy: 0.677
# Epoch 5/100, Train Loss: 242.748
# Dev Accuracy: 0.698
# Epoch 6/100, Train Loss: 227.505
# Dev Accuracy: 0.724
# Epoch 7/100, Train Loss: 215.779
# Dev Accuracy: 0.734
# Epoch 8/100, Train Loss: 206.721
# Dev Accuracy: 0.738
# Epoch 9/100, Train Loss: 199.005
# Dev Accuracy: 0.747
# Epoch 10/100, Train Loss: 191.128
# Dev Accuracy: 0.760
# Epoch 11/100, Train Loss: 182.745
# Dev Accuracy: 0.766
# Epoch 12/100, Train Loss: 175.355
# Dev Accuracy: 0.764
# Epoch 13/100, Train Loss: 168.185
# Dev Accuracy: 0.759
# Epoch 14/100, Train Loss: 162.389
# Dev Accuracy: 0.774
# Epoch 15/100, Train Loss: 154.075
# Dev Accuracy: 0.790
# Epoch 16/100, Train Loss: 148.104
# Dev Accuracy: 0.797
# Epoch 17/100, Train Loss: 140.648
# Dev Accuracy: 0.786
# Epoch 18/100, Train Loss: 135.104
# Dev Accuracy: 0.806
# Epoch 19/100, Train Loss: 127.697
# Dev Accuracy: 0.802
# Epoch 20/100, Train Loss: 123.637
# Dev Accuracy: 0.814
# Epoch 21/100, Train Loss: 114.839
# Dev Accuracy: 0.818
# Epoch 22/100, Train Loss: 108.926
# Dev Accuracy: 0.830
# Epoch 23/100, Train Loss: 104.390
# Dev Accuracy: 0.819
# Epoch 24/100, Train Loss: 102.243
# Dev Accuracy: 0.832
# Epoch 25/100, Train Loss: 92.634
# Dev Accuracy: 0.821
# Epoch 26/100, Train Loss: 92.405
# Dev Accuracy: 0.823
# Epoch 27/100, Train Loss: 86.471
# Dev Accuracy: 0.830
# Epoch 28/100, Train Loss: 78.732
# Dev Accuracy: 0.821
# Epoch 29/100, Train Loss: 75.085
# Dev Accuracy: 0.828
# Epoch 30/100, Train Loss: 70.460
# Dev Accuracy: 0.825
# Epoch 31/100, Train Loss: 76.553
# Dev Accuracy: 0.823
# Epoch 32/100, Train Loss: 68.147
# Dev Accuracy: 0.835
# Epoch 33/100, Train Loss: 59.985
# Dev Accuracy: 0.806
# Epoch 34/100, Train Loss: 57.415
# Dev Accuracy: 0.812
# Epoch 35/100, Train Loss: 48.945
# Dev Accuracy: 0.828
# Epoch 36/100, Train Loss: 47.224
# Dev Accuracy: 0.819
# Epoch 37/100, Train Loss: 58.847
# Dev Accuracy: 0.807
# Epoch 38/100, Train Loss: 61.263
# Dev Accuracy: 0.825
# Epoch 39/100, Train Loss: 41.149
# Dev Accuracy: 0.811
# Epoch 40/100, Train Loss: 44.434
# Dev Accuracy: 0.828
# Epoch 41/100, Train Loss: 47.546
# Dev Accuracy: 0.826
# Epoch 42/100, Train Loss: 36.403
# Dev Accuracy: 0.814
# Epoch 43/100, Train Loss: 35.426
# Dev Accuracy: 0.825
# Epoch 44/100, Train Loss: 29.373
# Dev Accuracy: 0.832
# Epoch 45/100, Train Loss: 33.461
# Dev Accuracy: 0.816
# Epoch 46/100, Train Loss: 32.483
# Dev Accuracy: 0.839
# Epoch 47/100, Train Loss: 44.631
# Dev Accuracy: 0.826
# Epoch 48/100, Train Loss: 23.810
# Dev Accuracy: 0.826
# Epoch 49/100, Train Loss: 19.576
# Dev Accuracy: 0.819
# Epoch 50/100, Train Loss: 34.230
# Dev Accuracy: 0.814
# Epoch 51/100, Train Loss: 33.500
# Dev Accuracy: 0.825
# Epoch 52/100, Train Loss: 20.008
# Dev Accuracy: 0.786
# Epoch 53/100, Train Loss: 17.505
# Dev Accuracy: 0.823
# Epoch 54/100, Train Loss: 15.635
# Dev Accuracy: 0.814
# Epoch 55/100, Train Loss: 16.079
# Dev Accuracy: 0.807
# Epoch 56/100, Train Loss: 34.826
# Dev Accuracy: 0.806
# Epoch 57/100, Train Loss: 21.351
# Dev Accuracy: 0.780
# Epoch 58/100, Train Loss: 29.146
# Dev Accuracy: 0.818
# Epoch 59/100, Train Loss: 20.562
# Dev Accuracy: 0.814
# Epoch 60/100, Train Loss: 14.113
# Dev Accuracy: 0.847
# Epoch 61/100, Train Loss: 15.349
# Dev Accuracy: 0.837
# Epoch 62/100, Train Loss: 17.111
# Dev Accuracy: 0.797
# Epoch 63/100, Train Loss: 29.294
# Dev Accuracy: 0.839
# Epoch 64/100, Train Loss: 16.829
# Dev Accuracy: 0.837
# Epoch 65/100, Train Loss: 14.087
# Dev Accuracy: 0.818
# Epoch 66/100, Train Loss: 10.195
# Dev Accuracy: 0.823
# Epoch 67/100, Train Loss: 10.541
# Dev Accuracy: 0.830
# Epoch 68/100, Train Loss: 38.445
# Dev Accuracy: 0.821
# Epoch 69/100, Train Loss: 10.857
# Dev Accuracy: 0.842
# Epoch 70/100, Train Loss: 7.071
# Dev Accuracy: 0.847
# Epoch 71/100, Train Loss: 4.796
# Dev Accuracy: 0.839
# Epoch 72/100, Train Loss: 14.378
# Dev Accuracy: 0.851
# Epoch 73/100, Train Loss: 24.409
# Dev Accuracy: 0.842
# Epoch 74/100, Train Loss: 9.332
# Dev Accuracy: 0.840
# Epoch 75/100, Train Loss: 21.193
# Dev Accuracy: 0.844
# Epoch 76/100, Train Loss: 7.050
# Dev Accuracy: 0.856
# Epoch 77/100, Train Loss: 16.590
# Dev Accuracy: 0.826
# Epoch 78/100, Train Loss: 10.798
# Dev Accuracy: 0.832
# Epoch 79/100, Train Loss: 16.485
# Dev Accuracy: 0.852
# Epoch 80/100, Train Loss: 12.352
# Dev Accuracy: 0.825
# Epoch 81/100, Train Loss: 7.772
# Dev Accuracy: 0.851
# Epoch 82/100, Train Loss: 5.212
# Dev Accuracy: 0.851
# Epoch 83/100, Train Loss: 18.315
# Dev Accuracy: 0.842
# Epoch 84/100, Train Loss: 14.870
# Dev Accuracy: 0.854
# Epoch 85/100, Train Loss: 12.078
# Dev Accuracy: 0.856
# Epoch 86/100, Train Loss: 8.382
# Dev Accuracy: 0.863
# Epoch 87/100, Train Loss: 3.450
# Dev Accuracy: 0.865
# Epoch 88/100, Train Loss: 15.059
# Dev Accuracy: 0.868
# Epoch 89/100, Train Loss: 13.162
# Dev Accuracy: 0.854
# Epoch 90/100, Train Loss: 9.850
# Dev Accuracy: 0.856
# Epoch 91/100, Train Loss: 5.428
# Dev Accuracy: 0.849
# Epoch 92/100, Train Loss: 2.618
# Dev Accuracy: 0.856
# Epoch 93/100, Train Loss: 13.135
# Dev Accuracy: 0.839
# Epoch 94/100, Train Loss: 22.461
# Dev Accuracy: 0.837
# Epoch 95/100, Train Loss: 13.444
# Dev Accuracy: 0.849
# Epoch 96/100, Train Loss: 7.692
# Dev Accuracy: 0.852
# Epoch 97/100, Train Loss: 10.606
# Dev Accuracy: 0.837
# Epoch 98/100, Train Loss: 9.610
# Dev Accuracy: 0.828
# Epoch 99/100, Train Loss: 11.415
# Dev Accuracy: 0.835
# Epoch 100/100, Train Loss: 8.140
# Dev Accuracy: 0.856
# ##############################################
# Best dev accuracy is 0.868 at epoch 88
# Number of class 1 samples:  288.0
# ##############################################
# Test Accuracy: 0.607
# ConvLayerNet3(
#   (convs): ModuleList(
#     (0): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (1): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (2): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (3): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (4): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (5): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (6): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (7): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (8): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (9): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (10): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (11): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (12): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (13): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (14): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#   )
#   (linear1_1): Linear(in_features=810, out_features=512, bias=True)
#   (linear1_2): Linear(in_features=512, out_features=256, bias=True)
#   (linear1_3): Linear(in_features=256, out_features=32, bias=True)
#   (linear2): Linear(in_features=32, out_features=1, bias=True)
#   (relu): ReLU()
#   (drop1): Dropout(p=0.5, inplace=False)
#   (sigmoid): Sigmoid()
# )
# Test Accuracy Last: 0.630
# ConvLayerNet3(
#   (convs): ModuleList(
#     (0): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (1): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (2): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (3): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (4): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (5): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (6): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (7): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (8): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (9): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (10): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (11): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (12): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (13): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (14): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#   )
#   (linear1_1): Linear(in_features=810, out_features=512, bias=True)
#   (linear1_2): Linear(in_features=512, out_features=256, bias=True)
#   (linear1_3): Linear(in_features=256, out_features=32, bias=True)
#   (linear2): Linear(in_features=32, out_features=1, bias=True)
#   (relu): ReLU()
#   (drop1): Dropout(p=0.5, inplace=False)
#   (sigmoid): Sigmoid()
# )
# 810
# ConvLayerNet3_pressure_conv2_epochs_100_bs_8_H_256_drop_0.5_ks_10_stride_3_spect_1d_bce_loss_lr_3
# /raid/togzhan_syrymova/lump_project/models/ConvLayerNet3_pressure_conv2_epochs_100_bs_8_H_256_drop_0.5_ks_10_stride_3_spect_1d_bce_loss_lr_3
# ConvLayerNet3(
#   (convs): ModuleList(
#     (0): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (1): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (2): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (3): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (4): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (5): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (6): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (7): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (8): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (9): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (10): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (11): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (12): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (13): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (14): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#   )
#   (linear1_1): Linear(in_features=810, out_features=256, bias=True)
#   (linear1_2): Linear(in_features=256, out_features=128, bias=True)
#   (linear1_3): Linear(in_features=128, out_features=32, bias=True)
#   (linear2): Linear(in_features=32, out_features=1, bias=True)
#   (relu): ReLU()
#   (drop1): Dropout(p=0.5, inplace=False)
#   (sigmoid): Sigmoid()
# )
# 256
# 8
# Epoch 1/100, Train Loss: 403.299
# Dev Accuracy: 0.535
# Epoch 2/100, Train Loss: 300.533
# Dev Accuracy: 0.583
# Epoch 3/100, Train Loss: 264.722
# Dev Accuracy: 0.747
# Epoch 4/100, Train Loss: 238.310
# Dev Accuracy: 0.773
# Epoch 5/100, Train Loss: 221.383
# Dev Accuracy: 0.780
# Epoch 6/100, Train Loss: 207.765
# Dev Accuracy: 0.780
# Epoch 7/100, Train Loss: 197.011
# Dev Accuracy: 0.781
# Epoch 8/100, Train Loss: 189.086
# Dev Accuracy: 0.790
# Epoch 9/100, Train Loss: 181.422
# Dev Accuracy: 0.802
# Epoch 10/100, Train Loss: 174.245
# Dev Accuracy: 0.806
# Epoch 11/100, Train Loss: 167.806
# Dev Accuracy: 0.812
# Epoch 12/100, Train Loss: 160.945
# Dev Accuracy: 0.806
# Epoch 13/100, Train Loss: 154.913
# Dev Accuracy: 0.818
# Epoch 14/100, Train Loss: 149.958
# Dev Accuracy: 0.823
# Epoch 15/100, Train Loss: 143.368
# Dev Accuracy: 0.830
# Epoch 16/100, Train Loss: 138.564
# Dev Accuracy: 0.837
# Epoch 17/100, Train Loss: 133.078
# Dev Accuracy: 0.835
# Epoch 18/100, Train Loss: 128.563
# Dev Accuracy: 0.840
# Epoch 19/100, Train Loss: 124.103
# Dev Accuracy: 0.842
# Epoch 20/100, Train Loss: 121.632
# Dev Accuracy: 0.847
# Epoch 21/100, Train Loss: 115.885
# Dev Accuracy: 0.851
# Epoch 22/100, Train Loss: 111.914
# Dev Accuracy: 0.847
# Epoch 23/100, Train Loss: 107.794
# Dev Accuracy: 0.856
# Epoch 24/100, Train Loss: 103.822
# Dev Accuracy: 0.852
# Epoch 25/100, Train Loss: 100.054
# Dev Accuracy: 0.861
# Epoch 26/100, Train Loss: 96.664
# Dev Accuracy: 0.861
# Epoch 27/100, Train Loss: 93.001
# Dev Accuracy: 0.861
# Epoch 28/100, Train Loss: 89.364
# Dev Accuracy: 0.863
# Epoch 29/100, Train Loss: 85.814
# Dev Accuracy: 0.865
# Epoch 30/100, Train Loss: 82.898
# Dev Accuracy: 0.866
# Epoch 31/100, Train Loss: 78.631
# Dev Accuracy: 0.868
# Epoch 32/100, Train Loss: 75.931
# Dev Accuracy: 0.866
# Epoch 33/100, Train Loss: 72.955
# Dev Accuracy: 0.870
# Epoch 34/100, Train Loss: 69.613
# Dev Accuracy: 0.866
# Epoch 35/100, Train Loss: 66.842
# Dev Accuracy: 0.873
# Epoch 36/100, Train Loss: 63.762
# Dev Accuracy: 0.870
# Epoch 37/100, Train Loss: 68.710
# Dev Accuracy: 0.872
# Epoch 38/100, Train Loss: 72.744
# Dev Accuracy: 0.863
# Epoch 39/100, Train Loss: 56.526
# Dev Accuracy: 0.868
# Epoch 40/100, Train Loss: 56.973
# Dev Accuracy: 0.870
# Epoch 41/100, Train Loss: 51.946
# Dev Accuracy: 0.872
# Epoch 42/100, Train Loss: 49.812
# Dev Accuracy: 0.880
# Epoch 43/100, Train Loss: 54.772
# Dev Accuracy: 0.880
# Epoch 44/100, Train Loss: 47.483
# Dev Accuracy: 0.861
# Epoch 45/100, Train Loss: 46.727
# Dev Accuracy: 0.870
# Epoch 46/100, Train Loss: 41.621
# Dev Accuracy: 0.863
# Epoch 47/100, Train Loss: 43.262
# Dev Accuracy: 0.866
# Epoch 48/100, Train Loss: 40.018
# Dev Accuracy: 0.863
# Epoch 49/100, Train Loss: 41.789
# Dev Accuracy: 0.875
# Epoch 50/100, Train Loss: 34.171
# Dev Accuracy: 0.870
# Epoch 51/100, Train Loss: 31.965
# Dev Accuracy: 0.872
# Epoch 52/100, Train Loss: 36.497
# Dev Accuracy: 0.877
# Epoch 53/100, Train Loss: 42.140
# Dev Accuracy: 0.865
# Epoch 54/100, Train Loss: 32.255
# Dev Accuracy: 0.863
# Epoch 55/100, Train Loss: 39.357
# Dev Accuracy: 0.866
# Epoch 56/100, Train Loss: 39.275
# Dev Accuracy: 0.854
# Epoch 57/100, Train Loss: 29.633
# Dev Accuracy: 0.863
# Epoch 58/100, Train Loss: 28.359
# Dev Accuracy: 0.877
# Epoch 59/100, Train Loss: 26.235
# Dev Accuracy: 0.865
# Epoch 60/100, Train Loss: 24.027
# Dev Accuracy: 0.866
# Epoch 61/100, Train Loss: 17.383
# Dev Accuracy: 0.866
# Epoch 62/100, Train Loss: 27.368
# Dev Accuracy: 0.873
# Epoch 63/100, Train Loss: 22.802
# Dev Accuracy: 0.872
# Epoch 64/100, Train Loss: 22.047
# Dev Accuracy: 0.880
# Epoch 65/100, Train Loss: 25.006
# Dev Accuracy: 0.873
# Epoch 66/100, Train Loss: 14.872
# Dev Accuracy: 0.873
# Epoch 67/100, Train Loss: 22.217
# Dev Accuracy: 0.877
# Epoch 68/100, Train Loss: 12.964
# Dev Accuracy: 0.873
# Epoch 69/100, Train Loss: 12.923
# Dev Accuracy: 0.865
# Epoch 70/100, Train Loss: 19.985
# Dev Accuracy: 0.863
# Epoch 71/100, Train Loss: 30.103
# Dev Accuracy: 0.875
# Epoch 72/100, Train Loss: 12.532
# Dev Accuracy: 0.880
# Epoch 73/100, Train Loss: 16.927
# Dev Accuracy: 0.875
# Epoch 74/100, Train Loss: 13.275
# Dev Accuracy: 0.877
# Epoch 75/100, Train Loss: 11.465
# Dev Accuracy: 0.880
# Epoch 76/100, Train Loss: 19.412
# Dev Accuracy: 0.859
# Epoch 77/100, Train Loss: 23.148
# Dev Accuracy: 0.870
# Epoch 78/100, Train Loss: 11.817
# Dev Accuracy: 0.880
# Epoch 79/100, Train Loss: 13.569
# Dev Accuracy: 0.885
# Epoch 80/100, Train Loss: 14.506
# Dev Accuracy: 0.873
# Epoch 81/100, Train Loss: 11.644
# Dev Accuracy: 0.877
# Epoch 82/100, Train Loss: 8.903
# Dev Accuracy: 0.877
# Epoch 83/100, Train Loss: 8.107
# Dev Accuracy: 0.877
# Epoch 84/100, Train Loss: 8.671
# Dev Accuracy: 0.872
# Epoch 85/100, Train Loss: 6.890
# Dev Accuracy: 0.868
# Epoch 86/100, Train Loss: 34.945
# Dev Accuracy: 0.872
# Epoch 87/100, Train Loss: 17.763
# Dev Accuracy: 0.863
# Epoch 88/100, Train Loss: 9.516
# Dev Accuracy: 0.880
# Epoch 89/100, Train Loss: 11.778
# Dev Accuracy: 0.882
# Epoch 90/100, Train Loss: 5.351
# Dev Accuracy: 0.877
# Epoch 91/100, Train Loss: 7.122
# Dev Accuracy: 0.878
# Epoch 92/100, Train Loss: 19.250
# Dev Accuracy: 0.872
# Epoch 93/100, Train Loss: 18.242
# Dev Accuracy: 0.875
# Epoch 94/100, Train Loss: 8.186
# Dev Accuracy: 0.878
# Epoch 95/100, Train Loss: 4.390
# Dev Accuracy: 0.884
# Epoch 96/100, Train Loss: 3.400
# Dev Accuracy: 0.882
# Epoch 97/100, Train Loss: 22.107
# Dev Accuracy: 0.866
# Epoch 98/100, Train Loss: 8.721
# Dev Accuracy: 0.873
# Epoch 99/100, Train Loss: 4.794
# Dev Accuracy: 0.872
# Epoch 100/100, Train Loss: 10.954
# Dev Accuracy: 0.884
# ##############################################
# Best dev accuracy is 0.885 at epoch 79
# Number of class 1 samples:  288.0
# ##############################################
# Test Accuracy: 0.583
# ConvLayerNet3(
#   (convs): ModuleList(
#     (0): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (1): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (2): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (3): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (4): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (5): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (6): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (7): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (8): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (9): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (10): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (11): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (12): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (13): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (14): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#   )
#   (linear1_1): Linear(in_features=810, out_features=256, bias=True)
#   (linear1_2): Linear(in_features=256, out_features=128, bias=True)
#   (linear1_3): Linear(in_features=128, out_features=32, bias=True)
#   (linear2): Linear(in_features=32, out_features=1, bias=True)
#   (relu): ReLU()
#   (drop1): Dropout(p=0.5, inplace=False)
#   (sigmoid): Sigmoid()
# )
# Test Accuracy Last: 0.578
# ConvLayerNet3(
#   (convs): ModuleList(
#     (0): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (1): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (2): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (3): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (4): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (5): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (6): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (7): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (8): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (9): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (10): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (11): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (12): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (13): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (14): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#   )
#   (linear1_1): Linear(in_features=810, out_features=256, bias=True)
#   (linear1_2): Linear(in_features=256, out_features=128, bias=True)
#   (linear1_3): Linear(in_features=128, out_features=32, bias=True)
#   (linear2): Linear(in_features=32, out_features=1, bias=True)
#   (relu): ReLU()
#   (drop1): Dropout(p=0.5, inplace=False)
#   (sigmoid): Sigmoid()
# )
# 810
# ConvLayerNet3_pressure_conv2_epochs_100_bs_8_H_128_drop_0.5_ks_10_stride_3_spect_1d_bce_loss_lr_3
# /raid/togzhan_syrymova/lump_project/models/ConvLayerNet3_pressure_conv2_epochs_100_bs_8_H_128_drop_0.5_ks_10_stride_3_spect_1d_bce_loss_lr_3
# ConvLayerNet3(
#   (convs): ModuleList(
#     (0): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (1): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (2): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (3): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (4): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (5): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (6): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (7): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (8): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (9): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (10): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (11): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (12): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (13): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (14): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#   )
#   (linear1_1): Linear(in_features=810, out_features=128, bias=True)
#   (linear1_2): Linear(in_features=128, out_features=64, bias=True)
#   (linear1_3): Linear(in_features=64, out_features=32, bias=True)
#   (linear2): Linear(in_features=32, out_features=1, bias=True)
#   (relu): ReLU()
#   (drop1): Dropout(p=0.5, inplace=False)
#   (sigmoid): Sigmoid()
# )
# 128
# 8
# Epoch 1/100, Train Loss: 362.387
# Dev Accuracy: 0.509
# Epoch 2/100, Train Loss: 328.154
# Dev Accuracy: 0.530
# Epoch 3/100, Train Loss: 309.643
# Dev Accuracy: 0.601
# Epoch 4/100, Train Loss: 287.198
# Dev Accuracy: 0.648
# Epoch 5/100, Train Loss: 266.321
# Dev Accuracy: 0.698
# Epoch 6/100, Train Loss: 244.392
# Dev Accuracy: 0.717
# Epoch 7/100, Train Loss: 227.581
# Dev Accuracy: 0.734
# Epoch 8/100, Train Loss: 214.719
# Dev Accuracy: 0.759
# Epoch 9/100, Train Loss: 203.666
# Dev Accuracy: 0.773
# Epoch 10/100, Train Loss: 194.051
# Dev Accuracy: 0.769
# Epoch 11/100, Train Loss: 185.722
# Dev Accuracy: 0.783
# Epoch 12/100, Train Loss: 178.466
# Dev Accuracy: 0.792
# Epoch 13/100, Train Loss: 171.915
# Dev Accuracy: 0.799
# Epoch 14/100, Train Loss: 166.016
# Dev Accuracy: 0.793
# Epoch 15/100, Train Loss: 160.797
# Dev Accuracy: 0.799
# Epoch 16/100, Train Loss: 155.468
# Dev Accuracy: 0.807
# Epoch 17/100, Train Loss: 150.982
# Dev Accuracy: 0.807
# Epoch 18/100, Train Loss: 146.603
# Dev Accuracy: 0.812
# Epoch 19/100, Train Loss: 142.725
# Dev Accuracy: 0.819
# Epoch 20/100, Train Loss: 138.682
# Dev Accuracy: 0.818
# Epoch 21/100, Train Loss: 135.110
# Dev Accuracy: 0.821
# Epoch 22/100, Train Loss: 131.330
# Dev Accuracy: 0.821
# Epoch 23/100, Train Loss: 127.684
# Dev Accuracy: 0.821
# Epoch 24/100, Train Loss: 123.800
# Dev Accuracy: 0.826
# Epoch 25/100, Train Loss: 120.066
# Dev Accuracy: 0.826
# Epoch 26/100, Train Loss: 116.362
# Dev Accuracy: 0.828
# Epoch 27/100, Train Loss: 112.700
# Dev Accuracy: 0.835
# Epoch 28/100, Train Loss: 109.064
# Dev Accuracy: 0.840
# Epoch 29/100, Train Loss: 105.722
# Dev Accuracy: 0.845
# Epoch 30/100, Train Loss: 102.368
# Dev Accuracy: 0.849
# Epoch 31/100, Train Loss: 98.851
# Dev Accuracy: 0.856
# Epoch 32/100, Train Loss: 95.428
# Dev Accuracy: 0.856
# Epoch 33/100, Train Loss: 92.344
# Dev Accuracy: 0.858
# Epoch 34/100, Train Loss: 88.769
# Dev Accuracy: 0.858
# Epoch 35/100, Train Loss: 86.200
# Dev Accuracy: 0.859
# Epoch 36/100, Train Loss: 88.548
# Dev Accuracy: 0.858
# Epoch 37/100, Train Loss: 81.950
# Dev Accuracy: 0.861
# Epoch 38/100, Train Loss: 77.846
# Dev Accuracy: 0.865
# Epoch 39/100, Train Loss: 75.180
# Dev Accuracy: 0.858
# Epoch 40/100, Train Loss: 73.738
# Dev Accuracy: 0.865
# Epoch 41/100, Train Loss: 72.493
# Dev Accuracy: 0.866
# Epoch 42/100, Train Loss: 68.284
# Dev Accuracy: 0.866
# Epoch 43/100, Train Loss: 65.248
# Dev Accuracy: 0.872
# Epoch 44/100, Train Loss: 63.198
# Dev Accuracy: 0.863
# Epoch 45/100, Train Loss: 60.664
# Dev Accuracy: 0.870
# Epoch 46/100, Train Loss: 58.870
# Dev Accuracy: 0.865
# Epoch 47/100, Train Loss: 66.321
# Dev Accuracy: 0.845
# Epoch 48/100, Train Loss: 62.881
# Dev Accuracy: 0.854
# Epoch 49/100, Train Loss: 52.811
# Dev Accuracy: 0.854
# Epoch 50/100, Train Loss: 50.947
# Dev Accuracy: 0.856
# Epoch 51/100, Train Loss: 48.718
# Dev Accuracy: 0.852
# Epoch 52/100, Train Loss: 47.248
# Dev Accuracy: 0.854
# Epoch 53/100, Train Loss: 45.054
# Dev Accuracy: 0.856
# Epoch 54/100, Train Loss: 43.706
# Dev Accuracy: 0.856
# Epoch 55/100, Train Loss: 59.804
# Dev Accuracy: 0.854
# Epoch 56/100, Train Loss: 54.612
# Dev Accuracy: 0.852
# Epoch 57/100, Train Loss: 43.767
# Dev Accuracy: 0.856
# Epoch 58/100, Train Loss: 38.604
# Dev Accuracy: 0.856
# Epoch 59/100, Train Loss: 36.872
# Dev Accuracy: 0.858
# Epoch 60/100, Train Loss: 35.168
# Dev Accuracy: 0.851
# Epoch 61/100, Train Loss: 33.945
# Dev Accuracy: 0.856
# Epoch 62/100, Train Loss: 47.010
# Dev Accuracy: 0.856
# Epoch 63/100, Train Loss: 56.083
# Dev Accuracy: 0.858
# Epoch 64/100, Train Loss: 39.503
# Dev Accuracy: 0.849
# Epoch 65/100, Train Loss: 33.553
# Dev Accuracy: 0.856
# Epoch 66/100, Train Loss: 28.992
# Dev Accuracy: 0.852
# Epoch 67/100, Train Loss: 27.205
# Dev Accuracy: 0.852
# Epoch 68/100, Train Loss: 26.160
# Dev Accuracy: 0.854
# Epoch 69/100, Train Loss: 25.501
# Dev Accuracy: 0.858
# Epoch 70/100, Train Loss: 31.572
# Dev Accuracy: 0.858
# Epoch 71/100, Train Loss: 50.518
# Dev Accuracy: 0.861
# Epoch 72/100, Train Loss: 34.702
# Dev Accuracy: 0.863
# Epoch 73/100, Train Loss: 23.441
# Dev Accuracy: 0.863
# Epoch 74/100, Train Loss: 21.460
# Dev Accuracy: 0.861
# Epoch 75/100, Train Loss: 20.107
# Dev Accuracy: 0.865
# Epoch 76/100, Train Loss: 19.514
# Dev Accuracy: 0.863
# Epoch 77/100, Train Loss: 48.232
# Dev Accuracy: 0.842
# Epoch 78/100, Train Loss: 44.231
# Dev Accuracy: 0.875
# Epoch 79/100, Train Loss: 26.018
# Dev Accuracy: 0.877
# Epoch 80/100, Train Loss: 18.259
# Dev Accuracy: 0.870
# Epoch 81/100, Train Loss: 20.412
# Dev Accuracy: 0.870
# Epoch 82/100, Train Loss: 16.875
# Dev Accuracy: 0.868
# Epoch 83/100, Train Loss: 15.891
# Dev Accuracy: 0.868
# Epoch 84/100, Train Loss: 14.415
# Dev Accuracy: 0.866
# Epoch 85/100, Train Loss: 13.767
# Dev Accuracy: 0.880
# Epoch 86/100, Train Loss: 58.421
# Dev Accuracy: 0.858
# Epoch 87/100, Train Loss: 39.402
# Dev Accuracy: 0.859
# Epoch 88/100, Train Loss: 22.618
# Dev Accuracy: 0.861
# Epoch 89/100, Train Loss: 13.484
# Dev Accuracy: 0.863
# Epoch 90/100, Train Loss: 11.922
# Dev Accuracy: 0.868
# Epoch 91/100, Train Loss: 10.811
# Dev Accuracy: 0.866
# Epoch 92/100, Train Loss: 25.225
# Dev Accuracy: 0.868
# Epoch 93/100, Train Loss: 32.601
# Dev Accuracy: 0.872
# Epoch 94/100, Train Loss: 13.745
# Dev Accuracy: 0.872
# Epoch 95/100, Train Loss: 10.861
# Dev Accuracy: 0.875
# Epoch 96/100, Train Loss: 9.176
# Dev Accuracy: 0.875
# Epoch 97/100, Train Loss: 8.288
# Dev Accuracy: 0.875
# Epoch 98/100, Train Loss: 7.754
# Dev Accuracy: 0.875
# Epoch 99/100, Train Loss: 31.883
# Dev Accuracy: 0.861
# Epoch 100/100, Train Loss: 46.813
# Dev Accuracy: 0.866
# ##############################################
# Best dev accuracy is 0.885 at epoch 79
# Number of class 1 samples:  288.0
# ##############################################
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-34-dd07aa60a5bb> in <module>
#      69         with torch.no_grad():
#      70         #             pdb.set_trace()
# ---> 71             model = torch.load(model_path)
#      72             model.eval().to(device)
#      73             output = model(test_x.to(device))
#
# ~/anaconda3/envs/py_env/lib/python3.8/site-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     577         pickle_load_args['encoding'] = 'utf-8'
#     578
# --> 579     with _open_file_like(f, 'rb') as opened_file:
#     580         if _is_zipfile(opened_file):
#     581             # The zipfile reader is going to advance the current file position.
#
# ~/anaconda3/envs/py_env/lib/python3.8/site-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     228 def _open_file_like(name_or_buffer, mode):
#     229     if _is_path(name_or_buffer):
# --> 230         return _open_file(name_or_buffer, mode)
#     231     else:
#     232         if 'w' in mode:
#
# ~/anaconda3/envs/py_env/lib/python3.8/site-packages/torch/serialization.py in __init__(self, name, mode)
#     209 class _open_file(_opener):
#     210     def __init__(self, name, mode):
# --> 211         super(_open_file, self).__init__(open(name, mode))
#     212
#     213     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/raid/togzhan_syrymova/lump_project/models/ConvLayerNet3_pressure_conv2_epochs_100_bs_8_H_128_drop_0.5_ks_10_stride_3_spect_1d_bce_loss_lr_3'

# %%
with torch.no_grad():
#             pdb.set_trace()
#     model = torch.load(model_path)
    model.eval().to(device)
    output = model(test_x.to(device))
    output = (output>0.5).float()
    acc    = accuracy_score(test_y, output.cpu())
    print("Test Accuracy: {:.3f}".format(acc))
    print(model)
# Out:
# Test Accuracy: 0.631
# ConvLayerNet3(
#   (convs): ModuleList(
#     (0): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (1): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (2): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (3): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (4): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (5): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (6): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (7): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (8): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (9): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (10): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (11): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (12): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (13): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (14): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#   )
#   (linear1_1): Linear(in_features=810, out_features=128, bias=True)
#   (linear1_2): Linear(in_features=128, out_features=64, bias=True)
#   (linear1_3): Linear(in_features=64, out_features=32, bias=True)
#   (linear2): Linear(in_features=32, out_features=1, bias=True)
#   (relu): ReLU()
#   (drop1): Dropout(p=0.5, inplace=False)
#   (sigmoid): Sigmoid()
# )
