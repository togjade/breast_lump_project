# %%
#!/usr/bin/python
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import os
import glob
# from model import *
from functions import *
import pdb
import scipy.stats as stats
from scipy.signal import spectrogram

# %% [markdown]
# # Go to the directory and print the *.csv files

# %%
directory = '/raid/togzhan_syrymova/lump_project/data/'
os.chdir(directory)
# glob.glob('*.csv')

# %% [markdown]
# # Load the datasets

# %%
directory = '/raid/togzhan_syrymova/lump_project/data/'
os.chdir(directory)
csv_files_train = glob.glob('df_train*raw*8.csv')
csv_files_test = glob.glob('test*raw*.csv')
csv_files_dev = glob.glob('df_dev*raw*8.csv')

index = 0

df_train_ = pd.read_csv(csv_files_train[index], sep = ',', header = None)
df_train_ = pd.DataFrame(df_train_.values[1:,:])

df_test1 = pd.read_csv(csv_files_test[index], sep = ',', header = None)
df_test2 = pd.read_csv(csv_files_test[index+1], sep = ',', header = None)
df_test_ = pd.concat([df_test1, df_test2], axis = 1)
df_test_ = df_test_.transpose()

df_dev_ = pd.read_csv(csv_files_dev[index], sep = ',', header = None)
df_dev_ = pd.DataFrame(df_dev_.values[1:,:])


print(csv_files_train, '\n')
print(csv_files_test, '\n')
print(csv_files_dev, '\n')

print(csv_files_train[index], '\n')
print(csv_files_test[index], '\n')
print(csv_files_dev[index], '\n')
# Out:
# ['df_train_raw_8.csv']
#
# ['test_pressure_data_without_raw.csv', 'test_pressure_data_with_raw.csv']
#
# ['df_dev_raw_8.csv']
#
# df_train_raw_8.csv
#
# test_pressure_data_without_raw.csv
#
# df_dev_raw_8.csv

# %% [markdown]
# # Get labels and data separately

# %%
# Train and dev labels
train_y11 = pd.DataFrame((df_train_.values[:,-1].astype('float64')))
dev_y11 = pd.DataFrame((df_dev_.values[:,-1].astype('float64')))

# Create test labels
test_y11 = pd.concat([ pd.DataFrame([0 for i in range(2*32*9)]), pd.DataFrame([1 for i in range(2*32*9)])], axis=0)
test_y11 = test_y11.reset_index(drop=True)


df_train1 = pd.DataFrame(df_train_.values[:,:-1].astype('float64'))
df_dev1 = pd.DataFrame(df_dev_.values[:,:-1].astype('float64'))
df_test1 = df_test_.astype('float64')

## SHUFFLE the TEST labels and data
test_y1, df_test1 = shuffle(test_y11.astype('float64'), df_test1)

# %% [markdown]
# # Compute mean and stdev of the whole sequence per sensor for train/dev/test sets

# %%
# idx = 0
# df_train, df_dev, df_test = get_data(idx, df_train1, df_dev1, df_test1)

# %% [markdown]
# # Compute mean and stdev of the 1 sec of sequence per sensor for train/dev/test sets

# %%
# idx = 1
# df_train, train_y2, df_dev,dev_y2, df_test, test_y2 = get_data(idx, df_train1, df_dev1, df_test1)

# %% [markdown]
# # Run to take imported sequence with no changes

# %%
# import pandas as pd
# import functions
# idx = 2
# df_train, df_dev, df_test = get_data(idx, df_train1, df_dev1, df_test1)

# %%
def get_data(idx, df_train1, df_dev1, df_test1):
    df_train_mean = pd.DataFrame()
    df_train_stdev = pd.DataFrame()

    df_test_mean = pd.DataFrame()
    df_test_stdev = pd.DataFrame()

    df_dev_mean = pd.DataFrame()
    df_dev_stdev = pd.DataFrame()
    if (idx == 0):
        for i in range(15):
            df_train_mean = pd.concat([df_train_mean, pd.DataFrame(np.mean(df_train1.values[:, i*1120:(i+1)*1120], axis = 1))], axis = 1)
            df_train_stdev = pd.concat([df_train_stdev, pd.DataFrame(np.std(df_train1.values[:, i*1120:(i+1)*1120], axis = 1))], axis = 1)

            df_dev_mean = pd.concat([df_dev_mean, pd.DataFrame(np.mean(df_dev1.values[:, i*1120:(i+1)*1120], axis = 1))], axis = 1)
            df_dev_stdev = pd.concat([df_dev_stdev, pd.DataFrame(np.std(df_dev1.values[:, i*1120:(i+1)*1120], axis = 1))], axis = 1)

            df_test_mean = pd.concat([df_test_mean, pd.DataFrame(np.mean(df_test1.values[:, i*1120:(i+1)*1120], axis = 1))], axis = 1)
            df_test_stdev = pd.concat([df_test_stdev, pd.DataFrame(np.std(df_test1.values[:, i*1120:(i+1)*1120], axis = 1))], axis = 1)

        df_train = pd.concat([df_train_mean, df_train_stdev], axis = 1)
        df_dev = pd.concat([df_dev_mean, df_dev_stdev], axis = 1)
        df_test = pd.concat([df_test_mean, df_test_stdev], axis = 1)
        return df_train, df_dev, df_test
    
    elif (idx == 1):
        train_y2 = pd.DataFrame()
        dev_y2 = pd.DataFrame()
        test_y2 = pd.DataFrame()

        for j in range(7):
            df_train_mean_s = pd.DataFrame()
            df_train_stdev_s = pd.DataFrame()

            df_test_mean_s = pd.DataFrame()
            df_test_stdev_s = pd.DataFrame()

            df_dev_mean_s = pd.DataFrame()
            df_dev_stdev_s = pd.DataFrame()

            for i in range(15):
                index1 = i*1120+j*160
                index2 = i*1120+(j+1)*160
                df_train_mean_s = pd.concat([df_train_mean_s, pd.DataFrame(np.mean(df_train1.values[:, index1:index2], axis = 1))], axis = 1)
                df_train_stdev_s = pd.concat([df_train_stdev_s, pd.DataFrame(np.std(df_train1.values[:, index1:index2], axis = 1))], axis = 1)

                df_dev_mean_s = pd.concat([df_dev_mean_s, pd.DataFrame(np.mean(df_dev1.values[:, index1:index2], axis = 1))], axis = 1)
                df_dev_stdev_s = pd.concat([df_dev_stdev_s, pd.DataFrame(np.std(df_dev1.values[:, index1:index2], axis = 1))], axis = 1)

                df_test_mean_s = pd.concat([df_test_mean_s, pd.DataFrame(np.mean(df_test1.values[:, index1:index2], axis = 1))], axis = 1)
                df_test_stdev_s = pd.concat([df_test_stdev_s, pd.DataFrame(np.std(df_test1.values[:, index1:index2], axis = 1))], axis = 1)

            df_train_mean = pd.concat([df_train_mean, df_train_mean_s], axis = 0)
            df_train_stdev = pd.concat([df_train_stdev, df_train_stdev_s], axis = 0)

            df_test_mean = pd.concat([df_test_mean, df_test_mean_s], axis = 0)
            df_test_stdev = pd.concat([df_test_stdev, df_test_stdev_s], axis = 0)

            df_dev_mean = pd.concat([df_dev_mean, df_dev_mean_s], axis = 0)
            df_dev_stdev = pd.concat([df_dev_stdev, df_dev_stdev_s], axis = 0)

            # concat labels 7 times corresponding to 7 second
            train_y2 = pd.concat([train_y2, train_y11], axis = 0)
            dev_y2 = pd.concat([dev_y2, dev_y11], axis = 0)
            test_y2 = pd.concat([test_y2, test_y11], axis = 0)


        df_train = pd.concat([df_train_mean, df_train_stdev], axis = 1)
        df_dev = pd.concat([df_dev_mean, df_dev_stdev], axis = 1)
        df_test = pd.concat([df_test_mean, df_test_stdev], axis = 1)
        
    elif(idx == 2):
        df_train = df_train1
        df_dev = df_dev1
        df_test = df_test1
        return df_train, df_dev, df_test
    
    elif(idx == 3): #COMPUTE z-score
        df_train_z = pd.DataFrame()
        df_test_z = pd.DataFrame()
        df_dev_z = pd.DataFrame()
        for i in range(15):
            df_train_z1 = pd.DataFrame()
            df_dev_z1 = pd.DataFrame()
            df_test_z1 = pd.DataFrame()

            index1 = i*1120
            index2 = (i+1)*1120

            d_train = df_train1.values[:, i*1120:(i+1)*1120]
            d_dev = df_dev1.values[:, i*1120:(i+1)*1120]
            d_test = df_test1.values[:, i*1120:(i+1)*1120] 

            df_train_z1 = pd.DataFrame(stats.zscore(d_train, axis = 1))
            df_dev_z1 = pd.DataFrame(stats.zscore(d_dev, axis = 1))
            df_test_z1 = pd.DataFrame(stats.zscore(d_test, axis = 1))

            df_train_z1.columns = [''] * len(df_train_z1.columns)
            df_dev_z1.columns = [''] * len(df_dev_z1.columns)
            df_test_z1.columns = [''] * len(df_test_z1.columns)

        #     df_train_z1 = df_train_z1.reset_indext_index()
            df_train_z = pd.concat([df_train_z, df_train_z1], axis = 1)
            df_dev_z = pd.concat([df_dev_z, df_dev_z1], axis = 1)
            df_test_z = pd.concat([df_test_z, df_test_z1], axis = 1)
            
        return df_train_z, df_dev_z, df_test_z
    
    elif(idx == 4): #COMPUTE z-score
        df_train_z = pd.DataFrame()
        df_test_z = pd.DataFrame()
        df_dev_z = pd.DataFrame()
        df_train_z = pd.DataFrame(stats.zscore(df_train1, axis = 1))
        df_dev_z = pd.DataFrame(stats.zscore(df_dev1, axis = 1))
        df_test_z = pd.DataFrame(stats.zscore(df_test1, axis = 1))
            
        return df_train_z, df_dev_z, df_test_z
    
def compute_spectogram(df):
    df_1 = np.zeros([np.shape(df)[0], 129, 4])
    for i in range(15):
        fs = 160
        f, t, data = spectrogram(df.values[:, 1120*i:(i+1)*1120], fs, axis = 1)
        df_1 = np.concatenate([df_1, 10*np.log10(data)], axis = 1)
        data = []
    return df_1[:, 129:, :],t, f

# %% [markdown]
# # Compute z-score

# %%
# # run FUNCTIONS at the end of the notebook
# idx = 3
# df_train11, df_dev11, df_test11 = get_data(idx, df_train1, df_dev1, df_test1)
# train_y1 = train_y11
# dev_y1 = dev_y11
# test_y1 = test_y1

# %% [markdown]
# # Compute z-score per trial

# %%
# # run FUNCTIONS at the end of the notebook
# idx = 4
# df_train11, df_dev11, df_test11 = get_data(idx, df_train1, df_dev1, df_test1)
# train_y1 = train_y11
# dev_y1 = dev_y11
# test_y1 = test_y11

# %% [markdown]
# # Compute spectogram

# %%
from numpy import newaxis

def compute_spectogram(df):
    df_1 = np.zeros([np.shape(df)[0], 1, 129, 4])
    for i in range(15):
        fs = 160
        f, t, data = spectrogram(df.values[:, 1120*i:(i+1)*1120], fs, axis = 1)
        data1 = data[:, newaxis, ...]
#         d = 10*np.log10(data1)
        df_1 = np.concatenate([df_1, data1], axis = 1)
        data = []
#         print(np.shape(df_1))
    return df_1[:, 1:, :, :],t, f

df_train3, t, f = compute_spectogram(df_train1)
train_y1 = train_y11
print(np.shape(df_train3))

df_dev3, t, f = compute_spectogram(df_dev1)
dev_y1 = dev_y11
print(np.shape(df_dev3))
df_test3, t, f = compute_spectogram(df_test1)
test_y1 = test_y1
print(np.shape(df_test3))
# Out:
# <ipython-input-25-b615dc563606>:9: RuntimeWarning: divide by zero encountered in log10
#   d = 10*np.log10(data1)
# (4032, 15, 129, 4)
# (576, 15, 129, 4)
# (1152, 15, 129, 4)

# %%
shape = np.shape(df_train3)
df_train = np.reshape(df_train3, (shape[0], shape[1], shape[2]*shape[3]))

shape = np.shape(df_dev3)
df_dev = np.reshape(df_dev3, (shape[0], shape[1], shape[2]*shape[3]))


shape = np.shape(df_test3)
df_test = np.reshape(df_test3, (shape[0], shape[1], shape[2]*shape[3]))

# %% [markdown]
# # Create Tensor from labels and data

# %%
# from numpy import newaxis
# sh = np.shape(df_train11)
# a = df_train11.values[:]
# df_train = df_train11.values[:, newaxis, :]
# df_dev = df_dev11.values[:,newaxis, :]
# df_test = df_test11.values[:,newaxis, :]
# print(np.shape(df_train))

# channels_in = 15

# df_train = df_train.reshape(np.shape(df_train)[0], channels_in, np.int64(np.shape(df_train)[2]//channels_in))
# df_dev = df_dev.reshape(np.shape(df_dev)[0], channels_in, np.int64(np.shape(df_dev)[2]//channels_in))
# df_test = df_test.reshape(np.shape(df_test)[0], channels_in, np.int64(np.shape(df_test)[2]//channels_in))
# print(np.shape(df_train))
####


# df_train = df_train11.values[:, :, newaxis]
# df_dev = df_dev11.values[:, :,newaxis]
# df_test = df_test11.values[:, :,newaxis]

# df_train = df_train.reshape(np.shape(df_train)[0], np.int64(np.shape(df_train)[1]//channels_in), channels_in)
# df_dev = df_dev.reshape(np.shape(df_dev)[0], np.int64(np.shape(df_dev)[1]//channels_in), channels_in)
# df_test = df_test.reshape(np.shape(df_test)[0], np.int64(np.shape(df_test)[1]//channels_in), channels_in)
# print(np.shape(df_train))
# Out:
# (4032, 1, 16800)
# (4032, 15, 1120)

# %%
# Create tensor from labels
# Transform labels in the format 1_9 to binary
train_y3 = pd.DataFrame(np.floor(train_y1.values[:].astype('float64')/10))
dev_y3 = pd.DataFrame(np.floor(dev_y1.values[:].astype('float64')/10))

train_y = torch.FloatTensor(train_y3.values[:])
dev_y = torch.FloatTensor(dev_y3.values[:])
test_y = torch.FloatTensor(test_y1.values[:])

train_x	= torch.FloatTensor(df_train.astype('float64'))
dev_x = torch.FloatTensor(df_dev.astype('float64'))
test_x = torch.FloatTensor(df_test.astype('float64'))

# %%
print(np.shape(train_x))
print(np.shape(train_y))

print(np.shape(dev_x))
print(np.shape(dev_y))

print(np.shape(test_x))
print(np.shape(test_y))
# Out:
# torch.Size([4032, 15, 516])
# torch.Size([4032, 1])
# torch.Size([576, 15, 516])
# torch.Size([576, 1])
# torch.Size([1152, 15, 516])
# torch.Size([1152, 1])

# %%
# from torch.nn import Conv2d, functional as F, Linear, MaxPool2d, Module

# class ConvLayerNet4(torch.nn.Module):

#     def __init__(self,  channels_in, channels_out, D_in, H, D_out, device, drop=0.0, kernel_size=1, stride=1):
#         super(ConvLayerNet4, self).__init__()
        
#         self.device = device
        
#         self.convs = nn.ModuleList([
#             nn.Conv2d(1, channels_out, kernel_size=kernel_size, stride=stride)
#         for i in range(15)])
        
#         W_out = ((D_in - kernel_size)//stride + 1)*channels_out
        
#         self.pool = MaxPool2d(kernel_size=2, stride=2, padding=0)
        
#         self.linear1_1 = torch.nn.Linear(H3, 64)
#         self.linear2 = torch.nn.Linear(64, D_out)
        
#         self.fc1 = Linear(18 * 16 * 16, 64)
#         self.fc2 = Linear(64, 1)

#     def forward(self, x):
#         ii = 0
#         h_relu = torch.FloatTensor([]).to(self.device)
#         for layers in self.convs:
#             print(np.shape(torch.unsqueeze(x[:, ii, :, :], 1)))
#             x_data = layers(torch.unsqueeze(x[:, ii, :, :], 1)) # torch.unsqueeze(x[:, ii, :, :], 1
#             print(np.shape(x_data))
#             x_data = self.relu(x_data)
#             b, h, w = x_data.size()
#             x_data = x_data.view(b,-1)
#             h_relu = torch.cat([h_relu, x_data], axis = 1)
#             ii = ii+1
            
#         x = F.relu(self.conv(x))
#         x = self.pool(x)
#         x = x.view(-1, 18 * 16 * 16)
#         x = F.relu(self.fc1(x))
#         x = self.fc2(x)
#         return x

# %%
# print(np.shape(train_x))
# print(D_in)
# W_out = ((D_in - kernel_size)//stride + 1)*channels_out
# print(W_out)
# #         W_out = ((W_out - kernel_size)//stride + 1)*channels_out
# W_out = ((W_out - kernel_size)//stride + 1)*15*channels_out
# W_out = np.int64(W_out) 

# print(W_out)

# %% [markdown]
# # Define the hyperparameters of the model

# %%
print('Started training')
seed = 777
torch.manual_seed(seed)

#################
# choose the gpu
gpu_id = 5
device = torch.device("cuda:" + str(gpu_id))
# device = torch.device("cpu")
print(device)

#################
# Input and output sizes
D_in = np.shape(train_x)[2]
channels_in = 1
channels_out = 1

D_out = 1

#################
# Choose the hidden layer, drop, batch_size, num_epochs, learning_rate
# H = 512  #hidden layer size

drop = 0.5
H1 = [1024, 512, 256, 128]#, 2048,1024, 512
N1 = [8, 16, 32, 64]
epochs = 100
learning_rate = 1e-3
kernel_size = 3
stride  = 2

# loss_fn = torch.nn.BCELoss()BCEWithLogitsLoss
# N = batch_size

best_epoch = 0
dev_acc_max=0
epoch_max=0
loss_list     = np.zeros((epochs,))
accuracy_list = np.zeros((epochs,))
# Out:
# Started training
# cuda:5

# %%
D_in
# Out:
# 516

# %%
# class ConvLayerNet3(torch.nn.Module):
#     def __init__(self,  channels_in, channels_out, D_in, H, D_out, device, drop=0.0, kernel_size=1, stride=1):
#         super(ConvLayerNet3, self).__init__()
#         self.device = device
# #         self.convs = nn.ModuleList([nn.Conv1d(1, channels_out, kernel_size=kernel_size, stride=stride) for i in range(15)])
#         self.convs = nn.ModuleList([nn.Sequential(
#             nn.Conv1d(1, channels_out, kernel_size=kernel_size, stride=stride),
#             nn.Conv1d(1, channels_out, kernel_size=kernel_size, stride=stride),
# #             nn.Conv1d(1, channels_out, kernel_size=kernel_size, stride=stride),
#         ) for i in range(15)])
                                    
#         W_out = ((D_in - kernel_size)//stride + 1)*channels_out
# #         W_out = ((W_out - kernel_size)//stride + 1)*channels_out
#         W_out = ((W_out - kernel_size)//stride + 1)*15*channels_out
#         W_out = np.int64(W_out) 
#         print(W_out)
        
#         self.linear1_1 = torch.nn.Linear(W_out, H)
#         self.linear1_2 = torch.nn.Linear(H, 32)
# #         self.linear1_3 = torch.nn.Linear(H3, 64)
#         self.linear2 = torch.nn.Linear(32, D_out)
        
#         self.relu = torch.nn.ReLU()
#         self.drop1   = torch.nn.Dropout(p=drop)
#         self.sigmoid = torch.nn.Sigmoid()
# #         self.softmax = torch.nn.Softmax(dim=1)

#     def forward(self, x):
#         ii = 0
#         h_relu = torch.FloatTensor([]).to(self.device)
#         for layers in self.convs:
#             x_data = layers(torch.unsqueeze(x[:, ii, :],1))
# #             print(np.shape(x_data))
#             x_data = self.relu(x_data)
#             b, h, w = x_data.size()
#             x_data = x_data.view(b,-1)
#             print(np.shape(x_data))
#             h_relu = torch.cat([h_relu, x_data], axis = 1)
#             ii = ii+1
        
#         h_relu = self.drop1(self.linear1_1(h_relu))#.clamp(min=0)#.clamp(min=0)
#         h_relu = self.relu(h_relu)
        
#         h_relu = self.drop1(self.linear1_2(h_relu))#.clamp(min=0)#.clamp(min=0)
#         h_relu = self.relu(h_relu)
        
# #         h_relu = self.drop1(self.linear1_3(h_relu))#.clamp(min=0)#.clamp(min=0)
# #         h_relu = self.relu(h_relu)
        
#         y_pred = self.sigmoid(self.linear2(h_relu))
        
#         return y_pred
class ConvLayerNet3(torch.nn.Module):
    def __init__(self,  channels_in, channels_out, D_in, H, D_out, device, drop=0.0, kernel_size=1, stride=1):
        super(ConvLayerNet3, self).__init__()
        self.device = device
#         self.convs = nn.ModuleList([nn.Conv1d(1, channels_out, kernel_size=kernel_size, stride=stride) for i in range(15)])
        self.convs = nn.ModuleList([nn.Sequential(
            nn.Conv1d(1, channels_out, kernel_size=kernel_size, stride=stride),
            nn.Conv1d(1, channels_out, kernel_size=kernel_size, stride=stride),
#             nn.Conv1d(1, channels_out, kernel_size=kernel_size, stride=stride),
        ) for i in range(15)])
                                    
        W_out = ((D_in - kernel_size)//stride + 1)*channels_out
#         W_out = ((W_out - kernel_size)//stride + 1)*channels_out
        W_out = ((W_out - kernel_size)//stride + 1)*15*channels_out
        W_out = np.int64(W_out) 
        H3 = H//2
        print(W_out)
        self.linear1_1 = torch.nn.Linear(W_out, H)
        self.linear1_2 = torch.nn.Linear(H, 32)
#         self.linear1_3 = torch.nn.Linear(H3, 64)
#         self.linear1_4 = torch.nn.Linear(64, 16)
        self.linear2 = torch.nn.Linear(32, D_out)
        
        self.relu = torch.nn.ReLU()
        self.drop1   = torch.nn.Dropout(p=drop)
        self.sigmoid = torch.nn.Sigmoid()
#         self.softmax = torch.nn.Softmax(dim=1)

    def forward(self, x):
        ii = 0
        h_relu = torch.FloatTensor([]).to(self.device)
        for layers in self.convs:
            x_data = layers(torch.unsqueeze(x[:, ii, :],1))
            x_data = self.relu(x_data)
            b, h, w = x_data.size()
            x_data = x_data.view(b,-1)
            h_relu = torch.cat([h_relu, x_data], axis = 1)
            ii = ii+1
        
        h_relu = self.drop1(self.linear1_1(h_relu))#.clamp(min=0)#.clamp(min=0)
        h_relu = self.relu(h_relu)
        
        h_relu = self.drop1(self.linear1_2(h_relu))#.clamp(min=0)#.clamp(min=0)
        h_relu = self.relu(h_relu)
        
#         h_relu = self.drop1(self.linear1_3(h_relu))#.clamp(min=0)#.clamp(min=0)
#         h_relu = self.relu(h_relu)
        
#         h_relu = self.drop1(self.linear1_4(h_relu))#.clamp(min=0)#.clamp(min=0)
#         h_relu = self.relu(h_relu)
        
        y_pred = self.sigmoid(self.linear2(h_relu))#
        
        return y_pred

# %%
for N in N1:
    for H in H1:
    #         H = 512
    #         H2 = 256
#         epochs  =1
        directory = '/raid/togzhan_syrymova/lump_project/models/'

        model = ConvLayerNet3(channels_in, channels_out, D_in, H, D_out, device, drop, kernel_size, stride).to(device)
        model_name = type(model).__name__

        model_name += '_pressure_' + 'conv2_' + 'epochs_' \
        + str(epochs) + '_bs_' + str(N)+ '_H_' + str(H) \
        + '_drop_' + str(drop) \
        + '_ks_' + str(kernel_size) + '_stride_' + str(stride) + '_spect_1d'
        model_path = directory + model_name

        optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
        loss_fn = torch.nn.BCELoss()#BCELoss()
        print(model_name)
        print(model_path)
        print(model)

        # for H in H1:
        #     for N in N1:
        print(H)
        print(N)
        for e in range(epochs):
            total_loss = 0
            for i in range(0, train_x.shape[0], N):
                if i+N >= train_x.shape[0]:
                    x = train_x[i:]
                    y = train_y[i:]
                else:
                    x = train_x[i:i+N]
                    y = train_y[i:i+N]
                y_pred = model(x.to(device))
                loss = loss_fn(y_pred, y.to(device))
        #         loss_list[e] = loss.item()
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                total_loss += loss.item()
            print("Epoch {}/{}, Train Loss: {:.3f}".format(e+1, epochs, total_loss))
            #pdb.set_trace()
            #Loss and accuracy on dev data
            with torch.no_grad():
                model.eval()
                output = model(dev_x.to(device))
                output = (output>0.5).float()
                acc    = accuracy_score(dev_y, output.cpu())
        #         accuracy_list[e] = acc
                if acc > dev_acc_max:
                    dev_acc_max=acc
                    epoch_max=e+1
                    torch.save(model, model_path)
              #correct = (output == dev_y.to(device)).float().sum()
    #             model.train()
                torch.save(model, model_path+'_last')
            print("Dev Accuracy: {:.3f}".format(acc))

        print("##############################################")
        print("Best dev accuracy is {:.3f} at epoch {}".format(dev_acc_max, epoch_max))
        print("Number of class 1 samples: ", (dev_y>0.5).float().sum().item())
        print("##############################################")

        ####################################################################################################
        #Evaluation
        ####################################################################################################
        with torch.no_grad():
        #             pdb.set_trace()
            model = torch.load(model_path)
            model.eval().to(device)
            output = model(test_x.to(device))
            output = (output>0.5).float()
            acc    = accuracy_score(test_y, output.cpu())
            print("Test Accuracy: {:.3f}".format(acc))
            print(model)

        with torch.no_grad():
        #             pdb.set_trace()
            model = torch.load(model_path+'_last')
            model.eval().to(device)
            output = model(test_x.to(device))
            output = (output>0.5).float()
            acc    = accuracy_score(test_y, output.cpu())
            print("Test Accuracy Last: {:.3f}".format(acc))
            print(model)
exit()
# Out:
# 1920
# ConvLayerNet3_pressure_conv2_epochs_100_bs_8_H_1024_drop_0.3_ks_3_stride_2_spect_1d
# /raid/togzhan_syrymova/lump_project/models/ConvLayerNet3_pressure_conv2_epochs_100_bs_8_H_1024_drop_0.3_ks_3_stride_2_spect_1d
# ConvLayerNet3(
#   (convs): ModuleList(
#     (0): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (1): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (2): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (3): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (4): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (5): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (6): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (7): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (8): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (9): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (10): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (11): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (12): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (13): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (14): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#   )
#   (linear1_1): Linear(in_features=1920, out_features=1024, bias=True)
#   (linear1_2): Linear(in_features=1024, out_features=32, bias=True)
#   (linear2): Linear(in_features=32, out_features=1, bias=True)
#   (relu): ReLU()
#   (drop1): Dropout(p=0.3, inplace=False)
#   (sigmoid): Sigmoid()
# )
# 1024
# 8
# Epoch 1/100, Train Loss: 475.464
# Dev Accuracy: 0.550
# Epoch 2/100, Train Loss: 306.181
# Dev Accuracy: 0.637
# Epoch 3/100, Train Loss: 277.092
# Dev Accuracy: 0.675
# Epoch 4/100, Train Loss: 260.646
# Dev Accuracy: 0.693
# Epoch 5/100, Train Loss: 243.337
# Dev Accuracy: 0.708
# Epoch 6/100, Train Loss: 228.733
# Dev Accuracy: 0.736
# Epoch 7/100, Train Loss: 214.706
# Dev Accuracy: 0.766
# Epoch 8/100, Train Loss: 205.172
# Dev Accuracy: 0.767
# Epoch 9/100, Train Loss: 196.194
# Dev Accuracy: 0.757
# Epoch 10/100, Train Loss: 187.458
# Dev Accuracy: 0.785
# Epoch 11/100, Train Loss: 177.791
# Dev Accuracy: 0.785
# Epoch 12/100, Train Loss: 167.815
# Dev Accuracy: 0.780
# Epoch 13/100, Train Loss: 159.994
# Dev Accuracy: 0.795
# Epoch 14/100, Train Loss: 154.024
# Dev Accuracy: 0.799
# Epoch 15/100, Train Loss: 154.160
# Dev Accuracy: 0.800
# Epoch 16/100, Train Loss: 137.559
# Dev Accuracy: 0.797
# Epoch 17/100, Train Loss: 127.956
# Dev Accuracy: 0.804
# Epoch 18/100, Train Loss: 118.869
# Dev Accuracy: 0.812
# Epoch 19/100, Train Loss: 116.525
# Dev Accuracy: 0.825
# Epoch 20/100, Train Loss: 106.421
# Dev Accuracy: 0.819
# Epoch 21/100, Train Loss: 99.941
# Dev Accuracy: 0.832
# Epoch 22/100, Train Loss: 93.608
# Dev Accuracy: 0.828
# Epoch 23/100, Train Loss: 86.605
# Dev Accuracy: 0.842
# Epoch 24/100, Train Loss: 91.159
# Dev Accuracy: 0.828
# Epoch 25/100, Train Loss: 73.914
# Dev Accuracy: 0.844
# Epoch 26/100, Train Loss: 69.352
# Dev Accuracy: 0.858
# Epoch 27/100, Train Loss: 66.727
# Dev Accuracy: 0.858
# Epoch 28/100, Train Loss: 59.027
# Dev Accuracy: 0.859
# Epoch 29/100, Train Loss: 56.540
# Dev Accuracy: 0.847
# Epoch 30/100, Train Loss: 64.561
# Dev Accuracy: 0.844
# Epoch 31/100, Train Loss: 52.179
# Dev Accuracy: 0.839
# Epoch 32/100, Train Loss: 45.675
# Dev Accuracy: 0.859
# Epoch 33/100, Train Loss: 54.738
# Dev Accuracy: 0.839
# Epoch 34/100, Train Loss: 49.576
# Dev Accuracy: 0.865
# Epoch 35/100, Train Loss: 37.153
# Dev Accuracy: 0.854
# Epoch 36/100, Train Loss: 31.512
# Dev Accuracy: 0.858
# Epoch 37/100, Train Loss: 27.694
# Dev Accuracy: 0.856
# Epoch 38/100, Train Loss: 47.118
# Dev Accuracy: 0.842
# Epoch 39/100, Train Loss: 34.007
# Dev Accuracy: 0.840
# Epoch 40/100, Train Loss: 23.885
# Dev Accuracy: 0.832
# Epoch 41/100, Train Loss: 27.020
# Dev Accuracy: 0.819
# Epoch 42/100, Train Loss: 28.272
# Dev Accuracy: 0.872
# Epoch 43/100, Train Loss: 39.809
# Dev Accuracy: 0.851
# Epoch 44/100, Train Loss: 32.524
# Dev Accuracy: 0.845
# Epoch 45/100, Train Loss: 17.876
# Dev Accuracy: 0.854
# Epoch 46/100, Train Loss: 14.292
# Dev Accuracy: 0.845
# Epoch 47/100, Train Loss: 12.260
# Dev Accuracy: 0.842
# Epoch 48/100, Train Loss: 10.045
# Dev Accuracy: 0.840
# Epoch 49/100, Train Loss: 18.299
# Dev Accuracy: 0.851
# Epoch 50/100, Train Loss: 31.804
# Dev Accuracy: 0.845
# Epoch 51/100, Train Loss: 17.990
# Dev Accuracy: 0.849
# Epoch 52/100, Train Loss: 33.532
# Dev Accuracy: 0.851
# Epoch 53/100, Train Loss: 26.258
# Dev Accuracy: 0.865
# Epoch 54/100, Train Loss: 10.744
# Dev Accuracy: 0.856
# Epoch 55/100, Train Loss: 7.045
# Dev Accuracy: 0.859
# Epoch 56/100, Train Loss: 6.517
# Dev Accuracy: 0.856
# Epoch 57/100, Train Loss: 5.174
# Dev Accuracy: 0.854
# Epoch 58/100, Train Loss: 4.354
# Dev Accuracy: 0.861
# Epoch 59/100, Train Loss: 58.009
# Dev Accuracy: 0.872
# Epoch 60/100, Train Loss: 22.896
# Dev Accuracy: 0.865
# Epoch 61/100, Train Loss: 16.899
# Dev Accuracy: 0.861
# Epoch 62/100, Train Loss: 6.500
# Dev Accuracy: 0.873
# Epoch 63/100, Train Loss: 4.885
# Dev Accuracy: 0.873
# Epoch 64/100, Train Loss: 3.768
# Dev Accuracy: 0.884
# Epoch 65/100, Train Loss: 3.055
# Dev Accuracy: 0.877
# Epoch 66/100, Train Loss: 2.220
# Dev Accuracy: 0.878
# Epoch 67/100, Train Loss: 1.776
# Dev Accuracy: 0.877
# Epoch 68/100, Train Loss: 12.087
# Dev Accuracy: 0.870
# Epoch 69/100, Train Loss: 46.366
# Dev Accuracy: 0.861
# Epoch 70/100, Train Loss: 17.204
# Dev Accuracy: 0.837
# Epoch 71/100, Train Loss: 17.747
# Dev Accuracy: 0.884
# Epoch 72/100, Train Loss: 6.298
# Dev Accuracy: 0.872
# Epoch 73/100, Train Loss: 3.749
# Dev Accuracy: 0.875
# Epoch 74/100, Train Loss: 6.330
# Dev Accuracy: 0.863
# Epoch 75/100, Train Loss: 7.445
# Dev Accuracy: 0.863
# Epoch 76/100, Train Loss: 16.788
# Dev Accuracy: 0.863
# Epoch 77/100, Train Loss: 12.343
# Dev Accuracy: 0.866
# Epoch 78/100, Train Loss: 3.224
# Dev Accuracy: 0.875
# Epoch 79/100, Train Loss: 2.082
# Dev Accuracy: 0.870
# Epoch 80/100, Train Loss: 1.307
# Dev Accuracy: 0.878
# Epoch 81/100, Train Loss: 1.668
# Dev Accuracy: 0.868
# Epoch 82/100, Train Loss: 32.500
# Dev Accuracy: 0.858
# Epoch 83/100, Train Loss: 15.742
# Dev Accuracy: 0.866
# Epoch 84/100, Train Loss: 6.623
# Dev Accuracy: 0.877
# Epoch 85/100, Train Loss: 14.001
# Dev Accuracy: 0.870
# Epoch 86/100, Train Loss: 6.028
# Dev Accuracy: 0.870
# Epoch 87/100, Train Loss: 3.462
# Dev Accuracy: 0.880
# Epoch 88/100, Train Loss: 1.386
# Dev Accuracy: 0.878
# Epoch 89/100, Train Loss: 1.031
# Dev Accuracy: 0.878
# Epoch 90/100, Train Loss: 0.993
# Dev Accuracy: 0.880
# Epoch 91/100, Train Loss: 19.855
# Dev Accuracy: 0.863
# Epoch 92/100, Train Loss: 11.684
# Dev Accuracy: 0.878
# Epoch 93/100, Train Loss: 4.219
# Dev Accuracy: 0.870
# Epoch 94/100, Train Loss: 8.340
# Dev Accuracy: 0.865
# Epoch 95/100, Train Loss: 21.022
# Dev Accuracy: 0.854
# Epoch 96/100, Train Loss: 3.862
# Dev Accuracy: 0.865
# Epoch 97/100, Train Loss: 1.639
# Dev Accuracy: 0.872
# Epoch 98/100, Train Loss: 1.119
# Dev Accuracy: 0.872
# Epoch 99/100, Train Loss: 0.962
# Dev Accuracy: 0.866
# Epoch 100/100, Train Loss: 1.191
# Dev Accuracy: 0.873
# ##############################################
# Best dev accuracy is 0.884 at epoch 64
# Number of class 1 samples:  288.0
# ##############################################
# Test Accuracy: 0.616
# ConvLayerNet3(
#   (convs): ModuleList(
#     (0): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (1): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (2): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (3): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (4): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (5): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (6): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (7): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (8): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (9): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (10): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (11): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (12): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (13): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (14): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#   )
#   (linear1_1): Linear(in_features=1920, out_features=1024, bias=True)
#   (linear1_2): Linear(in_features=1024, out_features=32, bias=True)
#   (linear2): Linear(in_features=32, out_features=1, bias=True)
#   (relu): ReLU()
#   (drop1): Dropout(p=0.3, inplace=False)
#   (sigmoid): Sigmoid()
# )
# Test Accuracy Last: 0.601
# ConvLayerNet3(
#   (convs): ModuleList(
#     (0): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (1): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (2): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (3): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (4): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (5): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (6): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (7): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (8): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (9): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (10): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (11): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (12): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (13): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (14): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#   )
#   (linear1_1): Linear(in_features=1920, out_features=1024, bias=True)
#   (linear1_2): Linear(in_features=1024, out_features=32, bias=True)
#   (linear2): Linear(in_features=32, out_features=1, bias=True)
#   (relu): ReLU()
#   (drop1): Dropout(p=0.3, inplace=False)
#   (sigmoid): Sigmoid()
# )
# 1920
# ConvLayerNet3_pressure_conv2_epochs_100_bs_8_H_512_drop_0.3_ks_3_stride_2_spect_1d
# /raid/togzhan_syrymova/lump_project/models/ConvLayerNet3_pressure_conv2_epochs_100_bs_8_H_512_drop_0.3_ks_3_stride_2_spect_1d
# ConvLayerNet3(
#   (convs): ModuleList(
#     (0): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (1): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (2): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (3): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (4): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (5): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (6): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (7): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (8): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (9): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (10): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (11): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (12): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (13): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#     (14): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(3,), stride=(2,))
#     )
#   )
#   (linear1_1): Linear(in_features=1920, out_features=512, bias=True)
#   (linear1_2): Linear(in_features=512, out_features=32, bias=True)
#   (linear2): Linear(in_features=32, out_features=1, bias=True)
#   (relu): ReLU()
#   (drop1): Dropout(p=0.3, inplace=False)
#   (sigmoid): Sigmoid()
# )
# 512
# 8
# Epoch 1/100, Train Loss: 322.110
# Dev Accuracy: 0.658
# Epoch 2/100, Train Loss: 272.181
# Dev Accuracy: 0.693
# Epoch 3/100, Train Loss: 253.790
# Dev Accuracy: 0.705
# Epoch 4/100, Train Loss: 241.501
# Dev Accuracy: 0.710
# Epoch 5/100, Train Loss: 231.205
# Dev Accuracy: 0.724
# Epoch 6/100, Train Loss: 220.582
# Dev Accuracy: 0.727
# Epoch 7/100, Train Loss: 213.108
# Dev Accuracy: 0.736
# Epoch 8/100, Train Loss: 204.973
# Dev Accuracy: 0.745
# Epoch 9/100, Train Loss: 197.939
# Dev Accuracy: 0.740
# Epoch 10/100, Train Loss: 190.013
# Dev Accuracy: 0.734
# Epoch 11/100, Train Loss: 182.335
# Dev Accuracy: 0.731
# Epoch 12/100, Train Loss: 175.961
# Dev Accuracy: 0.733
# Epoch 13/100, Train Loss: 167.706
# Dev Accuracy: 0.740
# Epoch 14/100, Train Loss: 159.395
# Dev Accuracy: 0.731
# Epoch 15/100, Train Loss: 152.962
# Dev Accuracy: 0.743
# Epoch 16/100, Train Loss: 144.195
# Dev Accuracy: 0.745
# Epoch 17/100, Train Loss: 136.010
# Dev Accuracy: 0.753
# Epoch 18/100, Train Loss: 130.799
# Dev Accuracy: 0.750
# Epoch 19/100, Train Loss: 123.055
# Dev Accuracy: 0.753
# Epoch 20/100, Train Loss: 115.490
# Dev Accuracy: 0.747
# Epoch 21/100, Train Loss: 108.636
# Dev Accuracy: 0.762
# Epoch 22/100, Train Loss: 102.147
# Dev Accuracy: 0.769
# Epoch 23/100, Train Loss: 97.423
# Dev Accuracy: 0.766
# Epoch 24/100, Train Loss: 90.270
# Dev Accuracy: 0.771
# Epoch 25/100, Train Loss: 83.324
# Dev Accuracy: 0.776
# Epoch 26/100, Train Loss: 76.332
# Dev Accuracy: 0.767
# Epoch 27/100, Train Loss: 73.713
# Dev Accuracy: 0.778
# Epoch 28/100, Train Loss: 72.383
# Dev Accuracy: 0.776
# Epoch 29/100, Train Loss: 74.246
# Dev Accuracy: 0.781
# Epoch 30/100, Train Loss: 62.786
# Dev Accuracy: 0.776
# Epoch 31/100, Train Loss: 58.023
# Dev Accuracy: 0.788
# Epoch 32/100, Train Loss: 49.493
# Dev Accuracy: 0.790
# Epoch 33/100, Train Loss: 44.832
# Dev Accuracy: 0.792
# Epoch 34/100, Train Loss: 42.023
# Dev Accuracy: 0.786
# Epoch 35/100, Train Loss: 41.657
# Dev Accuracy: 0.783
# Epoch 36/100, Train Loss: 60.124
# Dev Accuracy: 0.773
# Epoch 37/100, Train Loss: 59.026
# Dev Accuracy: 0.769
# Epoch 38/100, Train Loss: 46.431
# Dev Accuracy: 0.788
# Epoch 39/100, Train Loss: 39.694
# Dev Accuracy: 0.786
# Epoch 40/100, Train Loss: 27.678
# Dev Accuracy: 0.790
# Epoch 41/100, Train Loss: 25.740
# Dev Accuracy: 0.790
# Epoch 42/100, Train Loss: 22.857
# Dev Accuracy: 0.785
# Epoch 43/100, Train Loss: 20.576
# Dev Accuracy: 0.783
# Epoch 44/100, Train Loss: 18.468
# Dev Accuracy: 0.790
# Epoch 45/100, Train Loss: 22.154
# Dev Accuracy: 0.804
# Epoch 46/100, Train Loss: 63.249
# Dev Accuracy: 0.807
# Epoch 47/100, Train Loss: 35.703
# Dev Accuracy: 0.806
# Epoch 48/100, Train Loss: 18.306
# Dev Accuracy: 0.799
# Epoch 49/100, Train Loss: 15.474
# Dev Accuracy: 0.799
# Epoch 50/100, Train Loss: 12.674
# Dev Accuracy: 0.804
# Epoch 51/100, Train Loss: 21.751
# Dev Accuracy: 0.809
# Epoch 52/100, Train Loss: 32.731
# Dev Accuracy: 0.807
# Epoch 53/100, Train Loss: 25.163
# Dev Accuracy: 0.793
# Epoch 54/100, Train Loss: 14.640
# Dev Accuracy: 0.797
# Epoch 55/100, Train Loss: 10.359
# Dev Accuracy: 0.795
# Epoch 56/100, Train Loss: 8.992
# Dev Accuracy: 0.788
# Epoch 57/100, Train Loss: 7.968
# Dev Accuracy: 0.792
# Epoch 58/100, Train Loss: 7.499
# Dev Accuracy: 0.786
# Epoch 59/100, Train Loss: 7.060
# Dev Accuracy: 0.795
# Epoch 60/100, Train Loss: 54.483
# Dev Accuracy: 0.802
# Epoch 61/100, Train Loss: 23.167
# Dev Accuracy: 0.795
# Epoch 62/100, Train Loss: 9.431
# Dev Accuracy: 0.795
# Epoch 63/100, Train Loss: 7.568
# Dev Accuracy: 0.797
# Epoch 64/100, Train Loss: 5.878
# Dev Accuracy: 0.793
# Epoch 65/100, Train Loss: 14.720
# Dev Accuracy: 0.800
# Epoch 66/100, Train Loss: 6.257
# Dev Accuracy: 0.802
# Epoch 67/100, Train Loss: 8.797
# Dev Accuracy: 0.797
# Epoch 68/100, Train Loss: 14.128
# Dev Accuracy: 0.793
# Epoch 69/100, Train Loss: 35.767
# Dev Accuracy: 0.800
# Epoch 70/100, Train Loss: 12.191
# Dev Accuracy: 0.809
# Epoch 71/100, Train Loss: 7.435
# Dev Accuracy: 0.792
# Epoch 72/100, Train Loss: 10.612
# Dev Accuracy: 0.797
# Epoch 73/100, Train Loss: 4.333
# Dev Accuracy: 0.797
# Epoch 74/100, Train Loss: 3.381
# Dev Accuracy: 0.802

# %%
exit()
