# %%
#!/usr/bin/python
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import os
import glob
# from model import *
# from functions import *
import pdb
import scipy.stats as stats

# %% [markdown]
# # Go to the directory and print the *.csv files

# %%
directory = '/raid/togzhan_syrymova/lump_project/data/'
os.chdir(directory)
# glob.glob('*.csv')

# %% [markdown]
# # Load the datasets

# %%
directory = '/raid/togzhan_syrymova/lump_project/data/'
os.chdir(directory)
csv_files_train = glob.glob('df_train*raw*8.csv')
csv_files_test = glob.glob('test*raw*.csv')
csv_files_dev = glob.glob('df_dev*raw*8.csv')

index = 0

df_train_ = pd.read_csv(csv_files_train[index], sep = ',', header = None)
df_train_ = pd.DataFrame(df_train_.values[1:,:])

df_test1 = pd.read_csv(csv_files_test[index], sep = ',', header = None)
df_test2 = pd.read_csv(csv_files_test[index+1], sep = ',', header = None)
df_test_ = pd.concat([df_test1, df_test2], axis = 1)
df_test_ = df_test_.transpose()

df_dev_ = pd.read_csv(csv_files_dev[index], sep = ',', header = None)
df_dev_ = pd.DataFrame(df_dev_.values[1:,:])


print(csv_files_train, '\n')
print(csv_files_test, '\n')
print(csv_files_dev, '\n')

print(csv_files_train[index], '\n')
print(csv_files_test[index], '\n')
print(csv_files_dev[index], '\n')
# Out:
# ['df_train_raw_8.csv']
#
# ['test_pressure_data_without_raw.csv', 'test_pressure_data_with_raw.csv']
#
# ['df_dev_raw_8.csv']
#
# df_train_raw_8.csv
#
# test_pressure_data_without_raw.csv
#
# df_dev_raw_8.csv

# %% [markdown]
# # Get labels and data separately

# %%
# Train and dev labels
train_y11 = pd.DataFrame((df_train_.values[:,-1].astype('float64')))
dev_y11 = pd.DataFrame((df_dev_.values[:,-1].astype('float64')))

# Create test labels
test_y11 = pd.concat([ pd.DataFrame([0 for i in range(2*32*9)]), pd.DataFrame([1 for i in range(2*32*9)])], axis=0)
test_y11 = test_y11.reset_index(drop=True)


df_train1 = pd.DataFrame(df_train_.values[:,:-1].astype('float64'))
df_dev1 = pd.DataFrame(df_dev_.values[:,:-1].astype('float64'))
df_test1 = df_test_.astype('float64')

## SHUFFLE the TEST labels and data
test_y1, df_test1 = shuffle(test_y11.astype('float64'), df_test1)

# %%
def get_data(idx, df_train1, df_dev1, df_test1):
    df_train_mean = pd.DataFrame()
    df_train_stdev = pd.DataFrame()

    df_test_mean = pd.DataFrame()
    df_test_stdev = pd.DataFrame()

    df_dev_mean = pd.DataFrame()
    df_dev_stdev = pd.DataFrame()
    if (idx == 0):
        for i in range(15):
            df_train_mean = pd.concat([df_train_mean, pd.DataFrame(np.mean(df_train1.values[:, i*1120:(i+1)*1120], axis = 1))], axis = 1)
            df_train_stdev = pd.concat([df_train_stdev, pd.DataFrame(np.std(df_train1.values[:, i*1120:(i+1)*1120], axis = 1))], axis = 1)

            df_dev_mean = pd.concat([df_dev_mean, pd.DataFrame(np.mean(df_dev1.values[:, i*1120:(i+1)*1120], axis = 1))], axis = 1)
            df_dev_stdev = pd.concat([df_dev_stdev, pd.DataFrame(np.std(df_dev1.values[:, i*1120:(i+1)*1120], axis = 1))], axis = 1)

            df_test_mean = pd.concat([df_test_mean, pd.DataFrame(np.mean(df_test1.values[:, i*1120:(i+1)*1120], axis = 1))], axis = 1)
            df_test_stdev = pd.concat([df_test_stdev, pd.DataFrame(np.std(df_test1.values[:, i*1120:(i+1)*1120], axis = 1))], axis = 1)

        df_train = pd.concat([df_train_mean, df_train_stdev], axis = 1)
        df_dev = pd.concat([df_dev_mean, df_dev_stdev], axis = 1)
        df_test = pd.concat([df_test_mean, df_test_stdev], axis = 1)
        return df_train, df_dev, df_test
    
    elif (idx == 1):
        train_y2 = pd.DataFrame()
        dev_y2 = pd.DataFrame()
        test_y2 = pd.DataFrame()

        for j in range(7):
            df_train_mean_s = pd.DataFrame()
            df_train_stdev_s = pd.DataFrame()

            df_test_mean_s = pd.DataFrame()
            df_test_stdev_s = pd.DataFrame()

            df_dev_mean_s = pd.DataFrame()
            df_dev_stdev_s = pd.DataFrame()

            for i in range(15):
                index1 = i*1120+j*160
                index2 = i*1120+(j+1)*160
                df_train_mean_s = pd.concat([df_train_mean_s, pd.DataFrame(np.mean(df_train1.values[:, index1:index2], axis = 1))], axis = 1)
                df_train_stdev_s = pd.concat([df_train_stdev_s, pd.DataFrame(np.std(df_train1.values[:, index1:index2], axis = 1))], axis = 1)

                df_dev_mean_s = pd.concat([df_dev_mean_s, pd.DataFrame(np.mean(df_dev1.values[:, index1:index2], axis = 1))], axis = 1)
                df_dev_stdev_s = pd.concat([df_dev_stdev_s, pd.DataFrame(np.std(df_dev1.values[:, index1:index2], axis = 1))], axis = 1)

                df_test_mean_s = pd.concat([df_test_mean_s, pd.DataFrame(np.mean(df_test1.values[:, index1:index2], axis = 1))], axis = 1)
                df_test_stdev_s = pd.concat([df_test_stdev_s, pd.DataFrame(np.std(df_test1.values[:, index1:index2], axis = 1))], axis = 1)

            df_train_mean = pd.concat([df_train_mean, df_train_mean_s], axis = 0)
            df_train_stdev = pd.concat([df_train_stdev, df_train_stdev_s], axis = 0)

            df_test_mean = pd.concat([df_test_mean, df_test_mean_s], axis = 0)
            df_test_stdev = pd.concat([df_test_stdev, df_test_stdev_s], axis = 0)

            df_dev_mean = pd.concat([df_dev_mean, df_dev_mean_s], axis = 0)
            df_dev_stdev = pd.concat([df_dev_stdev, df_dev_stdev_s], axis = 0)

            # concat labels 7 times corresponding to 7 second
            train_y2 = pd.concat([train_y2, train_y11], axis = 0)
            dev_y2 = pd.concat([dev_y2, dev_y11], axis = 0)
            test_y2 = pd.concat([test_y2, test_y11], axis = 0)


        df_train = pd.concat([df_train_mean, df_train_stdev], axis = 1)
        df_dev = pd.concat([df_dev_mean, df_dev_stdev], axis = 1)
        df_test = pd.concat([df_test_mean, df_test_stdev], axis = 1)
        
    elif(idx == 2):
        df_train = df_train1
        df_dev = df_dev1
        df_test = df_test1
        return df_train, df_dev, df_test
    
    elif(idx == 3): #COMPUTE z-score
        df_train_z = pd.DataFrame()
        df_test_z = pd.DataFrame()
        df_dev_z = pd.DataFrame()
        for i in range(15):
            df_train_z1 = pd.DataFrame()
            df_dev_z1 = pd.DataFrame()
            df_test_z1 = pd.DataFrame()

            index1 = i*1120
            index2 = (i+1)*1120

            d_train = df_train1.values[:, i*1120:(i+1)*1120]
            d_dev = df_dev1.values[:, i*1120:(i+1)*1120]
            d_test = df_test1.values[:, i*1120:(i+1)*1120] 

            df_train_z1 = pd.DataFrame(stats.zscore(d_train, axis = 1))
            df_dev_z1 = pd.DataFrame(stats.zscore(d_dev, axis = 1))
            df_test_z1 = pd.DataFrame(stats.zscore(d_test, axis = 1))

            df_train_z1.columns = [''] * len(df_train_z1.columns)
            df_dev_z1.columns = [''] * len(df_dev_z1.columns)
            df_test_z1.columns = [''] * len(df_test_z1.columns)

        #     df_train_z1 = df_train_z1.reset_indext_index()
            df_train_z = pd.concat([df_train_z, df_train_z1], axis = 1)
            df_dev_z = pd.concat([df_dev_z, df_dev_z1], axis = 1)
            df_test_z = pd.concat([df_test_z, df_test_z1], axis = 1)
            
        return df_train_z, df_dev_z, df_test_z
    
    elif(idx == 4): #COMPUTE z-score
        df_train_z = pd.DataFrame()
        df_test_z = pd.DataFrame()
        df_dev_z = pd.DataFrame()
        df_train_z = pd.DataFrame(stats.zscore(df_train1, axis = 1))
        df_dev_z = pd.DataFrame(stats.zscore(df_dev1, axis = 1))
        df_test_z = pd.DataFrame(stats.zscore(df_test1, axis = 1))
            
        return df_train_z, df_dev_z, df_test_z

# %% [markdown]
# # Compute mean and stdev of the whole sequence per sensor for train/dev/test sets

# %%
# idx = 0
# df_train, df_dev, df_test = get_data(idx, df_train1, df_dev1, df_test1)

# %% [markdown]
# # Compute mean and stdev of the 1 sec of sequence per sensor for train/dev/test sets

# %%
# idx = 1
# df_train, train_y2, df_dev,dev_y2, df_test, test_y2 = get_data(idx, df_train1, df_dev1, df_test1)

# %% [markdown]
# # Run to take imported sequence with no changes

# %%
# idx = 2
# df_train, df_dev, df_test = get_data(idx, df_train1, df_dev1, df_test1)

# %% [markdown]
# # Compute z-score

# %%
# run FUNCTIONS at the end of the notebook
idx = 3
df_train11, df_dev11, df_test11 = get_data(idx, df_train1, df_dev1, df_test1)
train_y1 = train_y11
dev_y1 = dev_y11
test_y1 = test_y1

# %% [markdown]
# # Compute z-score per trial

# %%
# # run FUNCTIONS at the end of the notebook
# idx = 4
# df_train11, df_dev11, df_test11 = get_data(idx, df_train1, df_dev1, df_test1)
# train_y1 = train_y11
# dev_y1 = dev_y11
# test_y1 = test_y1

# %% [markdown]
# # Create Tensor from labels and data

# %%
from numpy import newaxis
sh = np.shape(df_train11)
a = df_train11.values[:]
df_train = df_train11.values[:, newaxis, :]
df_dev = df_dev11.values[:,newaxis, :]
df_test = df_test11.values[:,newaxis, :]
print(np.shape(df_train))

channels_in = 15

df_train = df_train.reshape(np.shape(df_train)[0], channels_in, np.int64(np.shape(df_train)[2]//channels_in))
df_dev = df_dev.reshape(np.shape(df_dev)[0], channels_in, np.int64(np.shape(df_dev)[2]//channels_in))
df_test = df_test.reshape(np.shape(df_test)[0], channels_in, np.int64(np.shape(df_test)[2]//channels_in))
print(np.shape(df_train))
####


# df_train = df_train11.values[:, :, newaxis]
# df_dev = df_dev11.values[:, :,newaxis]
# df_test = df_test11.values[:, :,newaxis]

# df_train = df_train.reshape(np.shape(df_train)[0], np.int64(np.shape(df_train)[1]//channels_in), channels_in)
# df_dev = df_dev.reshape(np.shape(df_dev)[0], np.int64(np.shape(df_dev)[1]//channels_in), channels_in)
# df_test = df_test.reshape(np.shape(df_test)[0], np.int64(np.shape(df_test)[1]//channels_in), channels_in)
# print(np.shape(df_train))
# Out:
# (4032, 1, 16800)
# (4032, 15, 1120)

# %%
# Create tensor from labels
# Transform labels in the format 1_9 to binary
train_y3 = pd.DataFrame(np.floor(train_y1.values[:].astype('float64')/10))
dev_y3 = pd.DataFrame(np.floor(dev_y1.values[:].astype('float64')/10))

train_y = torch.FloatTensor(train_y3.values[:])
dev_y = torch.FloatTensor(dev_y3.values[:])
test_y = torch.FloatTensor(test_y1.values[:])

train_x	= torch.FloatTensor(df_train.astype('float64'))
dev_x = torch.FloatTensor(df_dev.astype('float64'))
test_x = torch.FloatTensor(df_test.astype('float64'))

# %% [markdown]
# # Define the hyperparameters of the model

# %%
print('Started training')
seed = 777
torch.manual_seed(seed)

#################
# choose the gpu
gpu_id = 5
device = torch.device("cuda:" + str(gpu_id))
# device = torch.device("cpu")
print(device)

#################
# Input and output sizes
D_in = 1120 #np.shape(train_x)[2]
# channels_in = 1
channels_out = 1

D_out = 1

#################
# Choose the hidden layer, drop, batch_size, num_epochs, learning_rate
# H = 512  #hidden layer size

drop = 0.4
H1 = [512, 256, 128]#, 2048,512
N1 = [8, 16, 32, 64]
epochs = 100
learning_rate = 1e-4
kernel_size = 10
stride  = 3

# loss_fn = torch.nn.BCELoss()BCEWithLogitsLoss
# N = batch_size

best_epoch = 0
dev_acc_max=0
epoch_max=0
loss_list     = np.zeros((epochs,))
accuracy_list = np.zeros((epochs,))
# Out:
# Started training
# cuda:5

# %%
class ConvLayerNet3(torch.nn.Module):
    def __init__(self,  channels_in, channels_out, D_in, H, D_out, device, drop=0.0, kernel_size=1, stride=1):
        super(ConvLayerNet3, self).__init__()
        self.device = device
#         self.convs = nn.ModuleList([nn.Conv1d(1, channels_out, kernel_size=kernel_size, stride=stride) for i in range(15)])
        self.convs = nn.ModuleList([nn.Sequential(
            nn.Conv1d(1, channels_out, kernel_size=kernel_size, stride=stride),
            nn.Conv1d(1, channels_out, kernel_size=kernel_size, stride=stride),
            nn.Conv1d(1, channels_out, kernel_size=kernel_size, stride=stride),
        ) for i in range(15)])
                                    
        W_out = ((D_in - kernel_size)//stride + 1)*channels_out
        W_out = ((W_out - kernel_size)//stride + 1)*channels_out
        W_out = ((W_out - kernel_size)//stride + 1)*15*channels_out
        W_out = np.int64(W_out) 
        H3 = H//2
        self.linear1_1 = torch.nn.Linear(W_out, H)
        self.linear1_2 = torch.nn.Linear(H, 32)
#         self.linear1_3 = torch.nn.Linear(H3, 64)
#         self.linear1_4 = torch.nn.Linear(64, 16)
        self.linear2 = torch.nn.Linear(32, D_out)
        
        self.relu = torch.nn.ReLU()
        self.drop1   = torch.nn.Dropout(p=drop)
        self.sigmoid = torch.nn.Sigmoid()
#         self.softmax = torch.nn.Softmax(dim=1)

    def forward(self, x):
        ii = 0
        h_relu = torch.FloatTensor([]).to(self.device)
        for layers in self.convs:
            x_data = layers(torch.unsqueeze(x[:, ii, :],1))
            x_data = self.relu(x_data)
            b, h, w = x_data.size()
            x_data = x_data.view(b,-1)
            h_relu = torch.cat([h_relu, x_data], axis = 1)
            ii = ii+1
        
        h_relu = self.drop1(self.linear1_1(h_relu))#.clamp(min=0)#.clamp(min=0)
        h_relu = self.relu(h_relu)
        
        h_relu = self.drop1(self.linear1_2(h_relu))#.clamp(min=0)#.clamp(min=0)
        h_relu = self.relu(h_relu)
        
#         h_relu = self.drop1(self.linear1_3(h_relu))#.clamp(min=0)#.clamp(min=0)
#         h_relu = self.relu(h_relu)
        
#         h_relu = self.drop1(self.linear1_4(h_relu))#.clamp(min=0)#.clamp(min=0)
#         h_relu = self.relu(h_relu)
        
        y_pred = self.sigmoid(self.linear2(h_relu))
        
        return y_pred

# %%
for N in N1:
    for H in H1:
    #         H = 512
    #         H2 = 256
    #         H3 = 64
#         N = 32
        directory = '/raid/togzhan_syrymova/lump_project/models/'

        model = ConvLayerNet3(channels_in, channels_out, D_in, H, D_out, device, drop, kernel_size, stride).to(device)
        model_name = type(model).__name__

        model_name += '_pressure_' + 'conv3_FNN_2_' + 'epochs_' \
        + str(epochs) + '_bs_' + str(N)+ '_H_' + str(H) \
        + '_drop_' + str(drop) \
        + '_ks_' + str(kernel_size) + '_stride_' + str(stride) + '_whole_z_score'
        model_path = directory + model_name

        optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
        loss_fn = torch.nn.BCELoss()
        print(model_name)
        print(model_path)
        print(model)

        # for H in H1:
        #     for N in N1:
        print(H)
        print(N)
        for e in range(epochs):
            total_loss = 0
            for i in range(0, train_x.shape[0], N):
                if i+N >= train_x.shape[0]:
                    x = train_x[i:]
                    y = train_y[i:]
                else:
                    x = train_x[i:i+N]
                    y = train_y[i:i+N]
                y_pred = model(x.to(device))
                loss = loss_fn(y_pred, y.to(device))
        #         loss_list[e] = loss.item()
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                total_loss += loss.item()
            print("Epoch {}/{}, Train Loss: {:.3f}".format(e+1, epochs, total_loss))
            #pdb.set_trace()
            #Loss and accuracy on dev data
            with torch.no_grad():
                model.eval()
                output = model(dev_x.to(device))
                output = (output>0.5).float()
                acc    = accuracy_score(dev_y, output.cpu())
        #         accuracy_list[e] = acc
                if acc > dev_acc_max:
                    dev_acc_max=acc
                    epoch_max=e+1
                    torch.save(model, model_path)
              #correct = (output == dev_y.to(device)).float().sum()
    #             model.train()
                torch.save(model, model_path+'_last')
            print("Dev Accuracy: {:.3f}".format(acc))

        print("##############################################")
        print("Best dev accuracy is {:.3f} at epoch {}".format(dev_acc_max, epoch_max))
        print("Number of class 1 samples: ", (dev_y>0.5).float().sum().item())
        print("##############################################")

        ####################################################################################################
        #Evaluation
        ####################################################################################################
        with torch.no_grad():
        #             pdb.set_trace()
            model = torch.load(model_path)
            model.eval().to(device)
            output = model(test_x.to(device))
            output = (output>0.5).float()
            acc    = accuracy_score(test_y, output.cpu())
            print("Test Accuracy: {:.3f}".format(acc))
            print(model)

        with torch.no_grad():
        #             pdb.set_trace()
            model = torch.load(model_path+'_last')
            model.eval().to(device)
            output = model(test_x.to(device))
            output = (output>0.5).float()
            acc    = accuracy_score(test_y, output.cpu())
            print("Test Accuracy Last: {:.3f}".format(acc))
            print(model)
exit()
# Out:
# ConvLayerNet3_pressure_conv3_FNN_2_epochs_100_bs_8_H_512_drop_0.4_ks_10_stride_3_whole_z_score
# /raid/togzhan_syrymova/lump_project/models/ConvLayerNet3_pressure_conv3_FNN_2_epochs_100_bs_8_H_512_drop_0.4_ks_10_stride_3_whole_z_score
# ConvLayerNet3(
#   (convs): ModuleList(
#     (0): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (1): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (2): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (3): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (4): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (5): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (6): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (7): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (8): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (9): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (10): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (11): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (12): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (13): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (14): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#   )
#   (linear1_1): Linear(in_features=570, out_features=512, bias=True)
#   (linear1_2): Linear(in_features=512, out_features=32, bias=True)
#   (linear2): Linear(in_features=32, out_features=1, bias=True)
#   (relu): ReLU()
#   (drop1): Dropout(p=0.4, inplace=False)
#   (sigmoid): Sigmoid()
# )
# 512
# 8
# Epoch 1/100, Train Loss: 348.727
# Dev Accuracy: 0.526
# Epoch 2/100, Train Loss: 331.313
# Dev Accuracy: 0.599
# Epoch 3/100, Train Loss: 295.492
# Dev Accuracy: 0.649
# Epoch 4/100, Train Loss: 276.397
# Dev Accuracy: 0.660
# Epoch 5/100, Train Loss: 263.534
# Dev Accuracy: 0.661
# Epoch 6/100, Train Loss: 249.277
# Dev Accuracy: 0.670
# Epoch 7/100, Train Loss: 230.454
# Dev Accuracy: 0.665
# Epoch 8/100, Train Loss: 205.589
# Dev Accuracy: 0.674
# Epoch 9/100, Train Loss: 174.657
# Dev Accuracy: 0.681
# Epoch 10/100, Train Loss: 139.707
# Dev Accuracy: 0.688
# Epoch 11/100, Train Loss: 103.606
# Dev Accuracy: 0.679
# Epoch 12/100, Train Loss: 71.346
# Dev Accuracy: 0.681
# Epoch 13/100, Train Loss: 44.932
# Dev Accuracy: 0.682
# Epoch 14/100, Train Loss: 26.552
# Dev Accuracy: 0.681
# Epoch 15/100, Train Loss: 15.466
# Dev Accuracy: 0.684
# Epoch 16/100, Train Loss: 9.379
# Dev Accuracy: 0.686
# Epoch 17/100, Train Loss: 6.005
# Dev Accuracy: 0.686
# Epoch 18/100, Train Loss: 4.204
# Dev Accuracy: 0.677
# Epoch 19/100, Train Loss: 3.074
# Dev Accuracy: 0.677
# Epoch 20/100, Train Loss: 2.407
# Dev Accuracy: 0.675
# Epoch 21/100, Train Loss: 2.364
# Dev Accuracy: 0.684
# Epoch 22/100, Train Loss: 1.317
# Dev Accuracy: 0.681
# Epoch 23/100, Train Loss: 1.066
# Dev Accuracy: 0.670
# Epoch 24/100, Train Loss: 0.778
# Dev Accuracy: 0.696
# Epoch 25/100, Train Loss: 0.352
# Dev Accuracy: 0.696
# Epoch 26/100, Train Loss: 0.223
# Dev Accuracy: 0.693
# Epoch 27/100, Train Loss: 0.140
# Dev Accuracy: 0.698
# Epoch 28/100, Train Loss: 0.089
# Dev Accuracy: 0.696
# Epoch 29/100, Train Loss: 0.061
# Dev Accuracy: 0.694
# Epoch 30/100, Train Loss: 0.042
# Dev Accuracy: 0.694
# Epoch 31/100, Train Loss: 0.031
# Dev Accuracy: 0.696
# Epoch 32/100, Train Loss: 0.023
# Dev Accuracy: 0.694
# Epoch 33/100, Train Loss: 0.018
# Dev Accuracy: 0.694
# Epoch 34/100, Train Loss: 0.014
# Dev Accuracy: 0.694
# Epoch 35/100, Train Loss: 0.010
# Dev Accuracy: 0.696
# Epoch 36/100, Train Loss: 0.008
# Dev Accuracy: 0.694
# Epoch 37/100, Train Loss: 0.006
# Dev Accuracy: 0.694
# Epoch 38/100, Train Loss: 0.005
# Dev Accuracy: 0.694
# Epoch 39/100, Train Loss: 0.003
# Dev Accuracy: 0.696
# Epoch 40/100, Train Loss: 0.003
# Dev Accuracy: 0.694
# Epoch 41/100, Train Loss: 0.002
# Dev Accuracy: 0.694
# Epoch 42/100, Train Loss: 0.001
# Dev Accuracy: 0.694
# Epoch 43/100, Train Loss: 0.001
# Dev Accuracy: 0.696
# Epoch 44/100, Train Loss: 0.001
# Dev Accuracy: 0.696
# Epoch 45/100, Train Loss: 0.001
# Dev Accuracy: 0.698
# Epoch 46/100, Train Loss: 0.000
# Dev Accuracy: 0.700
# Epoch 47/100, Train Loss: 0.000
# Dev Accuracy: 0.701
# Epoch 48/100, Train Loss: 0.000
# Dev Accuracy: 0.701
# Epoch 49/100, Train Loss: 0.000
# Dev Accuracy: 0.701
# Epoch 50/100, Train Loss: 0.000
# Dev Accuracy: 0.701
# Epoch 51/100, Train Loss: 0.000
# Dev Accuracy: 0.701
# Epoch 52/100, Train Loss: 0.000
# Dev Accuracy: 0.703
# Epoch 53/100, Train Loss: 0.000
# Dev Accuracy: 0.703
# Epoch 54/100, Train Loss: 0.000
# Dev Accuracy: 0.703
# Epoch 55/100, Train Loss: 0.000
# Dev Accuracy: 0.705
# Epoch 56/100, Train Loss: 0.000
# Dev Accuracy: 0.707
# Epoch 57/100, Train Loss: 0.000
# Dev Accuracy: 0.705
# Epoch 58/100, Train Loss: 0.000
# Dev Accuracy: 0.705
# Epoch 59/100, Train Loss: 0.000
# Dev Accuracy: 0.703
# Epoch 60/100, Train Loss: 0.000
# Dev Accuracy: 0.708
# Epoch 61/100, Train Loss: 0.000
# Dev Accuracy: 0.707
# Epoch 62/100, Train Loss: 0.000
# Dev Accuracy: 0.705
# Epoch 63/100, Train Loss: 0.000
# Dev Accuracy: 0.705
# Epoch 64/100, Train Loss: 0.000
# Dev Accuracy: 0.705
# Epoch 65/100, Train Loss: 0.000
# Dev Accuracy: 0.707
# Epoch 66/100, Train Loss: 0.000
# Dev Accuracy: 0.703
# Epoch 67/100, Train Loss: 0.000
# Dev Accuracy: 0.708
# Epoch 68/100, Train Loss: 0.000
# Dev Accuracy: 0.701
# Epoch 69/100, Train Loss: 0.000
# Dev Accuracy: 0.701
# Epoch 70/100, Train Loss: 0.000
# Dev Accuracy: 0.698
# Epoch 71/100, Train Loss: 0.000
# Dev Accuracy: 0.701
# Epoch 72/100, Train Loss: 0.000
# Dev Accuracy: 0.700
# Epoch 73/100, Train Loss: 0.000
# Dev Accuracy: 0.698
# Epoch 74/100, Train Loss: 0.000
# Dev Accuracy: 0.708
# Epoch 75/100, Train Loss: 0.000
# Dev Accuracy: 0.707
# Epoch 76/100, Train Loss: 0.000
# Dev Accuracy: 0.707
# Epoch 77/100, Train Loss: 0.000
# Dev Accuracy: 0.708
# Epoch 78/100, Train Loss: 0.000
# Dev Accuracy: 0.703
# Epoch 79/100, Train Loss: 0.000
# Dev Accuracy: 0.708
# Epoch 80/100, Train Loss: 54.267
# Dev Accuracy: 0.708
# Epoch 81/100, Train Loss: 3.211
# Dev Accuracy: 0.707
# Epoch 82/100, Train Loss: 0.034
# Dev Accuracy: 0.712
# Epoch 83/100, Train Loss: 0.010
# Dev Accuracy: 0.710
# Epoch 84/100, Train Loss: 0.007
# Dev Accuracy: 0.712
# Epoch 85/100, Train Loss: 0.006
# Dev Accuracy: 0.712
# Epoch 86/100, Train Loss: 0.005
# Dev Accuracy: 0.714
# Epoch 87/100, Train Loss: 0.004
# Dev Accuracy: 0.714
# Epoch 88/100, Train Loss: 0.003
# Dev Accuracy: 0.714
# Epoch 89/100, Train Loss: 0.003
# Dev Accuracy: 0.714
# Epoch 90/100, Train Loss: 0.002
# Dev Accuracy: 0.715
# Epoch 91/100, Train Loss: 0.002
# Dev Accuracy: 0.715
# Epoch 92/100, Train Loss: 0.002
# Dev Accuracy: 0.715
# Epoch 93/100, Train Loss: 0.001
# Dev Accuracy: 0.715
# Epoch 94/100, Train Loss: 0.001
# Dev Accuracy: 0.714
# Epoch 95/100, Train Loss: 0.001
# Dev Accuracy: 0.715
# Epoch 96/100, Train Loss: 0.001
# Dev Accuracy: 0.714
# Epoch 97/100, Train Loss: 0.001
# Dev Accuracy: 0.712
# Epoch 98/100, Train Loss: 0.001
# Dev Accuracy: 0.712
# Epoch 99/100, Train Loss: 0.001
# Dev Accuracy: 0.707
# Epoch 100/100, Train Loss: 0.000
# Dev Accuracy: 0.707
# ##############################################
# Best dev accuracy is 0.715 at epoch 90
# Number of class 1 samples:  288.0
# ##############################################
# Test Accuracy: 0.581
# ConvLayerNet3(
#   (convs): ModuleList(
#     (0): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (1): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (2): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (3): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (4): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (5): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (6): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (7): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (8): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (9): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (10): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (11): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (12): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (13): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (14): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#   )
#   (linear1_1): Linear(in_features=570, out_features=512, bias=True)
#   (linear1_2): Linear(in_features=512, out_features=32, bias=True)
#   (linear2): Linear(in_features=32, out_features=1, bias=True)
#   (relu): ReLU()
#   (drop1): Dropout(p=0.4, inplace=False)
#   (sigmoid): Sigmoid()
# )
# Test Accuracy Last: 0.578
# ConvLayerNet3(
#   (convs): ModuleList(
#     (0): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (1): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (2): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (3): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (4): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (5): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (6): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (7): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (8): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (9): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (10): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (11): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (12): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (13): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (14): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#   )
#   (linear1_1): Linear(in_features=570, out_features=512, bias=True)
#   (linear1_2): Linear(in_features=512, out_features=32, bias=True)
#   (linear2): Linear(in_features=32, out_features=1, bias=True)
#   (relu): ReLU()
#   (drop1): Dropout(p=0.4, inplace=False)
#   (sigmoid): Sigmoid()
# )
# ConvLayerNet3_pressure_conv3_FNN_2_epochs_100_bs_8_H_256_drop_0.4_ks_10_stride_3_whole_z_score
# /raid/togzhan_syrymova/lump_project/models/ConvLayerNet3_pressure_conv3_FNN_2_epochs_100_bs_8_H_256_drop_0.4_ks_10_stride_3_whole_z_score
# ConvLayerNet3(
#   (convs): ModuleList(
#     (0): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (1): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (2): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (3): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (4): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (5): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (6): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (7): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (8): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (9): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (10): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (11): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (12): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (13): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#     (14): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (1): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#       (2): Conv1d(1, 1, kernel_size=(10,), stride=(3,))
#     )
#   )
#   (linear1_1): Linear(in_features=570, out_features=256, bias=True)
#   (linear1_2): Linear(in_features=256, out_features=32, bias=True)
#   (linear2): Linear(in_features=32, out_features=1, bias=True)
#   (relu): ReLU()
#   (drop1): Dropout(p=0.4, inplace=False)
#   (sigmoid): Sigmoid()
# )
# 256
# 8
# Epoch 1/100, Train Loss: 349.022
# Dev Accuracy: 0.618
# Epoch 2/100, Train Loss: 331.464
# Dev Accuracy: 0.615
# Epoch 3/100, Train Loss: 294.156
# Dev Accuracy: 0.649
# Epoch 4/100, Train Loss: 272.161
# Dev Accuracy: 0.667
# Epoch 5/100, Train Loss: 255.494
# Dev Accuracy: 0.679
# Epoch 6/100, Train Loss: 241.556
# Dev Accuracy: 0.677
# Epoch 7/100, Train Loss: 228.407
# Dev Accuracy: 0.688
# Epoch 8/100, Train Loss: 214.659
# Dev Accuracy: 0.693
# Epoch 9/100, Train Loss: 199.265
# Dev Accuracy: 0.705
# Epoch 10/100, Train Loss: 182.136
# Dev Accuracy: 0.703
# Epoch 11/100, Train Loss: 163.193
# Dev Accuracy: 0.701
# Epoch 12/100, Train Loss: 142.772
# Dev Accuracy: 0.707
# Epoch 13/100, Train Loss: 121.504
# Dev Accuracy: 0.705
# Epoch 14/100, Train Loss: 99.930
# Dev Accuracy: 0.701
# Epoch 15/100, Train Loss: 78.997
# Dev Accuracy: 0.694
# Epoch 16/100, Train Loss: 59.612
# Dev Accuracy: 0.703
# Epoch 17/100, Train Loss: 42.765
# Dev Accuracy: 0.700
# Epoch 18/100, Train Loss: 29.132
# Dev Accuracy: 0.707
# Epoch 19/100, Train Loss: 19.259
# Dev Accuracy: 0.705
# Epoch 20/100, Train Loss: 12.599
# Dev Accuracy: 0.700
# Epoch 21/100, Train Loss: 8.466
# Dev Accuracy: 0.703
# Epoch 22/100, Train Loss: 5.823
# Dev Accuracy: 0.701
# Epoch 23/100, Train Loss: 4.100
# Dev Accuracy: 0.696
# Epoch 24/100, Train Loss: 2.975
# Dev Accuracy: 0.700
# Epoch 25/100, Train Loss: 2.281
# Dev Accuracy: 0.696
# Epoch 26/100, Train Loss: 1.969
# Dev Accuracy: 0.674
# Epoch 27/100, Train Loss: 4.351
# Dev Accuracy: 0.667
# Epoch 28/100, Train Loss: 3.504
# Dev Accuracy: 0.696
# Epoch 29/100, Train Loss: 5.784
# Dev Accuracy: 0.653
# Epoch 30/100, Train Loss: 1.672
# Dev Accuracy: 0.705
# Epoch 31/100, Train Loss: 1.279
# Dev Accuracy: 0.734
# Epoch 32/100, Train Loss: 1.084
# Dev Accuracy: 0.736
# Epoch 33/100, Train Loss: 0.612
# Dev Accuracy: 0.734
# Epoch 34/100, Train Loss: 0.355
# Dev Accuracy: 0.736
# Epoch 35/100, Train Loss: 0.241
# Dev Accuracy: 0.733
# Epoch 36/100, Train Loss: 0.147
# Dev Accuracy: 0.736
# Epoch 37/100, Train Loss: 0.108
# Dev Accuracy: 0.738
# Epoch 38/100, Train Loss: 0.082
# Dev Accuracy: 0.741
# Epoch 39/100, Train Loss: 0.063
# Dev Accuracy: 0.740
# Epoch 40/100, Train Loss: 0.049
# Dev Accuracy: 0.740
# Epoch 41/100, Train Loss: 0.038
# Dev Accuracy: 0.740
# Epoch 42/100, Train Loss: 0.030
# Dev Accuracy: 0.740
# Epoch 43/100, Train Loss: 0.023
# Dev Accuracy: 0.740
# Epoch 44/100, Train Loss: 0.018
# Dev Accuracy: 0.736
# Epoch 45/100, Train Loss: 0.014
# Dev Accuracy: 0.736
# Epoch 46/100, Train Loss: 0.010
# Dev Accuracy: 0.734
# Epoch 47/100, Train Loss: 0.008
# Dev Accuracy: 0.734
# Epoch 48/100, Train Loss: 0.006
# Dev Accuracy: 0.734
# Epoch 49/100, Train Loss: 0.005
# Dev Accuracy: 0.734

# %%
with torch.no_grad():
    #             pdb.set_trace()
    model = torch.load(model_path)
    model.eval().to(device)
    output = model(test_x.to(device))
    output = (output>0.5).float()
    acc    = accuracy_score(test_y, output.cpu())
    print("Test Accuracy: {:.3f}".format(acc))
    print(model)
