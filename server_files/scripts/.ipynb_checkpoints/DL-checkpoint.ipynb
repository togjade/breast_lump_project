# %%
#!/usr/bin/python
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import os
import glob
# from model import *
# from functions import *
import pdb
import scipy.stats as stats

# %% [markdown]
# # Go to the directory and print the *.csv files

# %%
directory = '/raid/togzhan_syrymova/lump_project/data/'
os.chdir(directory)
# glob.glob('*.csv')

# %% [markdown]
# # Load the datasets

# %%
directory = '/raid/togzhan_syrymova/lump_project/data/'
os.chdir(directory)
csv_files_train = glob.glob('df_train*raw*8.csv')
csv_files_test = glob.glob('test*raw*.csv')
csv_files_dev = glob.glob('df_dev*raw*8.csv')

index = 0

df_train_ = pd.read_csv(csv_files_train[index], sep = ',', header = None)
df_train_ = pd.DataFrame(df_train_.values[1:,:])

df_test1 = pd.read_csv(csv_files_test[index], sep = ',', header = None)
df_test2 = pd.read_csv(csv_files_test[index+1], sep = ',', header = None)
df_test_ = pd.concat([df_test1, df_test2], axis = 1)
df_test_ = df_test_.transpose()

df_dev_ = pd.read_csv(csv_files_dev[index], sep = ',', header = None)
df_dev_ = pd.DataFrame(df_dev_.values[1:,:])


print(csv_files_train, '\n')
print(csv_files_test, '\n')
print(csv_files_dev, '\n')

print(csv_files_train[index], '\n')
print(csv_files_test[index], '\n')
print(csv_files_dev[index], '\n')
# Out:
# ['df_train_raw_8.csv']
#
# ['test_pressure_data_without_raw.csv', 'test_pressure_data_with_raw.csv']
#
# ['df_dev_raw_8.csv']
#
# df_train_raw_8.csv
#
# test_pressure_data_without_raw.csv
#
# df_dev_raw_8.csv

# %% [markdown]
# # Get labels and data separately

# %%
# Train and dev labels
train_y11 = pd.DataFrame((df_train_.values[:,-1].astype('float64')))
dev_y11 = pd.DataFrame((df_dev_.values[:,-1].astype('float64')))

# Create test labels
test_y11 = pd.concat([ pd.DataFrame([0 for i in range(2*32*9)]), pd.DataFrame([1 for i in range(2*32*9)])], axis=0)
test_y11 = test_y11.reset_index(drop=True)


df_train1 = pd.DataFrame(df_train_.values[:,:-1].astype('float64'))
df_dev1 = pd.DataFrame(df_dev_.values[:,:-1].astype('float64'))
df_test1 = df_test_.astype('float64')

## SHUFFLE the TEST labels and data
test_y1, df_test1 = shuffle(test_y11.astype('float64'), df_test1)

# %% [markdown]
# # Compute mean and stdev of the whole sequence per sensor for train/dev/test sets

# %%
idx = 0
df_train, df_dev, df_test = get_data(idx, df_train1, df_dev1, df_test1)

# %% [markdown]
# # Compute mean and stdev of the 1 sec of sequence per sensor for train/dev/test sets

# %%
idx = 1
df_train, train_y2, df_dev,dev_y2, df_test, test_y2 = get_data(idx, df_train1, df_dev1, df_test1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-09e0094f4570> in <module>
#       1 idx = 1
# ----> 2 df_train, train_y2, df_dev,dev_y2, df_test, test_y2 = get_data(idx, df_train1, df_dev1, df_test1)
#
# TypeError: cannot unpack non-iterable NoneType object

# %% [markdown]
# # Run to take imported sequence with no changes

# %%
idx = 2
df_train, df_dev, df_test = get_data(idx, df_train1, df_dev1, df_test1)

# %% [markdown]
# # Compute z-score

# %%
# run FUNCTIONS at the end of the notebook
idx = 3
df_train11, df_dev11, df_test11 = get_data(idx, df_train1, df_dev1, df_test1)
train_y1 = train_y11
dev_y1 = dev_y11
test_y1 = test_y1

# %% [markdown]
# # Compute z-score per trial

# %%
# run FUNCTIONS at the end of the notebook
idx = 4
df_train11, df_dev11, df_test11 = get_data(idx, df_train1, df_dev1, df_test1)
train_y1 = train_y11
dev_y1 = dev_y11
test_y1 = test_y1

# %%
def get_data(idx, df_train1, df_dev1, df_test1):
    df_train_mean = pd.DataFrame()
    df_train_stdev = pd.DataFrame()

    df_test_mean = pd.DataFrame()
    df_test_stdev = pd.DataFrame()

    df_dev_mean = pd.DataFrame()
    df_dev_stdev = pd.DataFrame()
    if (idx == 0):
        for i in range(15):
            df_train_mean = pd.concat([df_train_mean, pd.DataFrame(np.mean(df_train1.values[:, i*1120:(i+1)*1120], axis = 1))], axis = 1)
            df_train_stdev = pd.concat([df_train_stdev, pd.DataFrame(np.std(df_train1.values[:, i*1120:(i+1)*1120], axis = 1))], axis = 1)

            df_dev_mean = pd.concat([df_dev_mean, pd.DataFrame(np.mean(df_dev1.values[:, i*1120:(i+1)*1120], axis = 1))], axis = 1)
            df_dev_stdev = pd.concat([df_dev_stdev, pd.DataFrame(np.std(df_dev1.values[:, i*1120:(i+1)*1120], axis = 1))], axis = 1)

            df_test_mean = pd.concat([df_test_mean, pd.DataFrame(np.mean(df_test1.values[:, i*1120:(i+1)*1120], axis = 1))], axis = 1)
            df_test_stdev = pd.concat([df_test_stdev, pd.DataFrame(np.std(df_test1.values[:, i*1120:(i+1)*1120], axis = 1))], axis = 1)

        df_train = pd.concat([df_train_mean, df_train_stdev], axis = 1)
        df_dev = pd.concat([df_dev_mean, df_dev_stdev], axis = 1)
        df_test = pd.concat([df_test_mean, df_test_stdev], axis = 1)
        return df_train, df_dev, df_test
    
    elif (idx == 1):
        train_y2 = pd.DataFrame()
        dev_y2 = pd.DataFrame()
        test_y2 = pd.DataFrame()

        for j in range(7):
            df_train_mean_s = pd.DataFrame()
            df_train_stdev_s = pd.DataFrame()

            df_test_mean_s = pd.DataFrame()
            df_test_stdev_s = pd.DataFrame()

            df_dev_mean_s = pd.DataFrame()
            df_dev_stdev_s = pd.DataFrame()

            for i in range(15):
                index1 = i*1120+j*160
                index2 = i*1120+(j+1)*160
                df_train_mean_s = pd.concat([df_train_mean_s, pd.DataFrame(np.mean(df_train1.values[:, index1:index2], axis = 1))], axis = 1)
                df_train_stdev_s = pd.concat([df_train_stdev_s, pd.DataFrame(np.std(df_train1.values[:, index1:index2], axis = 1))], axis = 1)

                df_dev_mean_s = pd.concat([df_dev_mean_s, pd.DataFrame(np.mean(df_dev1.values[:, index1:index2], axis = 1))], axis = 1)
                df_dev_stdev_s = pd.concat([df_dev_stdev_s, pd.DataFrame(np.std(df_dev1.values[:, index1:index2], axis = 1))], axis = 1)

                df_test_mean_s = pd.concat([df_test_mean_s, pd.DataFrame(np.mean(df_test1.values[:, index1:index2], axis = 1))], axis = 1)
                df_test_stdev_s = pd.concat([df_test_stdev_s, pd.DataFrame(np.std(df_test1.values[:, index1:index2], axis = 1))], axis = 1)

            df_train_mean = pd.concat([df_train_mean, df_train_mean_s], axis = 0)
            df_train_stdev = pd.concat([df_train_stdev, df_train_stdev_s], axis = 0)

            df_test_mean = pd.concat([df_test_mean, df_test_mean_s], axis = 0)
            df_test_stdev = pd.concat([df_test_stdev, df_test_stdev_s], axis = 0)

            df_dev_mean = pd.concat([df_dev_mean, df_dev_mean_s], axis = 0)
            df_dev_stdev = pd.concat([df_dev_stdev, df_dev_stdev_s], axis = 0)

            # concat labels 7 times corresponding to 7 second
            train_y2 = pd.concat([train_y2, train_y11], axis = 0)
            dev_y2 = pd.concat([dev_y2, dev_y11], axis = 0)
            test_y2 = pd.concat([test_y2, test_y11], axis = 0)


        df_train = pd.concat([df_train_mean, df_train_stdev], axis = 1)
        df_dev = pd.concat([df_dev_mean, df_dev_stdev], axis = 1)
        df_test = pd.concat([df_test_mean, df_test_stdev], axis = 1)
        
    elif(idx == 2):
        df_train = df_train1
        df_dev = df_dev1
        df_test = df_test1
        return df_train, df_dev, df_test
    
    elif(idx == 3): #COMPUTE z-score
        df_train_z = pd.DataFrame()
        df_test_z = pd.DataFrame()
        df_dev_z = pd.DataFrame()
        for i in range(15):
            df_train_z1 = pd.DataFrame()
            df_dev_z1 = pd.DataFrame()
            df_test_z1 = pd.DataFrame()

            index1 = i*1120
            index2 = (i+1)*1120

            d_train = df_train1.values[:, i*1120:(i+1)*1120]
            d_dev = df_dev1.values[:, i*1120:(i+1)*1120]
            d_test = df_test1.values[:, i*1120:(i+1)*1120] 

            df_train_z1 = pd.DataFrame(stats.zscore(d_train, axis = 1))
            df_dev_z1 = pd.DataFrame(stats.zscore(d_dev, axis = 1))
            df_test_z1 = pd.DataFrame(stats.zscore(d_test, axis = 1))

            df_train_z1.columns = [''] * len(df_train_z1.columns)
            df_dev_z1.columns = [''] * len(df_dev_z1.columns)
            df_test_z1.columns = [''] * len(df_test_z1.columns)

        #     df_train_z1 = df_train_z1.reset_indext_index()
            df_train_z = pd.concat([df_train_z, df_train_z1], axis = 1)
            df_dev_z = pd.concat([df_dev_z, df_dev_z1], axis = 1)
            df_test_z = pd.concat([df_test_z, df_test_z1], axis = 1)
            
        return df_train_z, df_dev_z, df_test_z
    
    elif(idx == 4): #COMPUTE z-score
        df_train_z = pd.DataFrame()
        df_test_z = pd.DataFrame()
        df_dev_z = pd.DataFrame()
        df_train_z = pd.DataFrame(stats.zscore(df_train1, axis = 1))
        df_dev_z = pd.DataFrame(stats.zscore(df_dev1, axis = 1))
        df_test_z = pd.DataFrame(stats.zscore(df_test1, axis = 1))
            
        return df_train_z, df_dev_z, df_test_z

# %% [markdown]
# # Create Tensor from labels and data

# %%
from numpy import newaxis
sh = np.shape(df_train11)
a = df_train11.values[:]
df_train = df_train11.values[:, newaxis, :]
df_dev = df_dev11.values[:,newaxis, :]
df_test = df_test11.values[:,newaxis, :]
print(np.shape(df_train))

channels_in = 15

df_train = df_train.reshape(np.shape(df_train)[0], channels_in, np.int64(np.shape(df_train)[2]//channels_in))
df_dev = df_dev.reshape(np.shape(df_dev)[0], channels_in, np.int64(np.shape(df_dev)[2]//channels_in))
df_test = df_test.reshape(np.shape(df_test)[0], channels_in, np.int64(np.shape(df_test)[2]//channels_in))
print(np.shape(df_train))
####


# df_train = df_train11.values[:, :, newaxis]
# df_dev = df_dev11.values[:, :,newaxis]
# df_test = df_test11.values[:, :,newaxis]

# df_train = df_train.reshape(np.shape(df_train)[0], np.int64(np.shape(df_train)[1]//channels_in), channels_in)
# df_dev = df_dev.reshape(np.shape(df_dev)[0], np.int64(np.shape(df_dev)[1]//channels_in), channels_in)
# df_test = df_test.reshape(np.shape(df_test)[0], np.int64(np.shape(df_test)[1]//channels_in), channels_in)
# print(np.shape(df_train))
# Out:
# (4032, 1, 16800)
# (4032, 15, 1120)

# %%
# Create tensor from labels
# Transform labels in the format 1_9 to binary
train_y3 = pd.DataFrame(np.floor(train_y1.values[:].astype('float64')/10))
dev_y3 = pd.DataFrame(np.floor(dev_y1.values[:].astype('float64')/10))

train_y = torch.FloatTensor(train_y3.values[:])
dev_y = torch.FloatTensor(dev_y3.values[:])
test_y = torch.FloatTensor(test_y1.values[:])

train_x	= torch.FloatTensor(df_train.astype('float64'))
dev_x = torch.FloatTensor(df_dev.astype('float64'))
test_x = torch.FloatTensor(df_test.astype('float64'))

# %% [markdown]
# # Define the hyperparameters of the model

# %%
print('Started training')
seed = 777
torch.manual_seed(seed)

#################
# choose the gpu
gpu_id = 7
device = torch.device("cuda:" + str(gpu_id))
# device = torch.device("cpu")
print(device)

#################
# Input and output sizes
D_in = 1120 #np.shape(train_x)[2]
# channels_in = 1
channels_out = 1

D_out = 1

#################
# Choose the hidden layer, drop, batch_size, num_epochs, learning_rate
# H = 512  #hidden layer size

drop = 0.5
H1 = [ 256, 128]#, 2048,1024, 512
N1 = [8, 16, 32, 64]
epochs = 50
learning_rate = 1e-3
kernel_size = 15
stride  = 2

# loss_fn = torch.nn.BCELoss()BCEWithLogitsLoss
# N = batch_size

best_epoch = 0
dev_acc_max=0
epoch_max=0
loss_list     = np.zeros((epochs,))
accuracy_list = np.zeros((epochs,))
# Out:
# Started training
# cuda:7

# %%
# for N in N1:
for H in H1:
#         H = 512
#         H2 = 256
#         H3 = 64
    N = 32
    directory = '/raid/togzhan_syrymova/lump_project/models/'

    model = ConvLayerNet3(channels_in, channels_out, D_in, H, D_out, device, drop, kernel_size, stride).to(device)
    model_name = type(model).__name__

    model_name += '_pressure_' + 'conv3_FNN_3_' + 'epochs_' \
    + str(epochs) + '_bs_' + str(N)+ '_H_' + str(H) \
    + '_drop_' + str(drop) \
    + '_ks_' + str(kernel_size) + '_stride_' + str(stride) + '_whole_z_score'
    model_path = directory + model_name

    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    loss_fn = torch.nn.BCEWithLogitsLoss()
    print(model_name)
    print(model_path)
    print(model)

    # for H in H1:
    #     for N in N1:
    print(H)
    print(N)
    for e in range(epochs):
        total_loss = 0
        for i in range(0, train_x.shape[0], N):
            if i+N >= train_x.shape[0]:
                x = train_x[i:]
                y = train_y[i:]
            else:
                x = train_x[i:i+N]
                y = train_y[i:i+N]
            y_pred = model(x.to(device))
            loss = loss_fn(y_pred, y.to(device))
    #         loss_list[e] = loss.item()
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        print("Epoch {}/{}, Train Loss: {:.3f}".format(e+1, epochs, total_loss))
        #pdb.set_trace()
        #Loss and accuracy on dev data
        with torch.no_grad():
            model.eval()
            output = model(dev_x.to(device))
            output = (output>0.5).float()
            acc    = accuracy_score(dev_y, output.cpu())
    #         accuracy_list[e] = acc
            if acc > dev_acc_max:
                dev_acc_max=acc
                epoch_max=e+1
                torch.save(model, model_path)
          #correct = (output == dev_y.to(device)).float().sum()
#             model.train()
            torch.save(model, model_path+'_last')
        print("Dev Accuracy: {:.3f}".format(acc))

    print("##############################################")
    print("Best dev accuracy is {:.3f} at epoch {}".format(dev_acc_max, epoch_max))
    print("Number of class 1 samples: ", (dev_y>0.5).float().sum().item())
    print("##############################################")

    ####################################################################################################
    #Evaluation
    ####################################################################################################
    with torch.no_grad():
    #             pdb.set_trace()
        model = torch.load(model_path)
        model.eval().to(device)
        output = model(test_x.to(device))
        output = (output>0.5).float()
        acc    = accuracy_score(test_y, output.cpu())
        print("Test Accuracy: {:.3f}".format(acc))
        print(model)

exit()
# Out:
# ConvLayerNet3_pressure_conv3_FNN_3_epochs_50_bs_32_H_256_drop_0.5_ks_15_stride_2_whole_z_score
# /raid/togzhan_syrymova/lump_project/models/ConvLayerNet3_pressure_conv3_FNN_3_epochs_50_bs_32_H_256_drop_0.5_ks_15_stride_2_whole_z_score
# ConvLayerNet3(
#   (convs): ModuleList(
#     (0): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (1): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (2): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (3): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (4): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (5): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (6): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (7): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (8): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (9): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (10): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (11): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (12): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (13): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (14): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#   )
#   (linear1_1): Linear(in_features=1920, out_features=256, bias=True)
#   (linear1_2): Linear(in_features=256, out_features=16, bias=True)
#   (linear2): Linear(in_features=16, out_features=1, bias=True)
#   (relu): ReLU()
#   (drop1): Dropout(p=0.5, inplace=False)
#   (sigmoid): Sigmoid()
# )
# 256
# 32
# Epoch 1/50, Train Loss: 75.815
# Dev Accuracy: 0.689
# Epoch 2/50, Train Loss: 60.554
# Dev Accuracy: 0.771
# Epoch 3/50, Train Loss: 53.489
# Dev Accuracy: 0.766
# Epoch 4/50, Train Loss: 49.298
# Dev Accuracy: 0.748
# Epoch 5/50, Train Loss: 45.972
# Dev Accuracy: 0.740
# Epoch 6/50, Train Loss: 42.337
# Dev Accuracy: 0.733
# Epoch 7/50, Train Loss: 39.407
# Dev Accuracy: 0.745
# Epoch 8/50, Train Loss: 36.416
# Dev Accuracy: 0.774
# Epoch 9/50, Train Loss: 32.825
# Dev Accuracy: 0.769
# Epoch 10/50, Train Loss: 27.752
# Dev Accuracy: 0.781
# Epoch 11/50, Train Loss: 23.059
# Dev Accuracy: 0.804
# Epoch 12/50, Train Loss: 20.153
# Dev Accuracy: 0.807
# Epoch 13/50, Train Loss: 15.805
# Dev Accuracy: 0.840
# Epoch 14/50, Train Loss: 13.658
# Dev Accuracy: 0.821
# Epoch 15/50, Train Loss: 11.736
# Dev Accuracy: 0.816
# Epoch 16/50, Train Loss: 8.791
# Dev Accuracy: 0.839
# Epoch 17/50, Train Loss: 9.203
# Dev Accuracy: 0.807
# Epoch 18/50, Train Loss: 10.722
# Dev Accuracy: 0.819
# Epoch 19/50, Train Loss: 7.638
# Dev Accuracy: 0.804
# Epoch 20/50, Train Loss: 9.141
# Dev Accuracy: 0.825
# Epoch 21/50, Train Loss: 6.699
# Dev Accuracy: 0.823
# Epoch 22/50, Train Loss: 3.757
# Dev Accuracy: 0.823
# Epoch 23/50, Train Loss: 2.777
# Dev Accuracy: 0.833
# Epoch 24/50, Train Loss: 2.401
# Dev Accuracy: 0.840
# Epoch 25/50, Train Loss: 1.269
# Dev Accuracy: 0.835
# Epoch 26/50, Train Loss: 0.795
# Dev Accuracy: 0.826
# Epoch 27/50, Train Loss: 0.510
# Dev Accuracy: 0.830
# Epoch 28/50, Train Loss: 0.269
# Dev Accuracy: 0.818
# Epoch 29/50, Train Loss: 0.236
# Dev Accuracy: 0.821
# Epoch 30/50, Train Loss: 0.138
# Dev Accuracy: 0.826
# Epoch 31/50, Train Loss: 0.088
# Dev Accuracy: 0.826
# Epoch 32/50, Train Loss: 0.064
# Dev Accuracy: 0.835
# Epoch 33/50, Train Loss: 0.048
# Dev Accuracy: 0.835
# Epoch 34/50, Train Loss: 0.036
# Dev Accuracy: 0.839
# Epoch 35/50, Train Loss: 0.030
# Dev Accuracy: 0.837
# Epoch 36/50, Train Loss: 0.025
# Dev Accuracy: 0.835
# Epoch 37/50, Train Loss: 0.022
# Dev Accuracy: 0.835
# Epoch 38/50, Train Loss: 0.019
# Dev Accuracy: 0.835
# Epoch 39/50, Train Loss: 0.017
# Dev Accuracy: 0.835
# Epoch 40/50, Train Loss: 0.015
# Dev Accuracy: 0.835
# Epoch 41/50, Train Loss: 0.013
# Dev Accuracy: 0.835
# Epoch 42/50, Train Loss: 0.012
# Dev Accuracy: 0.835
# Epoch 43/50, Train Loss: 0.010
# Dev Accuracy: 0.837
# Epoch 44/50, Train Loss: 0.009
# Dev Accuracy: 0.837
# Epoch 45/50, Train Loss: 0.008
# Dev Accuracy: 0.837
# Epoch 46/50, Train Loss: 0.008
# Dev Accuracy: 0.837
# Epoch 47/50, Train Loss: 0.007
# Dev Accuracy: 0.832
# Epoch 48/50, Train Loss: 0.006
# Dev Accuracy: 0.832
# Epoch 49/50, Train Loss: 0.006
# Dev Accuracy: 0.832
# Epoch 50/50, Train Loss: 0.005
# Dev Accuracy: 0.832
# ##############################################
# Best dev accuracy is 0.840 at epoch 13
# Number of class 1 samples:  288.0
# ##############################################
# Test Accuracy: 0.582
# ConvLayerNet3(
#   (convs): ModuleList(
#     (0): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (1): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (2): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (3): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (4): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (5): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (6): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (7): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (8): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (9): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (10): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (11): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (12): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (13): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (14): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#   )
#   (linear1_1): Linear(in_features=1920, out_features=256, bias=True)
#   (linear1_2): Linear(in_features=256, out_features=16, bias=True)
#   (linear2): Linear(in_features=16, out_features=1, bias=True)
#   (relu): ReLU()
#   (drop1): Dropout(p=0.5, inplace=False)
#   (sigmoid): Sigmoid()
# )
# ConvLayerNet3_pressure_conv3_FNN_3_epochs_50_bs_32_H_128_drop_0.5_ks_15_stride_2_whole_z_score
# /raid/togzhan_syrymova/lump_project/models/ConvLayerNet3_pressure_conv3_FNN_3_epochs_50_bs_32_H_128_drop_0.5_ks_15_stride_2_whole_z_score
# ConvLayerNet3(
#   (convs): ModuleList(
#     (0): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (1): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (2): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (3): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (4): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (5): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (6): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (7): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (8): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (9): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (10): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (11): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (12): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (13): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (14): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#   )
#   (linear1_1): Linear(in_features=1920, out_features=128, bias=True)
#   (linear1_2): Linear(in_features=128, out_features=16, bias=True)
#   (linear2): Linear(in_features=16, out_features=1, bias=True)
#   (relu): ReLU()
#   (drop1): Dropout(p=0.5, inplace=False)
#   (sigmoid): Sigmoid()
# )
# 128
# 32
# Epoch 1/50, Train Loss: 83.318
# Dev Accuracy: 0.592
# Epoch 2/50, Train Loss: 64.248
# Dev Accuracy: 0.686
# Epoch 3/50, Train Loss: 56.609
# Dev Accuracy: 0.720
# Epoch 4/50, Train Loss: 50.475
# Dev Accuracy: 0.743
# Epoch 5/50, Train Loss: 43.632
# Dev Accuracy: 0.773
# Epoch 6/50, Train Loss: 38.158
# Dev Accuracy: 0.786
# Epoch 7/50, Train Loss: 33.966
# Dev Accuracy: 0.795
# Epoch 8/50, Train Loss: 29.835
# Dev Accuracy: 0.799
# Epoch 9/50, Train Loss: 26.415
# Dev Accuracy: 0.811
# Epoch 10/50, Train Loss: 22.672
# Dev Accuracy: 0.823
# Epoch 11/50, Train Loss: 19.976
# Dev Accuracy: 0.814
# Epoch 12/50, Train Loss: 18.104
# Dev Accuracy: 0.818
# Epoch 13/50, Train Loss: 18.154
# Dev Accuracy: 0.821
# Epoch 14/50, Train Loss: 15.218
# Dev Accuracy: 0.814
# Epoch 15/50, Train Loss: 15.779
# Dev Accuracy: 0.823
# Epoch 16/50, Train Loss: 12.000
# Dev Accuracy: 0.807
# Epoch 17/50, Train Loss: 11.136
# Dev Accuracy: 0.816
# Epoch 18/50, Train Loss: 11.401
# Dev Accuracy: 0.842
# Epoch 19/50, Train Loss: 10.440
# Dev Accuracy: 0.830
# Epoch 20/50, Train Loss: 8.370
# Dev Accuracy: 0.837
# Epoch 21/50, Train Loss: 7.662
# Dev Accuracy: 0.835
# Epoch 22/50, Train Loss: 7.479
# Dev Accuracy: 0.819
# Epoch 23/50, Train Loss: 5.723
# Dev Accuracy: 0.842
# Epoch 24/50, Train Loss: 3.633
# Dev Accuracy: 0.828
# Epoch 25/50, Train Loss: 4.524
# Dev Accuracy: 0.833
# Epoch 26/50, Train Loss: 3.824
# Dev Accuracy: 0.823
# Epoch 27/50, Train Loss: 7.045
# Dev Accuracy: 0.818
# Epoch 28/50, Train Loss: 7.567
# Dev Accuracy: 0.818
# Epoch 29/50, Train Loss: 3.682
# Dev Accuracy: 0.811
# Epoch 30/50, Train Loss: 3.180
# Dev Accuracy: 0.812
# Epoch 31/50, Train Loss: 2.619
# Dev Accuracy: 0.807
# Epoch 32/50, Train Loss: 2.578
# Dev Accuracy: 0.788
# Epoch 33/50, Train Loss: 4.073
# Dev Accuracy: 0.804
# Epoch 34/50, Train Loss: 5.065
# Dev Accuracy: 0.825
# Epoch 35/50, Train Loss: 3.289
# Dev Accuracy: 0.826
# Epoch 36/50, Train Loss: 1.131
# Dev Accuracy: 0.833
# Epoch 37/50, Train Loss: 0.422
# Dev Accuracy: 0.839
# Epoch 38/50, Train Loss: 0.291
# Dev Accuracy: 0.826
# Epoch 39/50, Train Loss: 0.300
# Dev Accuracy: 0.835
# Epoch 40/50, Train Loss: 0.175
# Dev Accuracy: 0.839
# Epoch 41/50, Train Loss: 0.113
# Dev Accuracy: 0.833
# Epoch 42/50, Train Loss: 0.083
# Dev Accuracy: 0.832
# Epoch 43/50, Train Loss: 0.067
# Dev Accuracy: 0.830
# Epoch 44/50, Train Loss: 0.055
# Dev Accuracy: 0.832
# Epoch 45/50, Train Loss: 0.047
# Dev Accuracy: 0.833
# Epoch 46/50, Train Loss: 0.041
# Dev Accuracy: 0.833
# Epoch 47/50, Train Loss: 0.036
# Dev Accuracy: 0.835
# Epoch 48/50, Train Loss: 0.031
# Dev Accuracy: 0.839
# Epoch 49/50, Train Loss: 0.027
# Dev Accuracy: 0.839
# Epoch 50/50, Train Loss: 0.024
# Dev Accuracy: 0.839
# ##############################################
# Best dev accuracy is 0.842 at epoch 18
# Number of class 1 samples:  288.0
# ##############################################
# Test Accuracy: 0.689
# ConvLayerNet3(
#   (convs): ModuleList(
#     (0): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (1): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (2): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (3): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (4): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (5): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (6): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (7): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (8): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (9): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (10): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (11): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (12): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (13): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#     (14): Sequential(
#       (0): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (1): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#       (2): Conv1d(1, 1, kernel_size=(15,), stride=(2,))
#     )
#   )
#   (linear1_1): Linear(in_features=1920, out_features=128, bias=True)
#   (linear1_2): Linear(in_features=128, out_features=16, bias=True)
#   (linear2): Linear(in_features=16, out_features=1, bias=True)
#   (relu): ReLU()
#   (drop1): Dropout(p=0.5, inplace=False)
#   (sigmoid): Sigmoid()
# )

# %%
with torch.no_grad():
    #             pdb.set_trace()
#     model = torch.load(model_path)
    model.eval().to(device)
    output = model(test_x.to(device))
    output = (output>0.5).float()
    acc    = accuracy_score(test_y, output.cpu())
    print("Test Accuracy: {:.3f}".format(acc))
    print(model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-88182f172a46> in <module>
# ----> 1 with torch.no_grad():
#       2     #             pdb.set_trace()
#       3 #     model = torch.load(model_path)
#       4     model.eval().to(device)
#       5     output = model(test_x.to(device))
#
# NameError: name 'torch' is not defined

# %%
class ConvLayerNet3(torch.nn.Module):
    def __init__(self,  channels_in, channels_out, D_in, H, D_out, device, drop=0.0, kernel_size=1, stride=1):
        super(ConvLayerNet3, self).__init__()
        self.device = device
#         self.convs = nn.ModuleList([nn.Conv1d(1, channels_out, kernel_size=kernel_size, stride=stride) for i in range(15)])
        self.convs = nn.ModuleList([nn.Sequential(
            nn.Conv1d(1, channels_out, kernel_size=kernel_size, stride=stride),
            nn.Conv1d(1, channels_out, kernel_size=kernel_size, stride=stride),
            nn.Conv1d(1, channels_out, kernel_size=kernel_size, stride=stride),
        ) for i in range(15)])
                                    
        W_out = ((D_in - kernel_size)//stride + 1)*channels_out
        W_out = ((W_out - kernel_size)//stride + 1)*channels_out
        W_out = ((W_out - kernel_size)//stride + 1)*15*channels_out
        W_out = np.int64(W_out) 
        H3 = H//2
        self.linear1_1 = torch.nn.Linear(W_out, H)
        self.linear1_2 = torch.nn.Linear(H, 16)
#         self.linear1_3 = torch.nn.Linear(H3, 64)
        self.linear2 = torch.nn.Linear(16, D_out)
        
        self.relu = torch.nn.ReLU()
        self.drop1   = torch.nn.Dropout(p=drop)
        self.sigmoid = torch.nn.Sigmoid()
#         self.softmax = torch.nn.Softmax(dim=1)

    def forward(self, x):
        ii = 0
        h_relu = torch.FloatTensor([]).to(self.device)
        for layers in self.convs:
            x_data = layers(torch.unsqueeze(x[:, ii, :],1))
            x_data = self.relu(x_data)
            b, h, w = x_data.size()
            x_data = x_data.view(b,-1)
            h_relu = torch.cat([h_relu, x_data], axis = 1)
            ii = ii+1
        
        h_relu = self.drop1(self.linear1_1(h_relu))#.clamp(min=0)#.clamp(min=0)
        h_relu = self.relu(h_relu)
        
        h_relu = self.drop1(self.linear1_2(h_relu))#.clamp(min=0)#.clamp(min=0)
        h_relu = self.relu(h_relu)
        
#         h_relu = self.drop1(self.linear1_3(h_relu))#.clamp(min=0)#.clamp(min=0)
#         h_relu = self.relu(h_relu)
        
        y_pred = (self.linear2(h_relu))
        
        return y_pred

# %%
class ConvLayerNet2(torch.nn.Module):
    def __init__(self,  channels_in, channels_out, D_in, H, H2, D_out, device, drop=0.0, kernel_size=1, stride=1):
        super(ConvLayerNet2, self).__init__()
        self.device = device
        self.convs = nn.ModuleList([nn.Conv1d(channels_in, channels_out, kernel_size=kernel_size, stride=stride) for i in range(15)])

        W_out = ((D_in - kernel_size)//stride + 1)*15*channels_out
        W_out = np.int64(W_out)
        
        self.linear1_1 = torch.nn.Linear(W_out, H)
        self.linear1_2 = torch.nn.Linear(H, H2)
        self.linear2 = torch.nn.Linear(H2, D_out)
        
        self.relu = torch.nn.ReLU()
        self.drop1   = torch.nn.Dropout(p=drop)
        self.sigmoid = torch.nn.Sigmoid()
#         self.softmax = torch.nn.Softmax(dim=1)

    def forward(self, x):
        ii = 0
        h_relu = torch.FloatTensor([]).to(self.device)
        for layers in self.convs:
            x_data = layers(x[:,:,ii*(D_in):(ii+1)*D_in])
            x_data = self.relu(x_data)
            b, h, w = x_data.size()
            x_data = x_data.view(b,-1)
            h_relu = torch.cat([h_relu, x_data], axis = 1)
            ii = ii+1
        
        h_relu = self.drop1(self.linear1_1(h_relu))#.clamp(min=0)#.clamp(min=0)
        h_relu = self.relu(h_relu)
        
        h_relu = self.drop1(self.linear1_2(h_relu))#.clamp(min=0)#.clamp(min=0)
        h_relu = self.relu(h_relu)
        
        y_pred = self.sigmoid(self.linear2(h_relu))
        
        return y_pred

# %% [markdown]
# # Functions

# %%
# RESHAPE TO 3D ARRAY
# df_train_3d = df_train.values[:,:-1]
# df_train_3d = df_train_3d[:, :, np.newaxis]
# df_train_3d = df_train_3d.reshape(np.shape(df_train)[0], 15, 1120)
# print(np.shape(df_train_3d))

# df_dev_3d = df_dev.values[:,:-1]
# df_dev_3d = df_dev_3d[:, :, np.newaxis]
# df_dev_3d = df_dev_3d.reshape(np.shape(df_dev)[0], 15, 1120)
# print(np.shape(df_dev_3d))

# df_test_3d = df_test.values[:,:-1]
# df_test_3d = df_test_3d[:, :, np.newaxis]
# df_test_3d = df_test_3d.reshape(np.shape(df_test)[0], 15, 1120)
# print(np.shape(df_test_3d))

#################

# Transform labels in the format 1_9 to binary
train_y3 = pd.DataFrame(np.floor(train_y1.values[:].astype('float64')/10))
dev_y3 = pd.DataFrame(np.floor(dev_y1.values[:].astype('float64')/10))
# test_y1 = pd.DataFrame(np.floor(df_test.values[:,-1].astype('float64')/10))

#################
# Transofrm the labels to one-hot encoded 
# train_y = pd.get_dummies(train_y3.values[:].astype('float64').reshape(-1))
# dev_y = pd.get_dummies(dev_y3.values[:].astype('float64').reshape(-1))
# test_y = pd.get_dummies(test_y1.values[:].astype('float64').reshape(-1))

#################

################# 
# train_y = torch.FloatTensor(train_y1.values[:].astype('float64').reshape(-1))
# dev_y = torch.FloatTensor(dev_y1.values[:].astype('float64').reshape(-1))
# test_y = torch.FloatTensor(test_y1.values[:].astype('float64').reshape(-1))

# train_y = torch.FloatTensor(np.round(df_train_.values[:,-1].astype('float64')/10)).long()
# dev_y = torch.FloatTensor(np.round(df_dev_.values[:,-1].astype('float64')/10)).long()
# test_y = torch.FloatTensor(np.round(df_test.values[:,-1].astype('float64')/10)).long()

#################
# 3D array Tensor
# df_train_3d = torch.FloatTensor(df_train_3d.astype('float64'))
# df_dev_3d = torch.FloatTensor(df_dev_3d.astype('float64'))
# df_test_3d = torch.FloatTensor(df_test_3d.astype('float64'))
#################

# 2D  array  Tensor
# train_x	= torch.FloatTensor(df_train.values[:,:].astype('float64'))
# dev_x = torch.FloatTensor(df_dev.values[:,:].astype('float64'))
# test_x = torch.FloatTensor(df_test.values[:,:].astype('float64'))
