# %%
#!/usr/bin/python
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import os
import glob
# from model import *
from functions import *
import pdb
import scipy.stats as stats
from scipy.signal import spectrogram

# %% [markdown]
# # Go to the directory and print the *.csv files

# %%
directory = '/raid/togzhan_syrymova/lump_project/data/'
os.chdir(directory)
# glob.glob('*.csv')

# %% [markdown]
# # Load the datasets

# %%
directory = '/raid/togzhan_syrymova/lump_project/data/'
os.chdir(directory)
csv_files_train = glob.glob('df_train*raw*8.csv')
csv_files_test = glob.glob('test*raw*.csv')
csv_files_dev = glob.glob('df_dev*raw*8.csv')

index = 0

df_train_ = pd.read_csv(csv_files_train[index], sep = ',', header = None)
df_train_ = pd.DataFrame(df_train_.values[1:,:])

df_test1 = pd.read_csv(csv_files_test[index], sep = ',', header = None)
df_test2 = pd.read_csv(csv_files_test[index+1], sep = ',', header = None)
df_test_ = pd.concat([df_test1, df_test2], axis = 1)
df_test_ = df_test_.transpose()

df_dev_ = pd.read_csv(csv_files_dev[index], sep = ',', header = None)
df_dev_ = pd.DataFrame(df_dev_.values[1:,:])


print(csv_files_train, '\n')
print(csv_files_test, '\n')
print(csv_files_dev, '\n')

print(csv_files_train[index], '\n')
print(csv_files_test[index], '\n')
print(csv_files_dev[index], '\n')
# Out:
# ['df_train_raw_8.csv']
#
# ['test_pressure_data_without_raw.csv', 'test_pressure_data_with_raw.csv']
#
# ['df_dev_raw_8.csv']
#
# df_train_raw_8.csv
#
# test_pressure_data_without_raw.csv
#
# df_dev_raw_8.csv

# %% [markdown]
# # Get labels and data separately

# %%
# Train and dev labels
train_y11 = pd.DataFrame((df_train_.values[:,-1].astype('float64')))
dev_y11 = pd.DataFrame((df_dev_.values[:,-1].astype('float64')))

# Create test labels
test_y11 = pd.concat([ pd.DataFrame([0 for i in range(2*32*9)]), pd.DataFrame([1 for i in range(2*32*9)])], axis=0)
test_y11 = test_y11.reset_index(drop=True)


df_train1 = pd.DataFrame(df_train_.values[:,:-1].astype('float64'))
df_dev1 = pd.DataFrame(df_dev_.values[:,:-1].astype('float64'))
df_test1 = df_test_.astype('float64')

## SHUFFLE the TEST labels and data
test_y1, df_test1 = shuffle(test_y11.astype('float64'), df_test1)

# %% [markdown]
# # Compute mean and stdev of the whole sequence per sensor for train/dev/test sets

# %%
# idx = 0
# df_train, df_dev, df_test = get_data(idx, df_train1, df_dev1, df_test1)

# %% [markdown]
# # Compute mean and stdev of the 1 sec of sequence per sensor for train/dev/test sets

# %%
# idx = 1
# df_train, train_y2, df_dev,dev_y2, df_test, test_y2 = get_data(idx, df_train1, df_dev1, df_test1)

# %% [markdown]
# # Run to take imported sequence with no changes

# %%
# import pandas as pd
# import functions
# idx = 2
# df_train, df_dev, df_test = get_data(idx, df_train1, df_dev1, df_test1)

# %%
def get_data(idx, df_train1, df_dev1, df_test1):
    df_train_mean = pd.DataFrame()
    df_train_stdev = pd.DataFrame()

    df_test_mean = pd.DataFrame()
    df_test_stdev = pd.DataFrame()

    df_dev_mean = pd.DataFrame()
    df_dev_stdev = pd.DataFrame()
    if (idx == 0):
        for i in range(15):
            df_train_mean = pd.concat([df_train_mean, pd.DataFrame(np.mean(df_train1.values[:, i*1120:(i+1)*1120], axis = 1))], axis = 1)
            df_train_stdev = pd.concat([df_train_stdev, pd.DataFrame(np.std(df_train1.values[:, i*1120:(i+1)*1120], axis = 1))], axis = 1)

            df_dev_mean = pd.concat([df_dev_mean, pd.DataFrame(np.mean(df_dev1.values[:, i*1120:(i+1)*1120], axis = 1))], axis = 1)
            df_dev_stdev = pd.concat([df_dev_stdev, pd.DataFrame(np.std(df_dev1.values[:, i*1120:(i+1)*1120], axis = 1))], axis = 1)

            df_test_mean = pd.concat([df_test_mean, pd.DataFrame(np.mean(df_test1.values[:, i*1120:(i+1)*1120], axis = 1))], axis = 1)
            df_test_stdev = pd.concat([df_test_stdev, pd.DataFrame(np.std(df_test1.values[:, i*1120:(i+1)*1120], axis = 1))], axis = 1)

        df_train = pd.concat([df_train_mean, df_train_stdev], axis = 1)
        df_dev = pd.concat([df_dev_mean, df_dev_stdev], axis = 1)
        df_test = pd.concat([df_test_mean, df_test_stdev], axis = 1)
        return df_train, df_dev, df_test
    
    elif (idx == 1):
        train_y2 = pd.DataFrame()
        dev_y2 = pd.DataFrame()
        test_y2 = pd.DataFrame()

        for j in range(7):
            df_train_mean_s = pd.DataFrame()
            df_train_stdev_s = pd.DataFrame()

            df_test_mean_s = pd.DataFrame()
            df_test_stdev_s = pd.DataFrame()

            df_dev_mean_s = pd.DataFrame()
            df_dev_stdev_s = pd.DataFrame()

            for i in range(15):
                index1 = i*1120+j*160
                index2 = i*1120+(j+1)*160
                df_train_mean_s = pd.concat([df_train_mean_s, pd.DataFrame(np.mean(df_train1.values[:, index1:index2], axis = 1))], axis = 1)
                df_train_stdev_s = pd.concat([df_train_stdev_s, pd.DataFrame(np.std(df_train1.values[:, index1:index2], axis = 1))], axis = 1)

                df_dev_mean_s = pd.concat([df_dev_mean_s, pd.DataFrame(np.mean(df_dev1.values[:, index1:index2], axis = 1))], axis = 1)
                df_dev_stdev_s = pd.concat([df_dev_stdev_s, pd.DataFrame(np.std(df_dev1.values[:, index1:index2], axis = 1))], axis = 1)

                df_test_mean_s = pd.concat([df_test_mean_s, pd.DataFrame(np.mean(df_test1.values[:, index1:index2], axis = 1))], axis = 1)
                df_test_stdev_s = pd.concat([df_test_stdev_s, pd.DataFrame(np.std(df_test1.values[:, index1:index2], axis = 1))], axis = 1)

            df_train_mean = pd.concat([df_train_mean, df_train_mean_s], axis = 0)
            df_train_stdev = pd.concat([df_train_stdev, df_train_stdev_s], axis = 0)

            df_test_mean = pd.concat([df_test_mean, df_test_mean_s], axis = 0)
            df_test_stdev = pd.concat([df_test_stdev, df_test_stdev_s], axis = 0)

            df_dev_mean = pd.concat([df_dev_mean, df_dev_mean_s], axis = 0)
            df_dev_stdev = pd.concat([df_dev_stdev, df_dev_stdev_s], axis = 0)

            # concat labels 7 times corresponding to 7 second
            train_y2 = pd.concat([train_y2, train_y11], axis = 0)
            dev_y2 = pd.concat([dev_y2, dev_y11], axis = 0)
            test_y2 = pd.concat([test_y2, test_y11], axis = 0)


        df_train = pd.concat([df_train_mean, df_train_stdev], axis = 1)
        df_dev = pd.concat([df_dev_mean, df_dev_stdev], axis = 1)
        df_test = pd.concat([df_test_mean, df_test_stdev], axis = 1)
        
    elif(idx == 2):
        df_train = df_train1
        df_dev = df_dev1
        df_test = df_test1
        return df_train, df_dev, df_test
    
    elif(idx == 3): #COMPUTE z-score
        df_train_z = pd.DataFrame()
        df_test_z = pd.DataFrame()
        df_dev_z = pd.DataFrame()
        for i in range(15):
            df_train_z1 = pd.DataFrame()
            df_dev_z1 = pd.DataFrame()
            df_test_z1 = pd.DataFrame()

            index1 = i*1120
            index2 = (i+1)*1120

            d_train = df_train1.values[:, i*1120:(i+1)*1120]
            d_dev = df_dev1.values[:, i*1120:(i+1)*1120]
            d_test = df_test1.values[:, i*1120:(i+1)*1120] 

            df_train_z1 = pd.DataFrame(stats.zscore(d_train, axis = 1))
            df_dev_z1 = pd.DataFrame(stats.zscore(d_dev, axis = 1))
            df_test_z1 = pd.DataFrame(stats.zscore(d_test, axis = 1))

            df_train_z1.columns = [''] * len(df_train_z1.columns)
            df_dev_z1.columns = [''] * len(df_dev_z1.columns)
            df_test_z1.columns = [''] * len(df_test_z1.columns)

        #     df_train_z1 = df_train_z1.reset_indext_index()
            df_train_z = pd.concat([df_train_z, df_train_z1], axis = 1)
            df_dev_z = pd.concat([df_dev_z, df_dev_z1], axis = 1)
            df_test_z = pd.concat([df_test_z, df_test_z1], axis = 1)
            
        return df_train_z, df_dev_z, df_test_z
    
    elif(idx == 4): #COMPUTE z-score
        df_train_z = pd.DataFrame()
        df_test_z = pd.DataFrame()
        df_dev_z = pd.DataFrame()
        df_train_z = pd.DataFrame(stats.zscore(df_train1, axis = 1))
        df_dev_z = pd.DataFrame(stats.zscore(df_dev1, axis = 1))
        df_test_z = pd.DataFrame(stats.zscore(df_test1, axis = 1))
            
        return df_train_z, df_dev_z, df_test_z
    
def compute_spectogram(df):
    df_1 = np.zeros([np.shape(df)[0], 129, 4])
    for i in range(15):
        fs = 160
        f, t, data = spectrogram(df.values[:, 1120*i:(i+1)*1120], fs, axis = 1)
        df_1 = np.concatenate([df_1, 10*np.log10(data)], axis = 1)
        data = []
    return df_1[:, 129:, :],t, f

# %% [markdown]
# # Compute z-score

# %%
# # run FUNCTIONS at the end of the notebook
# idx = 3
# df_train11, df_dev11, df_test11 = get_data(idx, df_train1, df_dev1, df_test1)
# train_y1 = train_y11
# dev_y1 = dev_y11
# test_y1 = test_y1

# %% [markdown]
# # Compute z-score per trial

# %%
# # run FUNCTIONS at the end of the notebook
# idx = 4
# df_train11, df_dev11, df_test11 = get_data(idx, df_train1, df_dev1, df_test1)
# train_y1 = train_y11
# dev_y1 = dev_y11
# test_y1 = test_y11

# %% [markdown]
# # Compute spectogram

# %%
from numpy import newaxis

def compute_spectogram(df):
    df_1 = np.zeros([np.shape(df)[0], 1, 129, 4])
    for i in range(15):
        fs = 160
        f, t, data = spectrogram(df.values[:, 1120*i:(i+1)*1120], fs, axis = 1)
        data1 = data[:, newaxis, ...]
#         d = 10*np.log10(data1)
        df_1 = np.concatenate([df_1, data1], axis = 1)
        data = []
#         print(np.shape(df_1))
    return df_1[:, 1:, :, :],t, f

df_train3, t, f = compute_spectogram(df_train1)
train_y1 = train_y11
print(np.shape(df_train3))

df_dev3, t, f = compute_spectogram(df_dev1)
dev_y1 = dev_y11
print(np.shape(df_dev3))
df_test3, t, f = compute_spectogram(df_test1)
test_y1 = test_y1
print(np.shape(df_test3))


df_train = df_train3
df_dev = df_dev3
df_test = df_test3
# Out:
# (4032, 15, 129, 4)
# (576, 15, 129, 4)
# (1152, 15, 129, 4)

# %%
# shape = np.shape(df_train3)
# df_train = np.reshape(df_train3, (shape[0], shape[1], shape[2]*shape[3]))

# shape = np.shape(df_dev3)
# df_dev = np.reshape(df_dev3, (shape[0], shape[1], shape[2]*shape[3]))


# shape = np.shape(df_test3)
# df_test = np.reshape(df_test3, (shape[0], shape[1], shape[2]*shape[3]))

# %% [markdown]
# # Create Tensor from labels and data

# %%
# from numpy import newaxis
# sh = np.shape(df_train11)
# a = df_train11.values[:]
# df_train = df_train11.values[:, newaxis, :]
# df_dev = df_dev11.values[:,newaxis, :]
# df_test = df_test11.values[:,newaxis, :]
# print(np.shape(df_train))

# channels_in = 15

# df_train = df_train.reshape(np.shape(df_train)[0], channels_in, np.int64(np.shape(df_train)[2]//channels_in))
# df_dev = df_dev.reshape(np.shape(df_dev)[0], channels_in, np.int64(np.shape(df_dev)[2]//channels_in))
# df_test = df_test.reshape(np.shape(df_test)[0], channels_in, np.int64(np.shape(df_test)[2]//channels_in))
# print(np.shape(df_train))
####


# df_train = df_train11.values[:, :, newaxis]
# df_dev = df_dev11.values[:, :,newaxis]
# df_test = df_test11.values[:, :,newaxis]

# df_train = df_train.reshape(np.shape(df_train)[0], np.int64(np.shape(df_train)[1]//channels_in), channels_in)
# df_dev = df_dev.reshape(np.shape(df_dev)[0], np.int64(np.shape(df_dev)[1]//channels_in), channels_in)
# df_test = df_test.reshape(np.shape(df_test)[0], np.int64(np.shape(df_test)[1]//channels_in), channels_in)
# print(np.shape(df_train))

# %%
# Create tensor from labels
# Transform labels in the format 1_9 to binary
train_y3 = pd.DataFrame(np.floor(train_y1.values[:].astype('float64')/10))
dev_y3 = pd.DataFrame(np.floor(dev_y1.values[:].astype('float64')/10))

train_y = torch.FloatTensor(train_y3.values[:])
dev_y = torch.FloatTensor(dev_y3.values[:])
test_y = torch.FloatTensor(test_y1.values[:])

train_x	= torch.FloatTensor(df_train.astype('float64'))
dev_x = torch.FloatTensor(df_dev.astype('float64'))
test_x = torch.FloatTensor(df_test.astype('float64'))

# %%
print(np.shape(train_x))
print(np.shape(train_y))

print(np.shape(dev_x))
print(np.shape(dev_y))

print(np.shape(test_x))
print(np.shape(test_y))
# Out:
# torch.Size([4032, 15, 129, 4])
# torch.Size([4032, 1])
# torch.Size([576, 15, 129, 4])
# torch.Size([576, 1])
# torch.Size([1152, 15, 129, 4])
# torch.Size([1152, 1])

# %%
# from torch.nn import Conv2d, functional as F, Linear, MaxPool2d, Module

# class ConvLayerNet4(torch.nn.Module):

#     def __init__(self,  channels_in, channels_out, D_in, H, D_out, device, drop=0.0, kernel_size=1, stride=1):
#         super(ConvLayerNet4, self).__init__()
        
#         self.device = device
        
#         self.convs = nn.ModuleList([
#             nn.Conv2d(1, channels_out, kernel_size=kernel_size, stride=stride)
#         for i in range(15)])
        
#         W_out = ((D_in - kernel_size)//stride + 1)*channels_out
        
#         self.pool = MaxPool2d(kernel_size=2, stride=2, padding=0)
        
#         self.linear1_1 = torch.nn.Linear(H3, 64)
#         self.linear2 = torch.nn.Linear(64, D_out)
        
#         self.fc1 = Linear(18 * 16 * 16, 64)
#         self.fc2 = Linear(64, 1)

#     def forward(self, x):
#         ii = 0
#         h_relu = torch.FloatTensor([]).to(self.device)
#         for layers in self.convs:
#             print(np.shape(torch.unsqueeze(x[:, ii, :, :], 1)))
#             x_data = layers(torch.unsqueeze(x[:, ii, :, :], 1)) # torch.unsqueeze(x[:, ii, :, :], 1
#             print(np.shape(x_data))
#             x_data = self.relu(x_data)
#             b, h, w = x_data.size()
#             x_data = x_data.view(b,-1)
#             h_relu = torch.cat([h_relu, x_data], axis = 1)
#             ii = ii+1
            
#         x = F.relu(self.conv(x))
#         x = self.pool(x)
#         x = x.view(-1, 18 * 16 * 16)
#         x = F.relu(self.fc1(x))
#         x = self.fc2(x)
#         return x

# %%
# print(np.shape(train_x))
# print(D_in)
# W_out = ((D_in - kernel_size)//stride + 1)*channels_out
# print(W_out)
# #         W_out = ((W_out - kernel_size)//stride + 1)*channels_out
# W_out = ((W_out - kernel_size)//stride + 1)*15*channels_out
# W_out = np.int64(W_out) 

# print(W_out)

# %% [markdown]
# # Define the hyperparameters of the model

# %%
print('Started training')
seed = 777
torch.manual_seed(seed)

#################
# choose the gpu
gpu_id = 5
device = torch.device("cuda:" + str(gpu_id))
# device = torch.device("cpu")
print(device)

#################
# Input and output sizes
H_in = np.shape(train_x)[2]
W_in = np.shape(train_x)[3]
channels_in = 1
channels_out = 1

D_out = 1

#################
# Choose the hidden layer, drop, batch_size, num_epochs, learning_rate
# H = 512  #hidden layer size

drop = 0.1
H1 = [1024, 512, 256, 128]#, 2048,1024, 512
N1 = [8, 16, 32, 64]
epochs = 1000
learning_rate = 1e-3
kernel_size = 1
stride  = 1

# loss_fn = torch.nn.BCELoss()BCEWithLogitsLoss
# N = batch_size

best_epoch = 0
dev_acc_max=0
epoch_max=0
loss_list     = np.zeros((epochs,))
accuracy_list = np.zeros((epochs,))
# Out:
# Started training
# cuda:5

# %%
D_in
# Out:
# 129

# %%
# class ConvLayerNet3(torch.nn.Module):
#     def __init__(self,  channels_in, channels_out, D_in, H, D_out, device, drop=0.0, kernel_size=1, stride=1):
#         super(ConvLayerNet3, self).__init__()
#         self.device = device
# #         self.convs = nn.ModuleList([nn.Conv1d(1, channels_out, kernel_size=kernel_size, stride=stride) for i in range(15)])
#         self.convs = nn.ModuleList([nn.Sequential(
#             nn.Conv1d(1, channels_out, kernel_size=kernel_size, stride=stride),
#             nn.Conv1d(1, channels_out, kernel_size=kernel_size, stride=stride),
# #             nn.Conv1d(1, channels_out, kernel_size=kernel_size, stride=stride),
#         ) for i in range(15)])
                                    
#         W_out = ((D_in - kernel_size)//stride + 1)*channels_out
# #         W_out = ((W_out - kernel_size)//stride + 1)*channels_out
#         W_out = ((W_out - kernel_size)//stride + 1)*15*channels_out
#         W_out = np.int64(W_out) 
#         print(W_out)
        
#         self.linear1_1 = torch.nn.Linear(W_out, H)
#         self.linear1_2 = torch.nn.Linear(H, 32)
# #         self.linear1_3 = torch.nn.Linear(H3, 64)
#         self.linear2 = torch.nn.Linear(32, D_out)
        
#         self.relu = torch.nn.ReLU()
#         self.drop1   = torch.nn.Dropout(p=drop)
#         self.sigmoid = torch.nn.Sigmoid()
# #         self.softmax = torch.nn.Softmax(dim=1)

#     def forward(self, x):
#         ii = 0
#         h_relu = torch.FloatTensor([]).to(self.device)
#         for layers in self.convs:
#             x_data = layers(torch.unsqueeze(x[:, ii, :],1))
# #             print(np.shape(x_data))
#             x_data = self.relu(x_data)
#             b, h, w = x_data.size()
#             x_data = x_data.view(b,-1)
#             print(np.shape(x_data))
#             h_relu = torch.cat([h_relu, x_data], axis = 1)
#             ii = ii+1
        
#         h_relu = self.drop1(self.linear1_1(h_relu))#.clamp(min=0)#.clamp(min=0)
#         h_relu = self.relu(h_relu)
        
#         h_relu = self.drop1(self.linear1_2(h_relu))#.clamp(min=0)#.clamp(min=0)
#         h_relu = self.relu(h_relu)
        
# #         h_relu = self.drop1(self.linear1_3(h_relu))#.clamp(min=0)#.clamp(min=0)
# #         h_relu = self.relu(h_relu)
        
#         y_pred = self.sigmoid(self.linear2(h_relu))
        
#         return y_pred
class ConvLayerNet3(torch.nn.Module):
    def __init__(self,  channels_in, channels_out, H_in, W_in, H, D_out, device, drop=0.0, kernel_size=1, stride=1):
        super(ConvLayerNet3, self).__init__()
        self.device = device
#         self.convs = nn.ModuleList([nn.Conv1d(1, channels_out, kernel_size=kernel_size, stride=stride) for i in range(15)])
        self.convs = nn.ModuleList([nn.Sequential(
            nn.Conv2d(1, channels_out, kernel_size=kernel_size, stride=stride),
#             nn.BatchNorm2d(channels_out),
#             nn.ReLU(inplace=True),
            nn.Conv2d(1, channels_out, kernel_size=kernel_size, stride=stride),
#             nn.BatchNorm2d(256),
#             nn.ReLU(inplace=True),
#             nn.Conv2d(1, channels_out, kernel_size=kernel_size, stride=stride),
#             nn.Conv1d(1, channels_out, kernel_size=kernel_size, stride=stride),
        ) for i in range(15)])
                                    
        H_out = ((H_in - kernel_size)//stride + 1)*channels_out
        H_out = ((H_out - kernel_size)//stride + 1)*channels_out
#         W_out = ((W_out - kernel_size)//stride + 1)*channels_out
        W_out = ((W_in - kernel_size)//stride + 1)*channels_out
        W_out = ((W_out - kernel_size)//stride + 1)*channels_out
#         print(H_out)
#         print(W_out)
        H3 = H//2
        print(H_out)
        print(W_out)
        self.linear1_1 = torch.nn.Linear(W_out*H_out*15, H)
        self.linear1_2 = torch.nn.Linear(H, H3)
        self.linear1_3 = torch.nn.Linear(H3, 32)
#         self.linear1_4 = torch.nn.Linear(64, 16)
        self.linear2 = torch.nn.Linear(32, D_out)
        
        self.relu = torch.nn.ReLU()
        self.drop1   = torch.nn.Dropout(p=drop)
        self.sigmoid = torch.nn.Sigmoid()
#         self.softmax = torch.nn.Softmax(dim=1)

    def forward(self, x):
        ii = 0
        h_relu = torch.FloatTensor([]).to(self.device)
        for layers in self.convs:
            x_data = layers(torch.unsqueeze(x[:, ii, :],1))
#             x_data = self.relu(x_data)
#             print(x_data.size())
            b, h, w, c = x_data.size()
            x_data = x_data.view(b,-1)
            h_relu = torch.cat([h_relu, x_data], axis = 1)
            ii = ii+1
#         print(np.shape(h_relu))
        h_relu = self.drop1(self.linear1_1(h_relu))#.clamp(min=0)#.clamp(min=0)
        h_relu = self.relu(h_relu)
        
        h_relu = self.drop1(self.linear1_2(h_relu))#.clamp(min=0)#.clamp(min=0)
        h_relu = self.relu(h_relu)
        
        h_relu = self.drop1(self.linear1_3(h_relu))#.clamp(min=0)#.clamp(min=0)
        h_relu = self.relu(h_relu)
        
#         h_relu = self.drop1(self.linear1_4(h_relu))#.clamp(min=0)#.clamp(min=0)
#         h_relu = self.relu(h_relu)
        
        y_pred = self.sigmoid(self.linear2(h_relu))#
        
        return y_pred

# %%
for N in N1:
    for H in H1:
    #         H = 512
    #         H2 = 256
#         epochs  =1
        directory = '/raid/togzhan_syrymova/lump_project/models/'

        model = ConvLayerNet3(channels_in, channels_out, H_in, W_in, H, D_out, device, drop, kernel_size, stride).to(device)
        model_name = type(model).__name__

        model_name += '_pressure_' + 'conv2_2' + 'epochs_' \
        + str(epochs) + '_bs_' + str(N)+ '_H_' + str(H) \
        + '_drop_' + str(drop) \
        + '_ks_' + str(kernel_size) + '_stride_' + str(stride) + '_spect_1d'
        model_path = directory + model_name

        optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
        loss_fn = torch.nn.BCELoss()#BCELoss()
        print(model_name)
        print(model_path)
        print(model)

        # for H in H1:
        #     for N in N1:
        print(H)
        print(N)
        for e in range(epochs):
            total_loss = 0
            for i in range(0, train_x.shape[0], N):
                if i+N >= train_x.shape[0]:
                    x = train_x[i:]
                    y = train_y[i:]
                else:
                    x = train_x[i:i+N]
                    y = train_y[i:i+N]
                y_pred = model(x.to(device))
                loss = loss_fn(y_pred, y.to(device))
        #         loss_list[e] = loss.item()
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                total_loss += loss.item()
            print("Epoch {}/{}, Train Loss: {:.3f}".format(e+1, epochs, total_loss))
            #pdb.set_trace()
            #Loss and accuracy on dev data
            with torch.no_grad():
                model.eval()
                output = model(dev_x.to(device))
                output = (output>0.5).float()
                acc    = accuracy_score(dev_y, output.cpu())
        #         accuracy_list[e] = acc
                if acc > dev_acc_max:
                    dev_acc_max=acc
                    epoch_max=e+1
                    torch.save(model, model_path)
              #correct = (output == dev_y.to(device)).float().sum()
    #             model.train()
                torch.save(model, model_path+'_last')
            print("Dev Accuracy: {:.3f}".format(acc))

        print("##############################################")
        print("Best dev accuracy is {:.3f} at epoch {}".format(dev_acc_max, epoch_max))
        print("Number of class 1 samples: ", (dev_y>0.5).float().sum().item())
        print("##############################################")

        ####################################################################################################
        #Evaluation
        ####################################################################################################
        with torch.no_grad():
        #             pdb.set_trace()
            model = torch.load(model_path)
            model.eval().to(device)
            output = model(test_x.to(device))
            output = (output>0.5).float()
            acc    = accuracy_score(test_y, output.cpu())
            print("Test Accuracy: {:.3f}".format(acc))
            print(model)

        with torch.no_grad():
        #             pdb.set_trace()
            model = torch.load(model_path+'_last')
            model.eval().to(device)
            output = model(test_x.to(device))
            output = (output>0.5).float()
            acc    = accuracy_score(test_y, output.cpu())
            print("Test Accuracy Last: {:.3f}".format(acc))
            print(model)
exit()
# Out:
# 129
# 4
# ConvLayerNet3_pressure_conv2_2epochs_1000_bs_8_H_1024_drop_0.1_ks_1_stride_1_spect_1d
# /raid/togzhan_syrymova/lump_project/models/ConvLayerNet3_pressure_conv2_2epochs_1000_bs_8_H_1024_drop_0.1_ks_1_stride_1_spect_1d
# ConvLayerNet3(
#   (convs): ModuleList(
#     (0): Sequential(
#       (0): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Sequential(
#       (0): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): Sequential(
#       (0): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (3): Sequential(
#       (0): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (4): Sequential(
#       (0): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (5): Sequential(
#       (0): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (6): Sequential(
#       (0): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (7): Sequential(
#       (0): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (8): Sequential(
#       (0): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (9): Sequential(
#       (0): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (10): Sequential(
#       (0): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (11): Sequential(
#       (0): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (12): Sequential(
#       (0): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (13): Sequential(
#       (0): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (14): Sequential(
#       (0): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (linear1_1): Linear(in_features=7740, out_features=1024, bias=True)
#   (linear1_2): Linear(in_features=1024, out_features=512, bias=True)
#   (linear1_3): Linear(in_features=512, out_features=32, bias=True)
#   (linear2): Linear(in_features=32, out_features=1, bias=True)
#   (relu): ReLU()
#   (drop1): Dropout(p=0.1, inplace=False)
#   (sigmoid): Sigmoid()
# )
# 1024
# 8
# Epoch 1/1000, Train Loss: 466.420
# Dev Accuracy: 0.700
# Epoch 2/1000, Train Loss: 245.279
# Dev Accuracy: 0.776
# Epoch 3/1000, Train Loss: 213.661
# Dev Accuracy: 0.800
# Epoch 4/1000, Train Loss: 199.433
# Dev Accuracy: 0.802
# Epoch 5/1000, Train Loss: 194.745
# Dev Accuracy: 0.793
# Epoch 6/1000, Train Loss: 177.143
# Dev Accuracy: 0.847
# Epoch 7/1000, Train Loss: 160.607
# Dev Accuracy: 0.845
# Epoch 8/1000, Train Loss: 149.292
# Dev Accuracy: 0.802
# Epoch 9/1000, Train Loss: 130.584
# Dev Accuracy: 0.835
# Epoch 10/1000, Train Loss: 141.916
# Dev Accuracy: 0.863
# Epoch 11/1000, Train Loss: 105.587
# Dev Accuracy: 0.852
# Epoch 12/1000, Train Loss: 120.419
# Dev Accuracy: 0.849
# Epoch 13/1000, Train Loss: 106.989
# Dev Accuracy: 0.875
# Epoch 14/1000, Train Loss: 98.328
# Dev Accuracy: 0.865
# Epoch 15/1000, Train Loss: 68.342
# Dev Accuracy: 0.852
# Epoch 16/1000, Train Loss: 75.191
# Dev Accuracy: 0.866
# Epoch 17/1000, Train Loss: 64.132
# Dev Accuracy: 0.830
# Epoch 18/1000, Train Loss: 65.798
# Dev Accuracy: 0.866
# Epoch 19/1000, Train Loss: 85.797
# Dev Accuracy: 0.854
# Epoch 20/1000, Train Loss: 60.535
# Dev Accuracy: 0.880
# Epoch 21/1000, Train Loss: 50.383
# Dev Accuracy: 0.870
# Epoch 22/1000, Train Loss: 42.264
# Dev Accuracy: 0.878
# Epoch 23/1000, Train Loss: 39.549
# Dev Accuracy: 0.878
# Epoch 24/1000, Train Loss: 34.511
# Dev Accuracy: 0.861
# Epoch 25/1000, Train Loss: 87.079
# Dev Accuracy: 0.873
# Epoch 26/1000, Train Loss: 43.388
# Dev Accuracy: 0.866
# Epoch 27/1000, Train Loss: 92.340
# Dev Accuracy: 0.870
# Epoch 28/1000, Train Loss: 42.566
# Dev Accuracy: 0.854
# Epoch 29/1000, Train Loss: 26.417
# Dev Accuracy: 0.877
# Epoch 30/1000, Train Loss: 51.258
# Dev Accuracy: 0.889
# Epoch 31/1000, Train Loss: 59.799
# Dev Accuracy: 0.875
# Epoch 32/1000, Train Loss: 62.720
# Dev Accuracy: 0.885
# Epoch 33/1000, Train Loss: 30.884
# Dev Accuracy: 0.858
# Epoch 34/1000, Train Loss: 69.333
# Dev Accuracy: 0.873
# Epoch 35/1000, Train Loss: 17.526
# Dev Accuracy: 0.884
# Epoch 36/1000, Train Loss: 17.354
# Dev Accuracy: 0.880
# Epoch 37/1000, Train Loss: 63.187
# Dev Accuracy: 0.837
# Epoch 38/1000, Train Loss: 28.679
# Dev Accuracy: 0.877
# Epoch 39/1000, Train Loss: 64.574
# Dev Accuracy: 0.861
# Epoch 40/1000, Train Loss: 47.500
# Dev Accuracy: 0.877
# Epoch 41/1000, Train Loss: 31.268
# Dev Accuracy: 0.858
# Epoch 42/1000, Train Loss: 40.550
# Dev Accuracy: 0.854
# Epoch 43/1000, Train Loss: 27.786
# Dev Accuracy: 0.884
# Epoch 44/1000, Train Loss: 60.925
# Dev Accuracy: 0.859
# Epoch 45/1000, Train Loss: 94.986
# Dev Accuracy: 0.873
# Epoch 46/1000, Train Loss: 32.262
# Dev Accuracy: 0.872
# Epoch 47/1000, Train Loss: 17.863
# Dev Accuracy: 0.885
# Epoch 48/1000, Train Loss: 22.898
# Dev Accuracy: 0.884
# Epoch 49/1000, Train Loss: 40.388
# Dev Accuracy: 0.884
# Epoch 50/1000, Train Loss: 33.303
# Dev Accuracy: 0.877
# Epoch 51/1000, Train Loss: 53.306
# Dev Accuracy: 0.875
# Epoch 52/1000, Train Loss: 26.114
# Dev Accuracy: 0.885
# Epoch 53/1000, Train Loss: 134.944
# Dev Accuracy: 0.884
# Epoch 54/1000, Train Loss: 83.127
# Dev Accuracy: 0.887
# Epoch 55/1000, Train Loss: 82.412
# Dev Accuracy: 0.877
# Epoch 56/1000, Train Loss: 24.233
# Dev Accuracy: 0.852
# Epoch 57/1000, Train Loss: 36.941
# Dev Accuracy: 0.878
# Epoch 58/1000, Train Loss: 13.135
# Dev Accuracy: 0.877
# Epoch 59/1000, Train Loss: 6.865
# Dev Accuracy: 0.882
# Epoch 60/1000, Train Loss: 46.403
# Dev Accuracy: 0.873
# Epoch 61/1000, Train Loss: 12.597
# Dev Accuracy: 0.885
# Epoch 62/1000, Train Loss: 8.761
# Dev Accuracy: 0.887
# Epoch 63/1000, Train Loss: 31.567
# Dev Accuracy: 0.873
# Epoch 64/1000, Train Loss: 39.569
# Dev Accuracy: 0.892
# Epoch 65/1000, Train Loss: 15.582
# Dev Accuracy: 0.891
# Epoch 66/1000, Train Loss: 8.725
# Dev Accuracy: 0.892
# Epoch 67/1000, Train Loss: 27.357
# Dev Accuracy: 0.880
# Epoch 68/1000, Train Loss: 79.989
# Dev Accuracy: 0.880
# Epoch 69/1000, Train Loss: 37.272
# Dev Accuracy: 0.887
# Epoch 70/1000, Train Loss: 28.954
# Dev Accuracy: 0.891
# Epoch 71/1000, Train Loss: 81.102
# Dev Accuracy: 0.872
# Epoch 72/1000, Train Loss: 63.531
# Dev Accuracy: 0.828
# Epoch 73/1000, Train Loss: 118.617
# Dev Accuracy: 0.877
# Epoch 74/1000, Train Loss: 59.723
# Dev Accuracy: 0.889
# Epoch 75/1000, Train Loss: 57.191
# Dev Accuracy: 0.885
# Epoch 76/1000, Train Loss: 33.419
# Dev Accuracy: 0.877
# Epoch 77/1000, Train Loss: 21.108
# Dev Accuracy: 0.875
# Epoch 78/1000, Train Loss: 52.314
# Dev Accuracy: 0.875
# Epoch 79/1000, Train Loss: 49.155
# Dev Accuracy: 0.882
# Epoch 80/1000, Train Loss: 34.751
# Dev Accuracy: 0.878
# Epoch 81/1000, Train Loss: 57.230
# Dev Accuracy: 0.882
# Epoch 82/1000, Train Loss: 8.183
# Dev Accuracy: 0.898
# Epoch 83/1000, Train Loss: 30.980
# Dev Accuracy: 0.877
# Epoch 84/1000, Train Loss: 5.746
# Dev Accuracy: 0.863
# Epoch 85/1000, Train Loss: 130.027
# Dev Accuracy: 0.878
# Epoch 86/1000, Train Loss: 48.521
# Dev Accuracy: 0.875
# Epoch 87/1000, Train Loss: 33.056
# Dev Accuracy: 0.880
# Epoch 88/1000, Train Loss: 19.626
# Dev Accuracy: 0.882
# Epoch 89/1000, Train Loss: 7.166
# Dev Accuracy: 0.887
# Epoch 90/1000, Train Loss: 109.132
# Dev Accuracy: 0.877
# Epoch 91/1000, Train Loss: 109.569
# Dev Accuracy: 0.896
# Epoch 92/1000, Train Loss: 40.531
# Dev Accuracy: 0.898
# Epoch 93/1000, Train Loss: 27.492
# Dev Accuracy: 0.878
# Epoch 94/1000, Train Loss: 42.322
# Dev Accuracy: 0.877
# Epoch 95/1000, Train Loss: 8.882
# Dev Accuracy: 0.896
# Epoch 96/1000, Train Loss: 28.617
# Dev Accuracy: 0.899
# Epoch 97/1000, Train Loss: 51.846
# Dev Accuracy: 0.906
# Epoch 98/1000, Train Loss: 10.759
# Dev Accuracy: 0.896
# Epoch 99/1000, Train Loss: 88.357
# Dev Accuracy: 0.899
# Epoch 100/1000, Train Loss: 53.936
# Dev Accuracy: 0.905
# Epoch 101/1000, Train Loss: 37.752
# Dev Accuracy: 0.885
# Epoch 102/1000, Train Loss: 27.046
# Dev Accuracy: 0.899
# Epoch 103/1000, Train Loss: 33.460
# Dev Accuracy: 0.887
# Epoch 104/1000, Train Loss: 79.679
# Dev Accuracy: 0.885
# Epoch 105/1000, Train Loss: 30.696
# Dev Accuracy: 0.889
# Epoch 106/1000, Train Loss: 132.458
# Dev Accuracy: 0.870
# Epoch 107/1000, Train Loss: 146.274
# Dev Accuracy: 0.878
# Epoch 108/1000, Train Loss: 82.432
# Dev Accuracy: 0.882
# Epoch 109/1000, Train Loss: 80.633
# Dev Accuracy: 0.865
# Epoch 110/1000, Train Loss: 48.477
# Dev Accuracy: 0.812
# Epoch 111/1000, Train Loss: 72.050
# Dev Accuracy: 0.894
# Epoch 112/1000, Train Loss: 73.851
# Dev Accuracy: 0.891
# Epoch 113/1000, Train Loss: 38.013
# Dev Accuracy: 0.875
# Epoch 114/1000, Train Loss: 85.244
# Dev Accuracy: 0.887
# Epoch 115/1000, Train Loss: 23.181
# Dev Accuracy: 0.894
# Epoch 116/1000, Train Loss: 71.907
# Dev Accuracy: 0.887
# Epoch 117/1000, Train Loss: 129.214
# Dev Accuracy: 0.859
# Epoch 118/1000, Train Loss: 77.672
# Dev Accuracy: 0.887
# Epoch 119/1000, Train Loss: 168.047
# Dev Accuracy: 0.849
# Epoch 120/1000, Train Loss: 70.076
# Dev Accuracy: 0.870
# Epoch 121/1000, Train Loss: 87.800
# Dev Accuracy: 0.880
# Epoch 122/1000, Train Loss: 42.178
# Dev Accuracy: 0.885
# Epoch 123/1000, Train Loss: 22.821
# Dev Accuracy: 0.884
# Epoch 124/1000, Train Loss: 20.280
# Dev Accuracy: 0.884
# Epoch 125/1000, Train Loss: 32.208
# Dev Accuracy: 0.894
# Epoch 126/1000, Train Loss: 1.383
# Dev Accuracy: 0.889
# Epoch 127/1000, Train Loss: 5.952
# Dev Accuracy: 0.878
# Epoch 128/1000, Train Loss: 9.537
# Dev Accuracy: 0.891
# Epoch 129/1000, Train Loss: 2.880
# Dev Accuracy: 0.885
# Epoch 130/1000, Train Loss: 26.867
# Dev Accuracy: 0.887
# Epoch 131/1000, Train Loss: 55.499
# Dev Accuracy: 0.889
# Epoch 132/1000, Train Loss: 35.939
# Dev Accuracy: 0.887
# Epoch 133/1000, Train Loss: 36.724
# Dev Accuracy: 0.877
# Epoch 134/1000, Train Loss: 9.986
# Dev Accuracy: 0.891
# Epoch 135/1000, Train Loss: 16.279
# Dev Accuracy: 0.884
# Epoch 136/1000, Train Loss: 11.834
# Dev Accuracy: 0.887
# Epoch 137/1000, Train Loss: 10.533
# Dev Accuracy: 0.899
# Epoch 138/1000, Train Loss: 3.411
# Dev Accuracy: 0.894
# Epoch 139/1000, Train Loss: 80.317
# Dev Accuracy: 0.882
# Epoch 140/1000, Train Loss: 30.833
# Dev Accuracy: 0.875
# Epoch 141/1000, Train Loss: 20.008
# Dev Accuracy: 0.901
# Epoch 142/1000, Train Loss: 33.103
# Dev Accuracy: 0.898
# Epoch 143/1000, Train Loss: 64.963
# Dev Accuracy: 0.877
# Epoch 144/1000, Train Loss: 34.457
# Dev Accuracy: 0.891
# Epoch 145/1000, Train Loss: 46.780
# Dev Accuracy: 0.894
# Epoch 146/1000, Train Loss: 26.722
# Dev Accuracy: 0.894
# Epoch 147/1000, Train Loss: 61.677
# Dev Accuracy: 0.877
# Epoch 148/1000, Train Loss: 129.117
# Dev Accuracy: 0.891
# Epoch 149/1000, Train Loss: 50.428
# Dev Accuracy: 0.894
# Epoch 150/1000, Train Loss: 15.706
# Dev Accuracy: 0.892
# Epoch 151/1000, Train Loss: 49.587
# Dev Accuracy: 0.882
# Epoch 152/1000, Train Loss: 146.186
# Dev Accuracy: 0.894
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-73-b7f6f2e934bd> in <module>
#      40                 loss.backward()
#      41                 optimizer.step()
# ---> 42                 total_loss += loss.item()
#      43             print("Epoch {}/{}, Train Loss: {:.3f}".format(e+1, epochs, total_loss))
#      44             #pdb.set_trace()
#
# KeyboardInterrupt:

# %%
with torch.no_grad():
#             pdb.set_trace()
    model = torch.load(model_path)
    model.eval().to(device)
    output = model(test_x.to(device))
    output = (output>0.5).float()
    acc    = accuracy_score(test_y, output.cpu())
    print("Test Accuracy: {:.3f}".format(acc))
    print(model)
# Out:
# Test Accuracy: 0.652
# ConvLayerNet3(
#   (convs): ModuleList(
#     (0): Sequential(
#       (0): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Sequential(
#       (0): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): Sequential(
#       (0): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (3): Sequential(
#       (0): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (4): Sequential(
#       (0): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (5): Sequential(
#       (0): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (6): Sequential(
#       (0): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (7): Sequential(
#       (0): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (8): Sequential(
#       (0): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (9): Sequential(
#       (0): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (10): Sequential(
#       (0): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (11): Sequential(
#       (0): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (12): Sequential(
#       (0): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (13): Sequential(
#       (0): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (14): Sequential(
#       (0): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (linear1_1): Linear(in_features=7740, out_features=1024, bias=True)
#   (linear1_2): Linear(in_features=1024, out_features=512, bias=True)
#   (linear1_3): Linear(in_features=512, out_features=32, bias=True)
#   (linear2): Linear(in_features=32, out_features=1, bias=True)
#   (relu): ReLU()
#   (drop1): Dropout(p=0.1, inplace=False)
#   (sigmoid): Sigmoid()
# )

# %%
torch.save(model, model_path)

# %%
exit()
